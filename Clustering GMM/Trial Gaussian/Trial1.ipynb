# %% [markdown]
# CELL 0 — Trial-1
# --
# MIN_POINTS=5 | chi-square 99.7 % (df=3)
# --
# Per-frame preprocessing
#
# ROI XY only
#
# Soft SNR weights
#
# K=1 Gaussian
#
# Refit on inliers (offline)
#
# Outputs Head 1–3 per trial per subject
#
# Head-4 not enabled

# %% [markdown]
# CELL 1 — Imports + Global Seed

# %%
import os
import json
from pathlib import Path
from typing import Dict, List, Optional, Tuple

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.stats import chi2

# Optional interactivity (VSCode Jupyter)
try:
    import ipywidgets as widgets
    from IPython.display import display
    HAS_WIDGETS = True
except Exception:
    HAS_WIDGETS = False

# -------------------------
# Reproducibility
# -------------------------
SEED = 42
np.random.seed(SEED)

# %% [markdown]
# CELL 2 — Paths + Trial-2 Config (LOCKED)

# %%
# -------------------------
# Paths
# -------------------------
DATASET_ROOT = Path(r"E:\0.TA_Teguh\dataset3")   # contains A..J
OUT_ROOT     = Path(r"E:\0.TA_Teguh\GMM Trial 1")        # output root

SUBJECTS = list("ABCDEFGHIJ")  # A..J
TRIALS   = list(range(1, 73))  # Jalan1..Jalan72

# ===============================
# Trial-2 Configuration (LOCKED)
# ===============================

# ROI (NO Z GATING)
ROI_X = (-2.5, 2.5)
ROI_Y = (0.0, 5.0)

# Frame validity
MIN_POINTS = 5  # baseline (later try 10)

# Gaussian model
GMM_K = 1  # fixed: single Gaussian

# Mahalanobis outlier removal
CHI2_LEVEL = 0.997
CHI2_DF = 3  # x,y,z

# Refit (offline)
USE_REFIT_OFFLINE = True

# Soft SNR weighting (baseline)
SNR_REF = 10.0
SNR_WEIGHT_MIN = 0.10
SNR_WEIGHT_MAX = 1.00

# Numerical safety
COV_EPS = 1e-6

# %% [markdown]
# CELL 3 — Create Output Folders (Head 1/2/3 + per subject + _summary)

# %%
def ensure_dirs():
    for head_name in ["Head 1", "Head 2", "Head 3"]:
        (OUT_ROOT / head_name).mkdir(parents=True, exist_ok=True)
        (OUT_ROOT / head_name / "_summary").mkdir(parents=True, exist_ok=True)
        for s in SUBJECTS:
            (OUT_ROOT / head_name / s).mkdir(parents=True, exist_ok=True)

    (OUT_ROOT / "_summary").mkdir(parents=True, exist_ok=True)

ensure_dirs()
print("Output folders ready:", OUT_ROOT)
# Out:
# Output folders ready: E:\0.TA_Teguh\GMM Trial 1

# %% [markdown]
# CELL 4 — Build File Index + Missing Files Audit

# %%
def build_file_index() -> pd.DataFrame:
    rows = []
    for s in SUBJECTS:
        for t in TRIALS:
            in_path = DATASET_ROOT / s / f"Jalan{t}.csv"
            h1_out  = OUT_ROOT / "Head 1" / s / f"Jalan{t}.csv"
            h2_out  = OUT_ROOT / "Head 2" / s / f"Jalan{t}.csv"
            h3_out  = OUT_ROOT / "Head 3" / s / f"Jalan{t}.jsonl"
            rows.append({
                "subject": s,
                "trial": t,
                "input_path": str(in_path),
                "head1_out": str(h1_out),
                "head2_out": str(h2_out),
                "head3_out": str(h3_out),
            })
    return pd.DataFrame(rows)

index_df = build_file_index()

missing = index_df[~index_df["input_path"].apply(lambda p: Path(p).exists())]
print("Total index rows:", len(index_df))
print("Missing files:", len(missing))
if len(missing) > 0:
    display(missing.head(20) if HAS_WIDGETS else missing.head(20))
# Out:
# Total index rows: 720
# Missing files: 0

# %% [markdown]
# CELL 5 — CSV Loader

# %%
REQUIRED_COLS = ["timestamp", "frame", "x", "y", "z", "doppler", "SNR"]

def load_trial_csv(path: str) -> pd.DataFrame:
    df = pd.read_csv(path)

    for c in REQUIRED_COLS:
        if c not in df.columns:
            raise ValueError(f"Missing column '{c}' in {path}")

    # types
    df["timestamp"] = df["timestamp"].astype(str)
    df["frame"] = df["frame"].astype(int)
    for c in ["x", "y", "z", "doppler", "SNR"]:
        df[c] = df[c].astype(float)

    df = df.sort_values(["frame"]).reset_index(drop=True)
    return df

# %% [markdown]
# CELL 6 — Utility: JSON-safe converter

# %%
def to_py(obj):
    """Convert numpy scalars/arrays to Python native types for JSON serialization."""
    if isinstance(obj, (np.integer,)):
        return int(obj)
    if isinstance(obj, (np.floating,)):
        return float(obj)
    if isinstance(obj, (np.ndarray,)):
        return obj.tolist()
    if isinstance(obj, dict):
        return {k: to_py(v) for k, v in obj.items()}
    if isinstance(obj, (list, tuple)):
        return [to_py(v) for v in obj]
    return obj

# %% [markdown]
# CELL 7 — Core Math: Soft SNR Weight, Fit K=1 Gaussian, Mahalanobis d²

# %%
def compute_snr_weight(snr_values: np.ndarray) -> np.ndarray:
    """
    Soft weighting: higher SNR => higher weight, clipped.
    Baseline: w = clip(SNR / SNR_REF, [min, max])
    """
    snr_values = np.asarray(snr_values, dtype=float)
    w = snr_values / float(SNR_REF)
    w = np.clip(w, SNR_WEIGHT_MIN, SNR_WEIGHT_MAX)
    return w

def fit_gaussian_k1(X: np.ndarray, weights: Optional[np.ndarray] = None) -> Tuple[np.ndarray, np.ndarray]:
    """
    Weighted Gaussian fit (K=1): returns (mu[3], Sigma[3x3]).
    """
    X = np.asarray(X, dtype=float)
    if X.ndim != 2 or X.shape[1] != 3:
        raise ValueError("X must be shape (N,3)")

    if weights is None:
        mu = X.mean(axis=0)
        Sigma = np.cov(X.T, bias=False)
    else:
        w = np.asarray(weights, dtype=float)
        w = w / (np.sum(w) + 1e-12)
        mu = np.sum(X * w[:, None], axis=0)
        Xc = X - mu
        Sigma = (Xc.T * w) @ Xc

    # numerical safety
    Sigma = np.asarray(Sigma, dtype=float)
    Sigma += COV_EPS * np.eye(3)
    return mu, Sigma

def mahalanobis_d2(X: np.ndarray, mu: np.ndarray, Sigma: np.ndarray) -> np.ndarray:
    """
    Returns Mahalanobis squared distance d² for each point in X.
    """
    X = np.asarray(X, dtype=float)
    mu = np.asarray(mu, dtype=float)
    Sigma = np.asarray(Sigma, dtype=float)

    invS = np.linalg.inv(Sigma)
    diff = X - mu
    d2 = np.einsum("ij,jk,ik->i", diff, invS, diff)
    return d2

def chi2_threshold(level: float, df: int = 3) -> float:
    return float(chi2.ppf(level, df=df))

# %% [markdown]
# CELL 8 — Per-frame Processor (Trial-2 rules)

# %%
def process_frame(df_frame: pd.DataFrame) -> Tuple[pd.DataFrame, Dict, Optional[Dict]]:
    """
    Input: df_frame = rows for one frame (raw points).
    Output:
      - df_h1: Head-1 rows for this frame (inliers only; may be empty)
      - row_h2: Head-2 summary row (always returned)
      - row_h3: Head-3 params row (only if valid and GMM executed; else None)
    """
    frame_id = int(df_frame["frame"].iloc[0])
    ts = str(df_frame["timestamp"].iloc[0])

    # ROI gating (x,y only)
    df_roi = df_frame[
        df_frame["x"].between(*ROI_X) &
        df_frame["y"].between(*ROI_Y)
    ].copy()

    N_raw = int(len(df_frame))
    N_roi = int(len(df_roi))

    # Head-2 row (always)
    row_h2 = {
        "timestamp": ts,
        "frame": frame_id,
        "N_raw": N_raw,
        "N_roi": N_roi,
        "valid_minpts": 0,
        "N_inlier": 0,
        "conf": 0.0,
    }

    # invalid by min points
    if N_roi < MIN_POINTS:
        return pd.DataFrame(), row_h2, None

    row_h2["valid_minpts"] = 1

    # Prepare for Gaussian fit
    X = df_roi[["x", "y", "z"]].values
    snr = df_roi["SNR"].values
    w_snr = compute_snr_weight(snr)

    # Fit initial Gaussian
    mu, Sigma = fit_gaussian_k1(X, w_snr)
    d2 = mahalanobis_d2(X, mu, Sigma)
    thr = chi2_threshold(CHI2_LEVEL, df=CHI2_DF)

    inlier_mask = d2 <= thr
    df_in = df_roi.loc[inlier_mask].copy()

    # Add audit columns
    df_in["w_snr"] = w_snr[inlier_mask]
    df_in["d2"] = d2[inlier_mask]
    df_in["is_inlier"] = 1

    N_in = int(len(df_in))
    row_h2["N_inlier"] = N_in
    row_h2["conf"] = float(N_in / max(N_roi, 1))

    # If inliers too few, treat as invalid for Head-1/3 (Opsi A)
    if N_in < MIN_POINTS:
        row_h2["valid_minpts"] = 0
        row_h2["conf"] = 0.0
        return pd.DataFrame(), row_h2, None

    # Optional refit on inliers (OFFLINE)
    if USE_REFIT_OFFLINE:
        X_in = df_in[["x", "y", "z"]].values
        w_in = df_in["w_snr"].values
        mu, Sigma = fit_gaussian_k1(X_in, w_in)

    # Head-3 row (valid only)
    row_h3 = {
        "timestamp": ts,
        "frame": frame_id,
        "mu": mu.tolist(),
        "Sigma": Sigma.tolist(),
        "chi2_level": float(CHI2_LEVEL),
        "chi2_df": int(CHI2_DF),
        "chi2_threshold": float(thr),
        "N_raw": int(N_raw),
        "N_roi": int(N_roi),
        "N_inlier": int(N_in),
        "refit": bool(USE_REFIT_OFFLINE),
    }

    return df_in, row_h2, row_h3

# %% [markdown]
# CELL 9 — Per-file Processor (saves Head 1/2/3 per trial)

# %%
def process_one_file(input_path: str, head1_out: str, head2_out: str, head3_out: str) -> Dict:
    df = load_trial_csv(input_path)

    frames = sorted(df["frame"].unique().tolist())

    h1_parts: List[pd.DataFrame] = []
    h2_rows: List[Dict] = []
    h3_rows: List[Dict] = []

    points_before = int(len(df))

    for f in frames:
        df_f = df[df["frame"] == f]
        df_h1, row_h2, row_h3 = process_frame(df_f)

        # Head-2 always
        h2_rows.append(row_h2)

        # Head-1 only if any
        if not df_h1.empty:
            h1_parts.append(df_h1)

        # Head-3 only if valid
        if row_h3 is not None:
            h3_rows.append(row_h3)

    # Save Head-1
    if len(h1_parts) > 0:
        h1_df = pd.concat(h1_parts, ignore_index=True)
        # ensure column order (optional but nice)
        cols = ["timestamp","frame","x","y","z","doppler","SNR","w_snr","d2","is_inlier"]
        cols = [c for c in cols if c in h1_df.columns]
        h1_df = h1_df[cols]
        h1_df.to_csv(head1_out, index=False)
        points_after = int(len(h1_df))
    else:
        pd.DataFrame(columns=["timestamp","frame","x","y","z","doppler","SNR","w_snr","d2","is_inlier"]).to_csv(head1_out, index=False)
        points_after = 0

    # Save Head-2
    h2_df = pd.DataFrame(h2_rows)
    h2_cols = ["timestamp","frame","N_raw","N_roi","valid_minpts","N_inlier","conf"]
    h2_cols = [c for c in h2_cols if c in h2_df.columns]
    h2_df = h2_df[h2_cols]
    h2_df.to_csv(head2_out, index=False)

    # Save Head-3 (JSONL)
    with open(head3_out, "w", encoding="utf-8") as f:
        for r in h3_rows:
            f.write(json.dumps(to_py(r)) + "\n")

    frames_total = int(len(frames))
    frames_invalid = int((h2_df["valid_minpts"] == 0).sum()) if "valid_minpts" in h2_df.columns else 0
    mean_conf = float(h2_df["conf"].mean()) if "conf" in h2_df.columns and len(h2_df) else 0.0
    min_conf = float(h2_df["conf"].min()) if "conf" in h2_df.columns and len(h2_df) else 0.0

    return {
        "input_path": input_path,
        "points_before": points_before,
        "points_after": points_after,
        "frames_total": frames_total,
        "frames_invalid": frames_invalid,
        "mean_conf": mean_conf,
        "min_conf": min_conf,
    }

# %% [markdown]
# CELL 10 — Batch Runner (process all subjects + trials, skip missing)

# %%
def run_batch(index_df: pd.DataFrame) -> pd.DataFrame:
    rows = index_df.copy()

    summaries = []
    total = len(rows)

    for i, row in rows.reset_index(drop=True).iterrows():
        s = row["subject"]
        t = int(row["trial"])
        in_path = row["input_path"]

        print(f"[{i+1}/{total}] Processing {s}/Jalan{t} ...")

        if not Path(in_path).exists():
            summaries.append({
                "subject": s,
                "trial": t,
                "input_path": in_path,
                "error": "missing_file"
            })
            continue

        try:
            summ = process_one_file(
                input_path=in_path,
                head1_out=row["head1_out"],
                head2_out=row["head2_out"],
                head3_out=row["head3_out"]
            )
            summ["subject"] = s
            summ["trial"] = t
            summaries.append(summ)
        except Exception as e:
            summaries.append({
                "subject": s,
                "trial": t,
                "input_path": in_path,
                "error": str(e)
            })

    return pd.DataFrame(summaries)

summaries_df = run_batch(index_df)
display(summaries_df.head(10) if HAS_WIDGETS else summaries_df.head(10))
# Out:
# [1/720] Processing A/Jalan1 ...
# [2/720] Processing A/Jalan2 ...
# [3/720] Processing A/Jalan3 ...
# [4/720] Processing A/Jalan4 ...
# [5/720] Processing A/Jalan5 ...
# [6/720] Processing A/Jalan6 ...
# [7/720] Processing A/Jalan7 ...
# [8/720] Processing A/Jalan8 ...
# [9/720] Processing A/Jalan9 ...
# [10/720] Processing A/Jalan10 ...
# [11/720] Processing A/Jalan11 ...
# [12/720] Processing A/Jalan12 ...
# [13/720] Processing A/Jalan13 ...
# [14/720] Processing A/Jalan14 ...
# [15/720] Processing A/Jalan15 ...
# [16/720] Processing A/Jalan16 ...
# [17/720] Processing A/Jalan17 ...
# [18/720] Processing A/Jalan18 ...
# [19/720] Processing A/Jalan19 ...
# [20/720] Processing A/Jalan20 ...
# [21/720] Processing A/Jalan21 ...
# [22/720] Processing A/Jalan22 ...
# [23/720] Processing A/Jalan23 ...
# [24/720] Processing A/Jalan24 ...
# [25/720] Processing A/Jalan25 ...
# [26/720] Processing A/Jalan26 ...
# [27/720] Processing A/Jalan27 ...
# [28/720] Processing A/Jalan28 ...
# [29/720] Processing A/Jalan29 ...
# [30/720] Processing A/Jalan30 ...
# [31/720] Processing A/Jalan31 ...
# [32/720] Processing A/Jalan32 ...
# [33/720] Processing A/Jalan33 ...
# [34/720] Processing A/Jalan34 ...
# [35/720] Processing A/Jalan35 ...
# [36/720] Processing A/Jalan36 ...
# [37/720] Processing A/Jalan37 ...
# [38/720] Processing A/Jalan38 ...
# [39/720] Processing A/Jalan39 ...
# [40/720] Processing A/Jalan40 ...
# [41/720] Processing A/Jalan41 ...
# [42/720] Processing A/Jalan42 ...
# [43/720] Processing A/Jalan43 ...
# [44/720] Processing A/Jalan44 ...
# [45/720] Processing A/Jalan45 ...
# [46/720] Processing A/Jalan46 ...
# [47/720] Processing A/Jalan47 ...
# [48/720] Processing A/Jalan48 ...
# [49/720] Processing A/Jalan49 ...
# [50/720] Processing A/Jalan50 ...
# [51/720] Processing A/Jalan51 ...
# [52/720] Processing A/Jalan52 ...
# [53/720] Processing A/Jalan53 ...
# [54/720] Processing A/Jalan54 ...
# [55/720] Processing A/Jalan55 ...
# [56/720] Processing A/Jalan56 ...
# [57/720] Processing A/Jalan57 ...
# [58/720] Processing A/Jalan58 ...
# [59/720] Processing A/Jalan59 ...
# [60/720] Processing A/Jalan60 ...
# [61/720] Processing A/Jalan61 ...
# [62/720] Processing A/Jalan62 ...
# [63/720] Processing A/Jalan63 ...
# [64/720] Processing A/Jalan64 ...
# [65/720] Processing A/Jalan65 ...
# [66/720] Processing A/Jalan66 ...
# [67/720] Processing A/Jalan67 ...
# [68/720] Processing A/Jalan68 ...
# [69/720] Processing A/Jalan69 ...
# [70/720] Processing A/Jalan70 ...
# [71/720] Processing A/Jalan71 ...
# [72/720] Processing A/Jalan72 ...
# [73/720] Processing B/Jalan1 ...
# [74/720] Processing B/Jalan2 ...
# [75/720] Processing B/Jalan3 ...
# [76/720] Processing B/Jalan4 ...
# [77/720] Processing B/Jalan5 ...
# [78/720] Processing B/Jalan6 ...
# [79/720] Processing B/Jalan7 ...
# [80/720] Processing B/Jalan8 ...
# [81/720] Processing B/Jalan9 ...
# [82/720] Processing B/Jalan10 ...
# [83/720] Processing B/Jalan11 ...
# [84/720] Processing B/Jalan12 ...
# [85/720] Processing B/Jalan13 ...
# [86/720] Processing B/Jalan14 ...
# [87/720] Processing B/Jalan15 ...
# [88/720] Processing B/Jalan16 ...
# [89/720] Processing B/Jalan17 ...
# [90/720] Processing B/Jalan18 ...
# [91/720] Processing B/Jalan19 ...
# [92/720] Processing B/Jalan20 ...
# [93/720] Processing B/Jalan21 ...
# [94/720] Processing B/Jalan22 ...
# [95/720] Processing B/Jalan23 ...
# [96/720] Processing B/Jalan24 ...
# [97/720] Processing B/Jalan25 ...
# [98/720] Processing B/Jalan26 ...
# [99/720] Processing B/Jalan27 ...
# [100/720] Processing B/Jalan28 ...
# [101/720] Processing B/Jalan29 ...
# [102/720] Processing B/Jalan30 ...
# [103/720] Processing B/Jalan31 ...
# [104/720] Processing B/Jalan32 ...
# [105/720] Processing B/Jalan33 ...
# [106/720] Processing B/Jalan34 ...
# [107/720] Processing B/Jalan35 ...
# [108/720] Processing B/Jalan36 ...
# [109/720] Processing B/Jalan37 ...
# [110/720] Processing B/Jalan38 ...
# [111/720] Processing B/Jalan39 ...
# [112/720] Processing B/Jalan40 ...
# [113/720] Processing B/Jalan41 ...
# [114/720] Processing B/Jalan42 ...
# [115/720] Processing B/Jalan43 ...
# [116/720] Processing B/Jalan44 ...
# [117/720] Processing B/Jalan45 ...
# [118/720] Processing B/Jalan46 ...
# [119/720] Processing B/Jalan47 ...
# [120/720] Processing B/Jalan48 ...
# [121/720] Processing B/Jalan49 ...
# [122/720] Processing B/Jalan50 ...
# [123/720] Processing B/Jalan51 ...
# [124/720] Processing B/Jalan52 ...
# [125/720] Processing B/Jalan53 ...
# [126/720] Processing B/Jalan54 ...
# [127/720] Processing B/Jalan55 ...
# [128/720] Processing B/Jalan56 ...
# [129/720] Processing B/Jalan57 ...
# [130/720] Processing B/Jalan58 ...
# [131/720] Processing B/Jalan59 ...
# [132/720] Processing B/Jalan60 ...
# [133/720] Processing B/Jalan61 ...
# [134/720] Processing B/Jalan62 ...
# [135/720] Processing B/Jalan63 ...
# [136/720] Processing B/Jalan64 ...
# [137/720] Processing B/Jalan65 ...
# [138/720] Processing B/Jalan66 ...
# [139/720] Processing B/Jalan67 ...
# [140/720] Processing B/Jalan68 ...
# [141/720] Processing B/Jalan69 ...
# [142/720] Processing B/Jalan70 ...
# [143/720] Processing B/Jalan71 ...
# [144/720] Processing B/Jalan72 ...
# [145/720] Processing C/Jalan1 ...
# [146/720] Processing C/Jalan2 ...
# [147/720] Processing C/Jalan3 ...
# [148/720] Processing C/Jalan4 ...
# [149/720] Processing C/Jalan5 ...
# [150/720] Processing C/Jalan6 ...
# [151/720] Processing C/Jalan7 ...
# [152/720] Processing C/Jalan8 ...
# [153/720] Processing C/Jalan9 ...
# [154/720] Processing C/Jalan10 ...
# [155/720] Processing C/Jalan11 ...
# [156/720] Processing C/Jalan12 ...
# [157/720] Processing C/Jalan13 ...
# [158/720] Processing C/Jalan14 ...
# [159/720] Processing C/Jalan15 ...
# [160/720] Processing C/Jalan16 ...
# [161/720] Processing C/Jalan17 ...
# [162/720] Processing C/Jalan18 ...
# [163/720] Processing C/Jalan19 ...
# [164/720] Processing C/Jalan20 ...
# [165/720] Processing C/Jalan21 ...
# [166/720] Processing C/Jalan22 ...
# [167/720] Processing C/Jalan23 ...
# [168/720] Processing C/Jalan24 ...
# [169/720] Processing C/Jalan25 ...
# [170/720] Processing C/Jalan26 ...
# [171/720] Processing C/Jalan27 ...
# [172/720] Processing C/Jalan28 ...
# [173/720] Processing C/Jalan29 ...
# [174/720] Processing C/Jalan30 ...
# [175/720] Processing C/Jalan31 ...
# [176/720] Processing C/Jalan32 ...
# [177/720] Processing C/Jalan33 ...
# [178/720] Processing C/Jalan34 ...
# [179/720] Processing C/Jalan35 ...
# [180/720] Processing C/Jalan36 ...
# [181/720] Processing C/Jalan37 ...
# [182/720] Processing C/Jalan38 ...
# [183/720] Processing C/Jalan39 ...
# [184/720] Processing C/Jalan40 ...
# [185/720] Processing C/Jalan41 ...
# [186/720] Processing C/Jalan42 ...
# [187/720] Processing C/Jalan43 ...
# [188/720] Processing C/Jalan44 ...
# [189/720] Processing C/Jalan45 ...
# [190/720] Processing C/Jalan46 ...
# [191/720] Processing C/Jalan47 ...
# [192/720] Processing C/Jalan48 ...
# [193/720] Processing C/Jalan49 ...
# [194/720] Processing C/Jalan50 ...
# [195/720] Processing C/Jalan51 ...
# [196/720] Processing C/Jalan52 ...
# [197/720] Processing C/Jalan53 ...
# [198/720] Processing C/Jalan54 ...
# [199/720] Processing C/Jalan55 ...
# [200/720] Processing C/Jalan56 ...
# [201/720] Processing C/Jalan57 ...
# [202/720] Processing C/Jalan58 ...
# [203/720] Processing C/Jalan59 ...
# [204/720] Processing C/Jalan60 ...
# [205/720] Processing C/Jalan61 ...
# [206/720] Processing C/Jalan62 ...
# [207/720] Processing C/Jalan63 ...
# [208/720] Processing C/Jalan64 ...
# [209/720] Processing C/Jalan65 ...
# [210/720] Processing C/Jalan66 ...
# [211/720] Processing C/Jalan67 ...
# [212/720] Processing C/Jalan68 ...
# [213/720] Processing C/Jalan69 ...
# [214/720] Processing C/Jalan70 ...
# [215/720] Processing C/Jalan71 ...
# [216/720] Processing C/Jalan72 ...
# [217/720] Processing D/Jalan1 ...
# [218/720] Processing D/Jalan2 ...
# [219/720] Processing D/Jalan3 ...
# [220/720] Processing D/Jalan4 ...
# [221/720] Processing D/Jalan5 ...
# [222/720] Processing D/Jalan6 ...
# [223/720] Processing D/Jalan7 ...
# [224/720] Processing D/Jalan8 ...
# [225/720] Processing D/Jalan9 ...
# [226/720] Processing D/Jalan10 ...
# [227/720] Processing D/Jalan11 ...
# [228/720] Processing D/Jalan12 ...
# [229/720] Processing D/Jalan13 ...
# [230/720] Processing D/Jalan14 ...
# [231/720] Processing D/Jalan15 ...
# [232/720] Processing D/Jalan16 ...
# [233/720] Processing D/Jalan17 ...
# [234/720] Processing D/Jalan18 ...
# [235/720] Processing D/Jalan19 ...
# [236/720] Processing D/Jalan20 ...
# [237/720] Processing D/Jalan21 ...
# [238/720] Processing D/Jalan22 ...
# [239/720] Processing D/Jalan23 ...
# [240/720] Processing D/Jalan24 ...
# [241/720] Processing D/Jalan25 ...
# [242/720] Processing D/Jalan26 ...
# [243/720] Processing D/Jalan27 ...
# [244/720] Processing D/Jalan28 ...
# [245/720] Processing D/Jalan29 ...
# [246/720] Processing D/Jalan30 ...
# [247/720] Processing D/Jalan31 ...
# [248/720] Processing D/Jalan32 ...
# [249/720] Processing D/Jalan33 ...
# [250/720] Processing D/Jalan34 ...
# [251/720] Processing D/Jalan35 ...
# [252/720] Processing D/Jalan36 ...
# [253/720] Processing D/Jalan37 ...
# [254/720] Processing D/Jalan38 ...
# [255/720] Processing D/Jalan39 ...
# [256/720] Processing D/Jalan40 ...
# [257/720] Processing D/Jalan41 ...
# [258/720] Processing D/Jalan42 ...
# [259/720] Processing D/Jalan43 ...
# [260/720] Processing D/Jalan44 ...
# [261/720] Processing D/Jalan45 ...
# [262/720] Processing D/Jalan46 ...
# [263/720] Processing D/Jalan47 ...
# [264/720] Processing D/Jalan48 ...
# [265/720] Processing D/Jalan49 ...
# [266/720] Processing D/Jalan50 ...
# [267/720] Processing D/Jalan51 ...
# [268/720] Processing D/Jalan52 ...
# [269/720] Processing D/Jalan53 ...
# [270/720] Processing D/Jalan54 ...
# [271/720] Processing D/Jalan55 ...
# [272/720] Processing D/Jalan56 ...
# [273/720] Processing D/Jalan57 ...
# [274/720] Processing D/Jalan58 ...
# [275/720] Processing D/Jalan59 ...
# [276/720] Processing D/Jalan60 ...
# [277/720] Processing D/Jalan61 ...
# [278/720] Processing D/Jalan62 ...
# [279/720] Processing D/Jalan63 ...
# [280/720] Processing D/Jalan64 ...
# [281/720] Processing D/Jalan65 ...
# [282/720] Processing D/Jalan66 ...
# [283/720] Processing D/Jalan67 ...
# [284/720] Processing D/Jalan68 ...
# [285/720] Processing D/Jalan69 ...
# [286/720] Processing D/Jalan70 ...
# [287/720] Processing D/Jalan71 ...
# [288/720] Processing D/Jalan72 ...
# [289/720] Processing E/Jalan1 ...
# [290/720] Processing E/Jalan2 ...
# [291/720] Processing E/Jalan3 ...
# [292/720] Processing E/Jalan4 ...
# [293/720] Processing E/Jalan5 ...
# [294/720] Processing E/Jalan6 ...
# [295/720] Processing E/Jalan7 ...
# [296/720] Processing E/Jalan8 ...
# [297/720] Processing E/Jalan9 ...
# [298/720] Processing E/Jalan10 ...
# [299/720] Processing E/Jalan11 ...
# [300/720] Processing E/Jalan12 ...
# [301/720] Processing E/Jalan13 ...
# [302/720] Processing E/Jalan14 ...
# [303/720] Processing E/Jalan15 ...
# [304/720] Processing E/Jalan16 ...
# [305/720] Processing E/Jalan17 ...
# [306/720] Processing E/Jalan18 ...
# [307/720] Processing E/Jalan19 ...
# [308/720] Processing E/Jalan20 ...
# [309/720] Processing E/Jalan21 ...
# [310/720] Processing E/Jalan22 ...
# [311/720] Processing E/Jalan23 ...
# [312/720] Processing E/Jalan24 ...
# [313/720] Processing E/Jalan25 ...
# [314/720] Processing E/Jalan26 ...
# [315/720] Processing E/Jalan27 ...
# [316/720] Processing E/Jalan28 ...
# [317/720] Processing E/Jalan29 ...
# [318/720] Processing E/Jalan30 ...
# [319/720] Processing E/Jalan31 ...
# [320/720] Processing E/Jalan32 ...
# [321/720] Processing E/Jalan33 ...
# [322/720] Processing E/Jalan34 ...
# [323/720] Processing E/Jalan35 ...
# [324/720] Processing E/Jalan36 ...
# [325/720] Processing E/Jalan37 ...
# [326/720] Processing E/Jalan38 ...
# [327/720] Processing E/Jalan39 ...
# [328/720] Processing E/Jalan40 ...
# [329/720] Processing E/Jalan41 ...
# [330/720] Processing E/Jalan42 ...
# [331/720] Processing E/Jalan43 ...
# [332/720] Processing E/Jalan44 ...
# [333/720] Processing E/Jalan45 ...
# [334/720] Processing E/Jalan46 ...
# [335/720] Processing E/Jalan47 ...
# [336/720] Processing E/Jalan48 ...
# [337/720] Processing E/Jalan49 ...
# [338/720] Processing E/Jalan50 ...
# [339/720] Processing E/Jalan51 ...
# [340/720] Processing E/Jalan52 ...
# [341/720] Processing E/Jalan53 ...
# [342/720] Processing E/Jalan54 ...
# [343/720] Processing E/Jalan55 ...
# [344/720] Processing E/Jalan56 ...
# [345/720] Processing E/Jalan57 ...
# [346/720] Processing E/Jalan58 ...
# [347/720] Processing E/Jalan59 ...
# [348/720] Processing E/Jalan60 ...
# [349/720] Processing E/Jalan61 ...
# [350/720] Processing E/Jalan62 ...
# [351/720] Processing E/Jalan63 ...
# [352/720] Processing E/Jalan64 ...
# [353/720] Processing E/Jalan65 ...
# [354/720] Processing E/Jalan66 ...
# [355/720] Processing E/Jalan67 ...
# [356/720] Processing E/Jalan68 ...
# [357/720] Processing E/Jalan69 ...
# [358/720] Processing E/Jalan70 ...
# [359/720] Processing E/Jalan71 ...
# [360/720] Processing E/Jalan72 ...
# [361/720] Processing F/Jalan1 ...
# [362/720] Processing F/Jalan2 ...
# [363/720] Processing F/Jalan3 ...
# [364/720] Processing F/Jalan4 ...
# [365/720] Processing F/Jalan5 ...
# [366/720] Processing F/Jalan6 ...
# [367/720] Processing F/Jalan7 ...
# [368/720] Processing F/Jalan8 ...
# [369/720] Processing F/Jalan9 ...
# [370/720] Processing F/Jalan10 ...
# [371/720] Processing F/Jalan11 ...
# [372/720] Processing F/Jalan12 ...
# [373/720] Processing F/Jalan13 ...
# [374/720] Processing F/Jalan14 ...
# [375/720] Processing F/Jalan15 ...
# [376/720] Processing F/Jalan16 ...
# [377/720] Processing F/Jalan17 ...
# [378/720] Processing F/Jalan18 ...
# [379/720] Processing F/Jalan19 ...
# [380/720] Processing F/Jalan20 ...
# [381/720] Processing F/Jalan21 ...
# [382/720] Processing F/Jalan22 ...
# [383/720] Processing F/Jalan23 ...
# [384/720] Processing F/Jalan24 ...
# [385/720] Processing F/Jalan25 ...
# [386/720] Processing F/Jalan26 ...
# [387/720] Processing F/Jalan27 ...
# [388/720] Processing F/Jalan28 ...
# [389/720] Processing F/Jalan29 ...
# [390/720] Processing F/Jalan30 ...
# [391/720] Processing F/Jalan31 ...
# [392/720] Processing F/Jalan32 ...
# [393/720] Processing F/Jalan33 ...
# [394/720] Processing F/Jalan34 ...
# [395/720] Processing F/Jalan35 ...
# [396/720] Processing F/Jalan36 ...
# [397/720] Processing F/Jalan37 ...
# [398/720] Processing F/Jalan38 ...
# [399/720] Processing F/Jalan39 ...
# [400/720] Processing F/Jalan40 ...
# [401/720] Processing F/Jalan41 ...
# [402/720] Processing F/Jalan42 ...
# [403/720] Processing F/Jalan43 ...
# [404/720] Processing F/Jalan44 ...
# [405/720] Processing F/Jalan45 ...
# [406/720] Processing F/Jalan46 ...
# [407/720] Processing F/Jalan47 ...
# [408/720] Processing F/Jalan48 ...
# [409/720] Processing F/Jalan49 ...
# [410/720] Processing F/Jalan50 ...
# [411/720] Processing F/Jalan51 ...
# [412/720] Processing F/Jalan52 ...
# [413/720] Processing F/Jalan53 ...
# [414/720] Processing F/Jalan54 ...
# [415/720] Processing F/Jalan55 ...
# [416/720] Processing F/Jalan56 ...
# [417/720] Processing F/Jalan57 ...
# [418/720] Processing F/Jalan58 ...
# [419/720] Processing F/Jalan59 ...
# [420/720] Processing F/Jalan60 ...
# [421/720] Processing F/Jalan61 ...
# [422/720] Processing F/Jalan62 ...
# [423/720] Processing F/Jalan63 ...
# [424/720] Processing F/Jalan64 ...
# [425/720] Processing F/Jalan65 ...
# [426/720] Processing F/Jalan66 ...
# [427/720] Processing F/Jalan67 ...
# [428/720] Processing F/Jalan68 ...
# [429/720] Processing F/Jalan69 ...
# [430/720] Processing F/Jalan70 ...
# [431/720] Processing F/Jalan71 ...
# [432/720] Processing F/Jalan72 ...
# [433/720] Processing G/Jalan1 ...
# [434/720] Processing G/Jalan2 ...
# [435/720] Processing G/Jalan3 ...
# [436/720] Processing G/Jalan4 ...
# [437/720] Processing G/Jalan5 ...
# [438/720] Processing G/Jalan6 ...
# [439/720] Processing G/Jalan7 ...
# [440/720] Processing G/Jalan8 ...
# [441/720] Processing G/Jalan9 ...
# [442/720] Processing G/Jalan10 ...
# [443/720] Processing G/Jalan11 ...
# [444/720] Processing G/Jalan12 ...
# [445/720] Processing G/Jalan13 ...
# [446/720] Processing G/Jalan14 ...
# [447/720] Processing G/Jalan15 ...
# [448/720] Processing G/Jalan16 ...
# [449/720] Processing G/Jalan17 ...
# [450/720] Processing G/Jalan18 ...
# [451/720] Processing G/Jalan19 ...
# [452/720] Processing G/Jalan20 ...
# [453/720] Processing G/Jalan21 ...
# [454/720] Processing G/Jalan22 ...
# [455/720] Processing G/Jalan23 ...
# [456/720] Processing G/Jalan24 ...
# [457/720] Processing G/Jalan25 ...
# [458/720] Processing G/Jalan26 ...
# [459/720] Processing G/Jalan27 ...
# [460/720] Processing G/Jalan28 ...
# [461/720] Processing G/Jalan29 ...
# [462/720] Processing G/Jalan30 ...
# [463/720] Processing G/Jalan31 ...
# [464/720] Processing G/Jalan32 ...
# [465/720] Processing G/Jalan33 ...
# [466/720] Processing G/Jalan34 ...
# [467/720] Processing G/Jalan35 ...
# [468/720] Processing G/Jalan36 ...
# [469/720] Processing G/Jalan37 ...
# [470/720] Processing G/Jalan38 ...
# [471/720] Processing G/Jalan39 ...
# [472/720] Processing G/Jalan40 ...
# [473/720] Processing G/Jalan41 ...
# [474/720] Processing G/Jalan42 ...
# [475/720] Processing G/Jalan43 ...
# [476/720] Processing G/Jalan44 ...
# [477/720] Processing G/Jalan45 ...
# [478/720] Processing G/Jalan46 ...
# [479/720] Processing G/Jalan47 ...
# [480/720] Processing G/Jalan48 ...
# [481/720] Processing G/Jalan49 ...
# [482/720] Processing G/Jalan50 ...
# [483/720] Processing G/Jalan51 ...
# [484/720] Processing G/Jalan52 ...
# [485/720] Processing G/Jalan53 ...
# [486/720] Processing G/Jalan54 ...
# [487/720] Processing G/Jalan55 ...
# [488/720] Processing G/Jalan56 ...
# [489/720] Processing G/Jalan57 ...
# [490/720] Processing G/Jalan58 ...
# [491/720] Processing G/Jalan59 ...
# [492/720] Processing G/Jalan60 ...
# [493/720] Processing G/Jalan61 ...
# [494/720] Processing G/Jalan62 ...
# [495/720] Processing G/Jalan63 ...
# [496/720] Processing G/Jalan64 ...
# [497/720] Processing G/Jalan65 ...
# [498/720] Processing G/Jalan66 ...
# [499/720] Processing G/Jalan67 ...
# [500/720] Processing G/Jalan68 ...
# [501/720] Processing G/Jalan69 ...
# [502/720] Processing G/Jalan70 ...
# [503/720] Processing G/Jalan71 ...
# [504/720] Processing G/Jalan72 ...
# [505/720] Processing H/Jalan1 ...
# [506/720] Processing H/Jalan2 ...
# [507/720] Processing H/Jalan3 ...
# [508/720] Processing H/Jalan4 ...
# [509/720] Processing H/Jalan5 ...
# [510/720] Processing H/Jalan6 ...
# [511/720] Processing H/Jalan7 ...
# [512/720] Processing H/Jalan8 ...
# [513/720] Processing H/Jalan9 ...
# [514/720] Processing H/Jalan10 ...
# [515/720] Processing H/Jalan11 ...
# [516/720] Processing H/Jalan12 ...
# [517/720] Processing H/Jalan13 ...
# [518/720] Processing H/Jalan14 ...
# [519/720] Processing H/Jalan15 ...
# [520/720] Processing H/Jalan16 ...
# [521/720] Processing H/Jalan17 ...
# [522/720] Processing H/Jalan18 ...
# [523/720] Processing H/Jalan19 ...
# [524/720] Processing H/Jalan20 ...
# [525/720] Processing H/Jalan21 ...
# [526/720] Processing H/Jalan22 ...
# [527/720] Processing H/Jalan23 ...
# [528/720] Processing H/Jalan24 ...
# [529/720] Processing H/Jalan25 ...
# [530/720] Processing H/Jalan26 ...
# [531/720] Processing H/Jalan27 ...
# [532/720] Processing H/Jalan28 ...
# [533/720] Processing H/Jalan29 ...
# [534/720] Processing H/Jalan30 ...
# [535/720] Processing H/Jalan31 ...
# [536/720] Processing H/Jalan32 ...
# [537/720] Processing H/Jalan33 ...
# [538/720] Processing H/Jalan34 ...
# [539/720] Processing H/Jalan35 ...
# [540/720] Processing H/Jalan36 ...
# [541/720] Processing H/Jalan37 ...
# [542/720] Processing H/Jalan38 ...
# [543/720] Processing H/Jalan39 ...
# [544/720] Processing H/Jalan40 ...
# [545/720] Processing H/Jalan41 ...
# [546/720] Processing H/Jalan42 ...
# [547/720] Processing H/Jalan43 ...
# [548/720] Processing H/Jalan44 ...
# [549/720] Processing H/Jalan45 ...
# [550/720] Processing H/Jalan46 ...
# [551/720] Processing H/Jalan47 ...
# [552/720] Processing H/Jalan48 ...
# [553/720] Processing H/Jalan49 ...
# [554/720] Processing H/Jalan50 ...
# [555/720] Processing H/Jalan51 ...
# [556/720] Processing H/Jalan52 ...
# [557/720] Processing H/Jalan53 ...
# [558/720] Processing H/Jalan54 ...
# [559/720] Processing H/Jalan55 ...
# [560/720] Processing H/Jalan56 ...
# [561/720] Processing H/Jalan57 ...
# [562/720] Processing H/Jalan58 ...
# [563/720] Processing H/Jalan59 ...
# [564/720] Processing H/Jalan60 ...
# [565/720] Processing H/Jalan61 ...
# [566/720] Processing H/Jalan62 ...
# [567/720] Processing H/Jalan63 ...
# [568/720] Processing H/Jalan64 ...
# [569/720] Processing H/Jalan65 ...
# [570/720] Processing H/Jalan66 ...
# [571/720] Processing H/Jalan67 ...
# [572/720] Processing H/Jalan68 ...
# [573/720] Processing H/Jalan69 ...
# [574/720] Processing H/Jalan70 ...
# [575/720] Processing H/Jalan71 ...
# [576/720] Processing H/Jalan72 ...
# [577/720] Processing I/Jalan1 ...
# [578/720] Processing I/Jalan2 ...
# [579/720] Processing I/Jalan3 ...
# [580/720] Processing I/Jalan4 ...
# [581/720] Processing I/Jalan5 ...
# [582/720] Processing I/Jalan6 ...
# [583/720] Processing I/Jalan7 ...
# [584/720] Processing I/Jalan8 ...
# [585/720] Processing I/Jalan9 ...
# [586/720] Processing I/Jalan10 ...
# [587/720] Processing I/Jalan11 ...
# [588/720] Processing I/Jalan12 ...
# [589/720] Processing I/Jalan13 ...
# [590/720] Processing I/Jalan14 ...
# [591/720] Processing I/Jalan15 ...
# [592/720] Processing I/Jalan16 ...
# [593/720] Processing I/Jalan17 ...
# [594/720] Processing I/Jalan18 ...
# [595/720] Processing I/Jalan19 ...
# [596/720] Processing I/Jalan20 ...
# [597/720] Processing I/Jalan21 ...
# [598/720] Processing I/Jalan22 ...
# [599/720] Processing I/Jalan23 ...
# [600/720] Processing I/Jalan24 ...
# [601/720] Processing I/Jalan25 ...
# [602/720] Processing I/Jalan26 ...
# [603/720] Processing I/Jalan27 ...
# [604/720] Processing I/Jalan28 ...
# [605/720] Processing I/Jalan29 ...
# [606/720] Processing I/Jalan30 ...
# [607/720] Processing I/Jalan31 ...
# [608/720] Processing I/Jalan32 ...
# [609/720] Processing I/Jalan33 ...
# [610/720] Processing I/Jalan34 ...
# [611/720] Processing I/Jalan35 ...
# [612/720] Processing I/Jalan36 ...
# [613/720] Processing I/Jalan37 ...
# [614/720] Processing I/Jalan38 ...
# [615/720] Processing I/Jalan39 ...
# [616/720] Processing I/Jalan40 ...
# [617/720] Processing I/Jalan41 ...
# [618/720] Processing I/Jalan42 ...
# [619/720] Processing I/Jalan43 ...
# [620/720] Processing I/Jalan44 ...
# [621/720] Processing I/Jalan45 ...
# [622/720] Processing I/Jalan46 ...
# [623/720] Processing I/Jalan47 ...
# [624/720] Processing I/Jalan48 ...
# [625/720] Processing I/Jalan49 ...
# [626/720] Processing I/Jalan50 ...
# [627/720] Processing I/Jalan51 ...
# [628/720] Processing I/Jalan52 ...
# [629/720] Processing I/Jalan53 ...
# [630/720] Processing I/Jalan54 ...
# [631/720] Processing I/Jalan55 ...
# [632/720] Processing I/Jalan56 ...
# [633/720] Processing I/Jalan57 ...
# [634/720] Processing I/Jalan58 ...
# [635/720] Processing I/Jalan59 ...
# [636/720] Processing I/Jalan60 ...
# [637/720] Processing I/Jalan61 ...
# [638/720] Processing I/Jalan62 ...
# [639/720] Processing I/Jalan63 ...
# [640/720] Processing I/Jalan64 ...
# [641/720] Processing I/Jalan65 ...
# [642/720] Processing I/Jalan66 ...
# [643/720] Processing I/Jalan67 ...
# [644/720] Processing I/Jalan68 ...
# [645/720] Processing I/Jalan69 ...
# [646/720] Processing I/Jalan70 ...
# [647/720] Processing I/Jalan71 ...
# [648/720] Processing I/Jalan72 ...
# [649/720] Processing J/Jalan1 ...
# [650/720] Processing J/Jalan2 ...
# [651/720] Processing J/Jalan3 ...
# [652/720] Processing J/Jalan4 ...
# [653/720] Processing J/Jalan5 ...
# [654/720] Processing J/Jalan6 ...
# [655/720] Processing J/Jalan7 ...
# [656/720] Processing J/Jalan8 ...
# [657/720] Processing J/Jalan9 ...
# [658/720] Processing J/Jalan10 ...
# [659/720] Processing J/Jalan11 ...
# [660/720] Processing J/Jalan12 ...
# [661/720] Processing J/Jalan13 ...
# [662/720] Processing J/Jalan14 ...
# [663/720] Processing J/Jalan15 ...
# [664/720] Processing J/Jalan16 ...
# [665/720] Processing J/Jalan17 ...
# [666/720] Processing J/Jalan18 ...
# [667/720] Processing J/Jalan19 ...
# [668/720] Processing J/Jalan20 ...
# [669/720] Processing J/Jalan21 ...
# [670/720] Processing J/Jalan22 ...
# [671/720] Processing J/Jalan23 ...
# [672/720] Processing J/Jalan24 ...
# [673/720] Processing J/Jalan25 ...
# [674/720] Processing J/Jalan26 ...
# [675/720] Processing J/Jalan27 ...
# [676/720] Processing J/Jalan28 ...
# [677/720] Processing J/Jalan29 ...
# [678/720] Processing J/Jalan30 ...
# [679/720] Processing J/Jalan31 ...
# [680/720] Processing J/Jalan32 ...
# [681/720] Processing J/Jalan33 ...
# [682/720] Processing J/Jalan34 ...
# [683/720] Processing J/Jalan35 ...
# [684/720] Processing J/Jalan36 ...
# [685/720] Processing J/Jalan37 ...
# [686/720] Processing J/Jalan38 ...
# [687/720] Processing J/Jalan39 ...
# [688/720] Processing J/Jalan40 ...
# [689/720] Processing J/Jalan41 ...
# [690/720] Processing J/Jalan42 ...
# [691/720] Processing J/Jalan43 ...
# [692/720] Processing J/Jalan44 ...
# [693/720] Processing J/Jalan45 ...
# [694/720] Processing J/Jalan46 ...
# [695/720] Processing J/Jalan47 ...
# [696/720] Processing J/Jalan48 ...
# [697/720] Processing J/Jalan49 ...
# [698/720] Processing J/Jalan50 ...
# [699/720] Processing J/Jalan51 ...
# [700/720] Processing J/Jalan52 ...
# [701/720] Processing J/Jalan53 ...
# [702/720] Processing J/Jalan54 ...
# [703/720] Processing J/Jalan55 ...
# [704/720] Processing J/Jalan56 ...
# [705/720] Processing J/Jalan57 ...
# [706/720] Processing J/Jalan58 ...
# [707/720] Processing J/Jalan59 ...
# [708/720] Processing J/Jalan60 ...
# [709/720] Processing J/Jalan61 ...
# [710/720] Processing J/Jalan62 ...
# [711/720] Processing J/Jalan63 ...
# [712/720] Processing J/Jalan64 ...
# [713/720] Processing J/Jalan65 ...
# [714/720] Processing J/Jalan66 ...
# [715/720] Processing J/Jalan67 ...
# [716/720] Processing J/Jalan68 ...
# [717/720] Processing J/Jalan69 ...
# [718/720] Processing J/Jalan70 ...
# [719/720] Processing J/Jalan71 ...
# [720/720] Processing J/Jalan72 ...
#                              input_path  points_before  points_after  \
# 0   E:\0.TA_Teguh\dataset3\A\Jalan1.csv           3083          2711
# 1   E:\0.TA_Teguh\dataset3\A\Jalan2.csv           6582          5465
# 2   E:\0.TA_Teguh\dataset3\A\Jalan3.csv           6634          5895
# 3   E:\0.TA_Teguh\dataset3\A\Jalan4.csv           2278          1739
# 4   E:\0.TA_Teguh\dataset3\A\Jalan5.csv           2191          1305
# 5   E:\0.TA_Teguh\dataset3\A\Jalan6.csv           3492          2249
# 6   E:\0.TA_Teguh\dataset3\A\Jalan7.csv           4143          3316
# 7   E:\0.TA_Teguh\dataset3\A\Jalan8.csv           2944          2826
# 8   E:\0.TA_Teguh\dataset3\A\Jalan9.csv           2540          2055
# 9  E:\0.TA_Teguh\dataset3\A\Jalan10.csv           4160          3721
#
#    frames_total  frames_invalid  mean_conf  min_conf subject  trial
# 0           111              29   0.725858       0.0       A      1
# 1           113              28   0.730652       0.0       A      2
# 2           119              34   0.694553       0.0       A      3
# 3            96              36   0.617508       0.0       A      4
# 4           127              60   0.519023       0.0       A      5
# 5           127              56   0.547602       0.0       A      6
# 6           118              31   0.718223       0.0       A      7
# 7            74              19   0.725632       0.0       A      8
# 8           123              50   0.577551       0.0       A      9
# 9           131              44   0.647169       0.0       A     10

# %% [markdown]
# CELL 11 — Save Summaries (per subject + global)

# %%
def save_summaries(summaries_df: pd.DataFrame):
    # per subject summary (saved under each head _summary, same content)
    for head in ["Head 1", "Head 2", "Head 3"]:
        sum_dir = OUT_ROOT / head / "_summary"
        for s in SUBJECTS:
            sub = summaries_df[summaries_df["subject"] == s].copy()
            if len(sub) == 0:
                continue
            out = sum_dir / f"summary_{s}.csv"
            sub.to_csv(out, index=False)

    # global
    summaries_df.to_csv(OUT_ROOT / "_summary" / "global_summary.csv", index=False)

save_summaries(summaries_df)
print("Summaries saved to:", OUT_ROOT / "_summary")
# Out:
# Summaries saved to: E:\0.TA_Teguh\GMM Trial 1\_summary

# %% [markdown]
# VISUALIZATION CELLS

# %% [markdown]
# CELL 12 — Loader for Head outputs (one subject+trial)

# %%
def load_head_outputs(subject: str, trial: int):
    h1_path = OUT_ROOT / "Head 1" / subject / f"Jalan{trial}.csv"
    h2_path = OUT_ROOT / "Head 2" / subject / f"Jalan{trial}.csv"
    h3_path = OUT_ROOT / "Head 3" / subject / f"Jalan{trial}.jsonl"

    h1 = pd.read_csv(h1_path) if h1_path.exists() else pd.DataFrame()
    h2 = pd.read_csv(h2_path) if h2_path.exists() else pd.DataFrame()

    # jsonl
    h3_rows = []
    if h3_path.exists():
        with open(h3_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                h3_rows.append(json.loads(line))
    h3 = pd.DataFrame(h3_rows)

    # types
    if len(h1) and "frame" in h1.columns:
        h1["frame"] = h1["frame"].astype(int)
    if len(h2) and "frame" in h2.columns:
        h2["frame"] = h2["frame"].astype(int)
    if len(h3) and "frame" in h3.columns:
        h3["frame"] = h3["frame"].astype(int)

    return h1, h2, h3

# %% [markdown]
# CELL 13 — Helper: Covariance → 2D ellipse params

# %%
from matplotlib.patches import Ellipse

def cov_to_ellipse_params_2d(S2: np.ndarray, n_std: float = 2.0):
    S2 = np.asarray(S2, dtype=float)
    vals, vecs = np.linalg.eigh(S2)
    order = vals.argsort()[::-1]
    vals = vals[order]
    vecs = vecs[:, order]
    angle = np.degrees(np.arctan2(vecs[1,0], vecs[0,0]))
    width  = 2 * n_std * np.sqrt(max(vals[0], 0))
    height = 2 * n_std * np.sqrt(max(vals[1], 0))
    return width, height, angle

# %% [markdown]
# CELL 14 — Frame Viewer (A+B+C+D in one tidy view)

# %%
def visualize_frame(subject="A", trial=1, frame_id=None, n_std=2.0, max_points=1500):
    h1, h2, h3 = load_head_outputs(subject, trial)

    if len(h2) == 0:
        print("Head-2 empty / missing.")
        return

    frames_all = sorted(h2["frame"].unique().tolist())
    if frame_id is None:
        frame_id = frames_all[0]

    # Head-2 row
    row2 = h2[h2["frame"] == frame_id].iloc[0].to_dict()

    # Head-1 inliers
    f1 = h1[h1["frame"] == frame_id].copy() if len(h1) else pd.DataFrame()

    # For "raw vs inlier", we need raw points from original CSV
    raw_path = DATASET_ROOT / subject / f"Jalan{trial}.csv"
    df_raw = load_trial_csv(str(raw_path))
    fraw = df_raw[df_raw["frame"] == frame_id].copy()

    # downsample for plotting
    if len(fraw) > max_points:
        fraw = fraw.sample(max_points, random_state=SEED)
    if len(f1) > max_points:
        f1 = f1.sample(max_points, random_state=SEED)

    # Head-3 params for this frame (if exists)
    row3 = None
    if len(h3) and (h3["frame"] == frame_id).any():
        row3 = h3[h3["frame"] == frame_id].iloc[0].to_dict()

    fig = plt.figure(figsize=(15, 10))

    # --- A: XY scatter (inliers) + ellipse
    ax1 = fig.add_subplot(2, 2, 1)
    ax1.set_title("A) XY Inliers + Gaussian ellipse")
    ax1.set_xlabel("x")
    ax1.set_ylabel("y")
    ax1.set_xlim(ROI_X[0], ROI_X[1])
    ax1.set_ylim(ROI_Y[0], ROI_Y[1])

    if len(f1):
        if "d2" in f1.columns:
            ax1.scatter(f1["x"], f1["y"], s=8, c=f1["d2"])
        else:
            ax1.scatter(f1["x"], f1["y"], s=8)

    if row3 is not None:
        mu = np.array(row3["mu"], dtype=float)
        Sigma = np.array(row3["Sigma"], dtype=float)
        Sxy = Sigma[np.ix_([0,1],[0,1])]
        w, h, ang = cov_to_ellipse_params_2d(Sxy, n_std=n_std)
        ax1.add_patch(Ellipse((mu[0], mu[1]), width=w, height=h, angle=ang, fill=False))
        ax1.scatter([mu[0]], [mu[1]], s=80)

    # --- B: YZ scatter (inliers) + ellipse
    ax2 = fig.add_subplot(2, 2, 2)
    ax2.set_title("B) YZ Inliers + Gaussian ellipse")
    ax2.set_xlabel("y")
    ax2.set_ylabel("z")

    if len(f1):
        if "d2" in f1.columns:
            ax2.scatter(f1["y"], f1["z"], s=8, c=f1["d2"])
        else:
            ax2.scatter(f1["y"], f1["z"], s=8)

    if row3 is not None:
        mu = np.array(row3["mu"], dtype=float)
        Sigma = np.array(row3["Sigma"], dtype=float)
        Syz = Sigma[np.ix_([1,2],[1,2])]
        w, h, ang = cov_to_ellipse_params_2d(Syz, n_std=n_std)
        ax2.add_patch(Ellipse((mu[1], mu[2]), width=w, height=h, angle=ang, fill=False))
        ax2.scatter([mu[1]], [mu[2]], s=80)

    # --- C: raw vs inlier (XY)
    ax3 = fig.add_subplot(2, 2, 3)
    ax3.set_title("C) Raw vs Inlier (XY)")
    ax3.set_xlabel("x")
    ax3.set_ylabel("y")
    ax3.set_xlim(ROI_X[0], ROI_X[1])
    ax3.set_ylim(ROI_Y[0], ROI_Y[1])

    ax3.scatter(fraw["x"], fraw["y"], s=8, alpha=0.35, label="raw")
    if len(f1):
        ax3.scatter(f1["x"], f1["y"], s=10, label="inlier")
    ax3.legend()

    # --- D: histogram d² + threshold
    ax4 = fig.add_subplot(2, 2, 4)
    ax4.set_title("D) Mahalanobis d² distribution (ROI points)")

    # Recompute d² on ROI points for this frame (so we can always show D)
    df_roi = fraw[fraw["x"].between(*ROI_X) & fraw["y"].between(*ROI_Y)].copy()

    if len(df_roi) >= MIN_POINTS:
        X = df_roi[["x","y","z"]].values
        w = compute_snr_weight(df_roi["SNR"].values)
        mu0, S0 = fit_gaussian_k1(X, w)
        d2_all = mahalanobis_d2(X, mu0, S0)
        thr = chi2_threshold(CHI2_LEVEL, df=CHI2_DF)
        ax4.hist(d2_all, bins=30)
        ax4.axvline(thr, linestyle="--")
        ax4.set_xlabel("d²")
        ax4.set_ylabel("count")
    else:
        ax4.text(0.02, 0.5, "Frame invalid (N_roi < MIN_POINTS)", transform=ax4.transAxes)

    # Header info
    info = (
        f"{subject}/Jalan{trial} | frame={frame_id} | "
        f"N_raw={int(row2.get('N_raw',-1))} | N_roi={int(row2.get('N_roi',-1))} | "
        f"valid_minpts={int(row2.get('valid_minpts',0))} | "
        f"N_inlier={int(row2.get('N_inlier',0))} | conf={float(row2.get('conf',0.0)):.3f}"
    )
    fig.suptitle(info, y=0.98)
    plt.tight_layout()
    plt.show()


if HAS_WIDGETS:
    def frame_slider(subject="A", trial=1, n_std=2.0):
        _, h2, _ = load_head_outputs(subject, trial)
        if len(h2) == 0:
            print("Head-2 missing/empty for this trial.")
            return

        frames = sorted(h2["frame"].unique().tolist())
        slider = widgets.IntSlider(value=frames[0], min=min(frames), max=max(frames), step=1, description="frame")
        out = widgets.Output()

        def _update(change):
            with out:
                out.clear_output(wait=True)
                visualize_frame(subject, trial, frame_id=change["new"], n_std=n_std)

        slider.observe(_update, names="value")
        display(slider, out)
        _update({"new": slider.value})

    # Example:
    # frame_slider("A", 1, n_std=2.0)
else:
    print("ipywidgets not available. Use visualize_frame(subject, trial, frame_id=...)")

# %%
frame_slider("J", 23, n_std=2.0)
# Out:
# IntSlider(value=1, description='frame', max=543, min=1)
# Output()

# %% [markdown]
# CELL 15 — Trial Quality Plot (N_inlier, conf over time)

# %%
def plot_trial_quality(subject="A", trial=1):
    _, h2, _ = load_head_outputs(subject, trial)
    if len(h2) == 0:
        print("Head-2 missing/empty.")
        return

    fig = plt.figure(figsize=(12, 6))

    ax1 = fig.add_subplot(2, 1, 1)
    ax1.set_title(f"{subject}/Jalan{trial} - Frame Quality")
    ax1.plot(h2["frame"], h2["N_inlier"])
    ax1.set_ylabel("N_inlier")

    ax2 = fig.add_subplot(2, 1, 2)
    ax2.plot(h2["frame"], h2["conf"])
    ax2.set_ylabel("conf (0-1)")
    ax2.set_xlabel("frame")

    plt.tight_layout()
    plt.show()

# Example:
# plot_trial_quality("A", 1)

# %%
plot_trial_quality("J", 23)
