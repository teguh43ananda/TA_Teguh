# %% [markdown]
# Cell 1 — Imports & Config

# %%
from pathlib import Path
import numpy as np
import pandas as pd
from typing import Dict, Tuple, List

# Paths
DATASET_ROOT = Path(r"E:\0.TA_Teguh\GMM Trial 2")
HEAD1_DIR = DATASET_ROOT / "Head 1"
OUT_ROOT = Path(r"E:\0.TA_Teguh\Sampling\FPS")     

# Subjects A..J
SUBJECTS = list("ABCDEFGHIJ")

# Candidates
N_TARGETS = [48, 56, 64]
RUN_N_TARGETS = [64]  # start with one; change to [48,56,64] after sanity check

# Must-match Head-1 columns
COLS_EXPECTED = ["timestamp","frame","x","y","z","doppler","SNR","w_snr","d2","is_inlier"]
COLS_OUT = COLS_EXPECTED[:]  # keep order

# Sampling settings
START_MODE = "centroid_nearest"
EPS_W = 1e-12

# Read/write config
CSV_READ_KWARGS = dict(dtype={
    "timestamp": str,
    "frame": np.int32,
    "x": np.float32,
    "y": np.float32,
    "z": np.float32,
    "doppler": np.float32,
    "SNR": np.float32,
    "w_snr": np.float32,
    "d2": np.float32,
    "is_inlier": np.int8,
})
CSV_WRITE_KWARGS = dict(index=False)

print("OK | HEAD1_DIR:", HEAD1_DIR)
print("OK | OUT_ROOT :", OUT_ROOT)
print("RUN_N_TARGETS :", RUN_N_TARGETS)
# Out:
# OK | HEAD1_DIR: E:\0.TA_Teguh\GMM Trial 2\Head 1
# OK | OUT_ROOT : E:\0.TA_Teguh\Sampling\FPS
# RUN_N_TARGETS : [64]

# %% [markdown]
# Cell 2 — Deterministic seed helper

# %%
import hashlib

def stable_seed(subject: str, file_name: str, frame: int, n_target: int) -> int:
    """
    Stable seed across runs/machines for weighted resampling.
    """
    s = f"{subject}|{file_name}|{frame}|{n_target}"
    h = hashlib.sha256(s.encode("utf-8")).hexdigest()
    # Take first 8 hex chars -> 32-bit
    return int(h[:8], 16)

# %% [markdown]
# Cell 3 — IO helpers (list files, read head1)

# %%
def list_jalan_csvs(subject_dir: Path) -> List[Path]:
    if not subject_dir.exists():
        return []
    return sorted(subject_dir.glob("Jalan*.csv"))

def read_head1_csv(path: Path) -> pd.DataFrame:
    df = pd.read_csv(path, **CSV_READ_KWARGS)
    missing = [c for c in COLS_EXPECTED if c not in df.columns]
    if missing:
        raise ValueError(f"Missing columns in {path.name}: {missing}")
    # Ensure correct column order (and drop extras if any)
    df = df[COLS_EXPECTED].copy()
    return df

# %% [markdown]
# Cell 4 — Frame extraction & sanitization

# %%
def get_frame_df(df: pd.DataFrame, frame_id: int) -> pd.DataFrame:
    f = df[df["frame"] == frame_id].copy()
    if f.empty:
        return f
    # Drop NaN/Inf just in case (should be clean already)
    num_cols = ["x","y","z","doppler","SNR","w_snr","d2"]
    for c in num_cols:
        v = f[c].to_numpy()
        ok = np.isfinite(v)
        if not ok.all():
            f = f.loc[ok].copy()
    return f

def xyz_array(frame_df: pd.DataFrame) -> np.ndarray:
    return frame_df[["x","y","z"]].to_numpy(dtype=np.float32, copy=False)

# %% [markdown]
# Cell 5 — FPS core (downsample only)

# %%
def fps_indices(xyz: np.ndarray, n_select: int, start_idx: int) -> np.ndarray:
    """
    xyz: [M,3], n_select <= M
    Returns indices length n_select using farthest point sampling.
    """
    M = xyz.shape[0]
    if n_select >= M:
        return np.arange(M, dtype=np.int32)

    selected = np.empty(n_select, dtype=np.int32)
    selected[0] = start_idx

    # min squared distance to the selected set for each point
    diff0 = xyz - xyz[start_idx]
    min_dist2 = np.einsum("ij,ij->i", diff0, diff0).astype(np.float32)

    for i in range(1, n_select):
        nxt = int(np.argmax(min_dist2))
        selected[i] = nxt
        diff = xyz - xyz[nxt]
        dist2 = np.einsum("ij,ij->i", diff, diff).astype(np.float32)
        min_dist2 = np.minimum(min_dist2, dist2)

    return selected

# %% [markdown]
# Cell 6 — Start point selection (centroid-nearest)

# %%
def start_index_centroid_nearest(xyz: np.ndarray) -> int:
    c = xyz.mean(axis=0)
    diff = xyz - c
    dist2 = np.einsum("ij,ij->i", diff, diff)
    return int(np.argmin(dist2))

# %% [markdown]
# Cell 7 — Shared upsample (weighted replacement by w_snr)

# %%
def weighted_resample_indices(w: np.ndarray, k: int, seed: int) -> np.ndarray:
    """
    Sample k indices with replacement using probability ∝ w.
    """
    if k <= 0:
        return np.empty((0,), dtype=np.int32)

    w = np.asarray(w, dtype=np.float64)
    w = np.clip(w, 0.0, None)
    s = w.sum()
    if not np.isfinite(s) or s <= EPS_W:
        # fallback to uniform if weights degenerate
        p = None
    else:
        p = w / s

    rng = np.random.default_rng(seed)
    return rng.choice(len(w), size=k, replace=True, p=p).astype(np.int32)

# %% [markdown]
# Cell 8 — Per-frame sampler (FPS + shared upsample)

# %%
def sample_frame_fps(frame_df: pd.DataFrame, n_target: int, subject: str, file_name: str) -> Tuple[pd.DataFrame, Dict]:
    """
    Returns sampled_frame_df with SAME columns as input (COLS_OUT).
    """
    M = len(frame_df)
    meta = {"M": M, "N": n_target, "action": None, "n_drop": 0, "n_fill": 0}

    if M == 0:
        meta["action"] = "empty"
        return frame_df[COLS_OUT].copy(), meta

    if M == n_target:
        meta["action"] = "equal"
        return frame_df[COLS_OUT].copy(), meta

    if M > n_target:
        xyz = xyz_array(frame_df)
        start_idx = start_index_centroid_nearest(xyz)
        idx = fps_indices(xyz, n_target, start_idx)
        out = frame_df.iloc[idx].copy()
        meta["action"] = "downsample"
        meta["n_drop"] = M - n_target
        return out[COLS_OUT], meta

    # M < n_target → upsample with replacement using w_snr
    k = n_target - M
    seed = stable_seed(subject, file_name, int(frame_df["frame"].iloc[0]), n_target)
    add_idx = weighted_resample_indices(frame_df["w_snr"].to_numpy(), k=k, seed=seed)
    add = frame_df.iloc[add_idx].copy()
    out = pd.concat([frame_df, add], axis=0, ignore_index=True)
    meta["action"] = "upsample"
    meta["n_fill"] = k
    return out[COLS_OUT], meta

# %% [markdown]
# Cell 9 — Per-file processing (loop frames, save CSV)

# %%
def process_one_file(head1_path: Path, subject: str, n_target: int) -> Dict:
    """
    Process one Jalan*.csv from Head-1 and write sampled output CSV.
    """
    df = read_head1_csv(head1_path)

    file_name = head1_path.name
    out_dir = OUT_ROOT / f"N{n_target}" / subject
    out_dir.mkdir(parents=True, exist_ok=True)
    out_path = out_dir / file_name

    frames = df["frame"].unique()
    frames.sort()

    out_chunks = []
    stats = {"file": file_name, "subject": subject, "N": n_target,
             "frames": int(len(frames)), "down": 0, "up": 0, "eq": 0, "empty": 0,
             "total_drop": 0, "total_fill": 0}

    for fr in frames:
        fdf = get_frame_df(df, int(fr))
        sampled, meta = sample_frame_fps(fdf, n_target=n_target, subject=subject, file_name=file_name)

        out_chunks.append(sampled)

        act = meta["action"]
        if act == "downsample":
            stats["down"] += 1
            stats["total_drop"] += int(meta["n_drop"])
        elif act == "upsample":
            stats["up"] += 1
            stats["total_fill"] += int(meta["n_fill"])
        elif act == "equal":
            stats["eq"] += 1
        else:
            stats["empty"] += 1

    out_df = pd.concat(out_chunks, axis=0, ignore_index=True)
    out_df.to_csv(out_path, **CSV_WRITE_KWARGS)
    return stats

# %% [markdown]
# Cell 10 — Run all (batch: subject → file), plus summary CSV

# %%
all_stats = []

for n_target in RUN_N_TARGETS:
    for subject in SUBJECTS:
        subj_dir = HEAD1_DIR / subject
        files = list_jalan_csvs(subj_dir)
        if not files:
            print(f"[WARN] No files for subject {subject} in {subj_dir}")
            continue

        print(f"\n=== N={n_target} | Subject {subject} | files={len(files)} ===")
        for p in files:
            st = process_one_file(p, subject=subject, n_target=n_target)
            all_stats.append(st)
            print(f"  {st['file']}: frames={st['frames']}, down={st['down']}, up={st['up']}, eq={st['eq']}, "
                  f"fill={st['total_fill']}, drop={st['total_drop']}")

# Save summary
summary_df = pd.DataFrame(all_stats)
summary_path = OUT_ROOT / "fps_sampling_summary.csv"
summary_df.to_csv(summary_path, index=False)
print("\nSaved summary:", summary_path)
summary_df.head()
# Out:
# === N=64 | Subject A | files=72 ===
#   Jalan1.csv: frames=82, down=7, up=74, eq=1, fill=2662, drop=100
#   Jalan10.csv: frames=87, down=20, up=66, eq=1, fill=2257, drop=375
#   Jalan11.csv: frames=87, down=33, up=54, eq=0, fill=2002, drop=1044
#   Jalan12.csv: frames=98, down=34, up=62, eq=2, fill=2085, drop=615
#   Jalan13.csv: frames=103, down=28, up=74, eq=1, fill=2137, drop=568
#   Jalan14.csv: frames=81, down=3, up=78, eq=0, fill=2965, drop=31
#   Jalan15.csv: frames=239, down=40, up=196, eq=3, fill=6940, drop=603
#   Jalan16.csv: frames=229, down=45, up=181, eq=3, fill=6298, drop=779
#   Jalan17.csv: frames=194, down=67, up=126, eq=1, fill=3688, drop=1635
#   Jalan18.csv: frames=166, down=91, up=71, eq=4, fill=1670, drop=3188
#   Jalan19.csv: frames=222, down=53, up=169, eq=0, fill=5668, drop=1310
#   Jalan2.csv: frames=85, down=44, up=40, eq=1, fill=980, drop=973
#   Jalan20.csv: frames=174, down=58, up=115, eq=1, fill=3624, drop=889
#   Jalan21.csv: frames=149, down=50, up=98, eq=1, fill=3223, drop=1511
#   Jalan22.csv: frames=125, down=68, up=57, eq=0, fill=1330, drop=2200
#   Jalan23.csv: frames=424, down=41, up=376, eq=7, fill=14042, drop=586
#   Jalan24.csv: frames=433, down=131, up=292, eq=10, fill=8717, drop=2434
#   Jalan25.csv: frames=74, down=3, up=71, eq=0, fill=2371, drop=27
#   Jalan26.csv: frames=76, down=39, up=35, eq=2, fill=810, drop=809
#   Jalan27.csv: frames=71, down=37, up=32, eq=2, fill=919, drop=1160
#   Jalan28.csv: frames=52, down=2, up=50, eq=0, fill=1939, drop=12
#   Jalan29.csv: frames=48, down=15, up=33, eq=0, fill=1071, drop=399
#   Jalan3.csv: frames=85, down=44, up=41, eq=0, fill=945, drop=1364
#   Jalan30.csv: frames=66, down=17, up=49, eq=0, fill=1581, drop=252
#   Jalan31.csv: frames=64, down=1, up=63, eq=0, fill=2219, drop=16
#   Jalan32.csv: frames=53, down=1, up=52, eq=0, fill=2325, drop=3
#   Jalan33.csv: frames=66, down=4, up=62, eq=0, fill=2143, drop=38
#   Jalan34.csv: frames=63, down=12, up=50, eq=1, fill=1606, drop=151
#   Jalan35.csv: frames=61, down=24, up=37, eq=0, fill=1549, drop=501
#   Jalan36.csv: frames=71, down=22, up=47, eq=2, fill=1724, drop=436
#   Jalan37.csv: frames=77, down=14, up=62, eq=1, fill=2289, drop=253
#   Jalan38.csv: frames=60, down=12, up=47, eq=1, fill=1631, drop=109
#   Jalan39.csv: frames=182, down=39, up=143, eq=0, fill=5178, drop=538
#   Jalan4.csv: frames=60, down=5, up=55, eq=0, fill=2150, drop=42
#   Jalan40.csv: frames=178, down=57, up=119, eq=2, fill=4140, drop=1484
#   Jalan41.csv: frames=162, down=61, up=99, eq=2, fill=3094, drop=1770
#   Jalan42.csv: frames=112, down=50, up=60, eq=2, fill=1872, drop=1431
#   Jalan43.csv: frames=161, down=39, up=119, eq=3, fill=4415, drop=1038
#   Jalan44.csv: frames=135, down=51, up=83, eq=1, fill=2991, drop=1054
#   Jalan45.csv: frames=123, down=52, up=70, eq=1, fill=2468, drop=1641
#   Jalan46.csv: frames=96, down=54, up=41, eq=1, fill=981, drop=1913
#   Jalan47.csv: frames=295, down=44, up=249, eq=2, fill=8962, drop=845
#   Jalan48.csv: frames=312, down=96, up=211, eq=5, fill=6962, drop=2265
#   Jalan49.csv: frames=96, down=7, up=89, eq=0, fill=2987, drop=125
#   Jalan5.csv: frames=67, down=0, up=67, eq=0, fill=2998, drop=0
#   Jalan50.csv: frames=114, down=65, up=49, eq=0, fill=1093, drop=1542
#   Jalan51.csv: frames=117, down=55, up=59, eq=3, fill=1596, drop=1020
#   Jalan52.csv: frames=76, down=5, up=71, eq=0, fill=2762, drop=20
#   Jalan53.csv: frames=73, down=24, up=49, eq=0, fill=1570, drop=378
#   Jalan54.csv: frames=105, down=26, up=78, eq=1, fill=2547, drop=406
#   Jalan55.csv: frames=85, down=6, up=77, eq=2, fill=2905, drop=59
#   Jalan56.csv: frames=76, down=0, up=76, eq=0, fill=3506, drop=0
#   Jalan57.csv: frames=90, down=7, up=82, eq=1, fill=2865, drop=76
#   Jalan58.csv: frames=119, down=28, up=91, eq=0, fill=2868, drop=587
#   Jalan59.csv: frames=117, down=48, up=69, eq=0, fill=2410, drop=1200
#   Jalan6.csv: frames=71, down=5, up=65, eq=1, fill=2372, drop=60
#   Jalan60.csv: frames=118, down=4, up=114, eq=0, fill=4706, drop=59
#   Jalan61.csv: frames=141, down=23, up=118, eq=0, fill=3719, drop=372
#   Jalan62.csv: frames=132, down=50, up=81, eq=1, fill=2227, drop=1206
#   Jalan63.csv: frames=332, down=58, up=270, eq=4, fill=9208, drop=1028
#   Jalan64.csv: frames=310, down=68, up=242, eq=0, fill=8571, drop=1319
#   Jalan65.csv: frames=207, down=73, up=133, eq=1, fill=3927, drop=1601
#   Jalan66.csv: frames=179, down=97, up=81, eq=1, fill=2280, drop=3048
#   Jalan67.csv: frames=273, down=64, up=205, eq=4, fill=7331, drop=1728
#   Jalan68.csv: frames=202, down=81, up=120, eq=1, fill=3976, drop=2015
#   Jalan69.csv: frames=158, down=69, up=85, eq=4, fill=2220, drop=2145
#   Jalan7.csv: frames=87, down=13, up=71, eq=3, fill=2498, drop=230
#   Jalan70.csv: frames=133, down=69, up=63, eq=1, fill=1911, drop=2292
#   Jalan71.csv: frames=534, down=56, up=476, eq=2, fill=17264, drop=680
#   Jalan72.csv: frames=538, down=158, up=379, eq=1, fill=12500, drop=3332
#   Jalan8.csv: frames=55, down=16, up=37, eq=2, fill=1077, drop=369
#   Jalan9.csv: frames=73, down=4, up=68, eq=1, fill=2648, drop=17
#
# === N=64 | Subject B | files=72 ===
#   Jalan1.csv: frames=94, down=13, up=79, eq=2, fill=2600, drop=133
#   Jalan10.csv: frames=96, down=29, up=65, eq=2, fill=2410, drop=573
#   Jalan11.csv: frames=98, down=16, up=81, eq=1, fill=2580, drop=131
#   Jalan12.csv: frames=106, down=32, up=73, eq=1, fill=2663, drop=798
#   Jalan13.csv: frames=112, down=48, up=63, eq=1, fill=1784, drop=875
#   Jalan14.csv: frames=105, down=20, up=83, eq=2, fill=2949, drop=403
#   Jalan15.csv: frames=296, down=43, up=251, eq=2, fill=9797, drop=699
#   Jalan16.csv: frames=264, down=64, up=197, eq=3, fill=6921, drop=1319
#   Jalan17.csv: frames=229, down=68, up=159, eq=2, fill=4319, drop=1342
#   Jalan18.csv: frames=191, down=104, up=83, eq=4, fill=1904, drop=2956
#   Jalan19.csv: frames=276, down=41, up=233, eq=2, fill=9574, drop=742
#   Jalan2.csv: frames=111, down=59, up=48, eq=4, fill=1211, drop=1770
#   Jalan20.csv: frames=248, down=45, up=202, eq=1, fill=7460, drop=593
#   Jalan21.csv: frames=208, down=94, up=113, eq=1, fill=2950, drop=2226
#   Jalan22.csv: frames=184, down=104, up=79, eq=1, fill=1843, drop=3034
#   Jalan23.csv: frames=471, down=79, up=379, eq=13, fill=12381, drop=1294
#   Jalan24.csv: frames=475, down=110, up=362, eq=3, fill=13206, drop=4225
#   Jalan25.csv: frames=77, down=7, up=70, eq=0, fill=2078, drop=98
#   Jalan26.csv: frames=84, down=41, up=42, eq=1, fill=1106, drop=1388
#   Jalan27.csv: frames=80, down=46, up=34, eq=0, fill=971, drop=1328
#   Jalan28.csv: frames=59, down=1, up=58, eq=0, fill=3130, drop=1
#   Jalan29.csv: frames=70, down=1, up=69, eq=0, fill=2918, drop=13
#   Jalan3.csv: frames=98, down=62, up=36, eq=0, fill=917, drop=1582
#   Jalan30.csv: frames=73, down=10, up=63, eq=0, fill=2459, drop=81
#   Jalan31.csv: frames=77, down=13, up=63, eq=1, fill=1810, drop=189
#   Jalan32.csv: frames=66, down=21, up=45, eq=0, fill=1613, drop=391
#   Jalan33.csv: frames=73, down=22, up=50, eq=1, fill=2004, drop=638
#   Jalan34.csv: frames=71, down=21, up=49, eq=1, fill=1866, drop=277
#   Jalan35.csv: frames=71, down=6, up=63, eq=2, fill=1954, drop=60
#   Jalan36.csv: frames=74, down=10, up=64, eq=0, fill=2156, drop=143
#   Jalan37.csv: frames=85, down=25, up=60, eq=0, fill=2073, drop=368
#   Jalan38.csv: frames=77, down=16, up=60, eq=1, fill=2185, drop=253
#   Jalan39.csv: frames=237, down=30, up=202, eq=5, fill=7703, drop=465
#   Jalan4.csv: frames=67, down=0, up=67, eq=0, fill=3492, drop=0
#   Jalan40.csv: frames=217, down=40, up=176, eq=1, fill=6795, drop=910
#   Jalan41.csv: frames=192, down=61, up=131, eq=0, fill=3872, drop=1427
#   Jalan42.csv: frames=146, down=68, up=75, eq=3, fill=1845, drop=1770
#   Jalan43.csv: frames=218, down=24, up=191, eq=3, fill=8124, drop=388
#   Jalan44.csv: frames=202, down=50, up=152, eq=0, fill=5052, drop=1222
#   Jalan45.csv: frames=185, down=71, up=109, eq=5, fill=3110, drop=1447
#   Jalan46.csv: frames=155, down=115, up=38, eq=2, fill=687, drop=4076
#   Jalan47.csv: frames=370, down=80, up=289, eq=1, fill=10034, drop=1382
#   Jalan48.csv: frames=402, down=101, up=298, eq=3, fill=10287, drop=3210
#   Jalan49.csv: frames=86, down=1, up=85, eq=0, fill=3274, drop=4
#   Jalan5.csv: frames=78, down=1, up=77, eq=0, fill=3346, drop=2
#   Jalan50.csv: frames=116, down=58, up=58, eq=0, fill=1479, drop=1573
#   Jalan51.csv: frames=116, down=54, up=59, eq=3, fill=1595, drop=1115
#   Jalan52.csv: frames=85, down=0, up=85, eq=0, fill=4361, drop=0
#   Jalan53.csv: frames=72, down=0, up=72, eq=0, fill=3518, drop=0
#   Jalan54.csv: frames=106, down=1, up=103, eq=2, fill=3797, drop=27
#   Jalan55.csv: frames=110, down=29, up=78, eq=3, fill=2757, drop=484
#   Jalan56.csv: frames=95, down=30, up=64, eq=1, fill=2216, drop=569
#   Jalan57.csv: frames=104, down=38, up=66, eq=0, fill=2155, drop=1397
#   Jalan58.csv: frames=116, down=30, up=86, eq=0, fill=3082, drop=451
#   Jalan59.csv: frames=106, down=13, up=92, eq=1, fill=2801, drop=145
#   Jalan6.csv: frames=95, down=1, up=93, eq=1, fill=3441, drop=13
#   Jalan60.csv: frames=105, down=15, up=89, eq=1, fill=3185, drop=162
#   Jalan61.csv: frames=125, down=27, up=97, eq=1, fill=3228, drop=528
#   Jalan62.csv: frames=120, down=22, up=94, eq=4, fill=2971, drop=587
#   Jalan63.csv: frames=337, down=36, up=298, eq=3, fill=11345, drop=497
#   Jalan64.csv: frames=304, down=50, up=253, eq=1, fill=8878, drop=999
#   Jalan65.csv: frames=244, down=79, up=162, eq=3, fill=4733, drop=1551
#   Jalan66.csv: frames=208, down=86, up=121, eq=1, fill=3588, drop=2259
#   Jalan67.csv: frames=353, down=49, up=303, eq=1, fill=12528, drop=863
#   Jalan68.csv: frames=276, down=68, up=206, eq=2, fill=7584, drop=1121
#   Jalan69.csv: frames=259, down=76, up=181, eq=2, fill=5431, drop=1547
#   Jalan7.csv: frames=93, down=32, up=61, eq=0, fill=1832, drop=513
#   Jalan70.csv: frames=216, down=101, up=115, eq=0, fill=2848, drop=2107
#   Jalan71.csv: frames=520, down=76, up=440, eq=4, fill=15459, drop=1393
#   Jalan72.csv: frames=515, down=105, up=407, eq=3, fill=14782, drop=3373
#   Jalan8.csv: frames=78, down=12, up=64, eq=2, fill=2057, drop=162
#   Jalan9.csv: frames=96, down=29, up=67, eq=0, fill=2259, drop=849
#
# === N=64 | Subject C | files=72 ===
#   Jalan1.csv: frames=130, down=14, up=115, eq=1, fill=4026, drop=140
#   Jalan10.csv: frames=114, down=29, up=85, eq=0, fill=3042, drop=549
#   Jalan11.csv: frames=110, down=40, up=70, eq=0, fill=2628, drop=830
#   Jalan12.csv: frames=124, down=26, up=98, eq=0, fill=3320, drop=565
#   Jalan13.csv: frames=139, down=33, up=104, eq=2, fill=3111, drop=500
#   Jalan14.csv: frames=119, down=14, up=105, eq=0, fill=3834, drop=243
#   Jalan15.csv: frames=361, down=31, up=327, eq=3, fill=11799, drop=468
#   Jalan16.csv: frames=333, down=79, up=254, eq=0, fill=8748, drop=1313
#   Jalan17.csv: frames=305, down=77, up=225, eq=3, fill=6662, drop=1294
#   Jalan18.csv: frames=224, down=75, up=147, eq=2, fill=4319, drop=1699
#   Jalan19.csv: frames=326, down=47, up=275, eq=4, fill=9723, drop=657
#   Jalan2.csv: frames=128, down=47, up=77, eq=4, fill=2139, drop=957
#   Jalan20.csv: frames=302, down=32, up=269, eq=1, fill=9340, drop=886
#   Jalan21.csv: frames=261, down=92, up=167, eq=2, fill=4950, drop=1908
#   Jalan22.csv: frames=224, down=98, up=124, eq=2, fill=3281, drop=2406
#   Jalan23.csv: frames=519, down=46, up=468, eq=5, fill=17541, drop=682
#   Jalan24.csv: frames=576, down=105, up=469, eq=2, fill=15946, drop=2740
#   Jalan25.csv: frames=90, down=9, up=80, eq=1, fill=2667, drop=124
#   Jalan26.csv: frames=127, down=49, up=76, eq=2, fill=2104, drop=1090
#   Jalan27.csv: frames=94, down=37, up=55, eq=2, fill=1560, drop=982
#   Jalan28.csv: frames=64, down=0, up=64, eq=0, fill=3361, drop=0
#   Jalan29.csv: frames=60, down=0, up=60, eq=0, fill=2878, drop=0
#   Jalan3.csv: frames=147, down=69, up=78, eq=0, fill=1837, drop=1857
#   Jalan30.csv: frames=77, down=0, up=76, eq=1, fill=3315, drop=0
#   Jalan31.csv: frames=95, down=6, up=89, eq=0, fill=3435, drop=25
#   Jalan32.csv: frames=80, down=31, up=48, eq=1, fill=1540, drop=912
#   Jalan33.csv: frames=85, down=28, up=57, eq=0, fill=2114, drop=675
#   Jalan34.csv: frames=88, down=17, up=71, eq=0, fill=2773, drop=288
#   Jalan35.csv: frames=88, down=6, up=82, eq=0, fill=2991, drop=46
#   Jalan36.csv: frames=102, down=29, up=73, eq=0, fill=2736, drop=862
#   Jalan37.csv: frames=94, down=16, up=77, eq=1, fill=2099, drop=253
#   Jalan38.csv: frames=78, down=9, up=69, eq=0, fill=2652, drop=86
#   Jalan39.csv: frames=241, down=25, up=215, eq=1, fill=7965, drop=391
#   Jalan4.csv: frames=80, down=0, up=79, eq=1, fill=3964, drop=0
#   Jalan40.csv: frames=247, down=61, up=183, eq=3, fill=6491, drop=1007
#   Jalan41.csv: frames=200, down=46, up=152, eq=2, fill=4321, drop=800
#   Jalan42.csv: frames=144, down=57, up=84, eq=3, fill=2160, drop=993
#   Jalan43.csv: frames=237, down=44, up=192, eq=1, fill=7018, drop=855
#   Jalan44.csv: frames=251, down=60, up=186, eq=5, fill=5657, drop=1124
#   Jalan45.csv: frames=206, down=52, up=152, eq=2, fill=4755, drop=995
#   Jalan46.csv: frames=198, down=72, up=119, eq=7, fill=3336, drop=1778
#   Jalan47.csv: frames=395, down=39, up=355, eq=1, fill=14039, drop=539
#   Jalan48.csv: frames=429, down=70, up=356, eq=3, fill=12640, drop=2165
#   Jalan49.csv: frames=122, down=16, up=105, eq=1, fill=3398, drop=247
#   Jalan5.csv: frames=65, down=0, up=65, eq=0, fill=3035, drop=0
#   Jalan50.csv: frames=155, down=47, up=105, eq=3, fill=3239, drop=1002
#   Jalan51.csv: frames=140, down=73, up=65, eq=2, fill=1677, drop=1713
#   Jalan52.csv: frames=87, down=0, up=87, eq=0, fill=4150, drop=0
#   Jalan53.csv: frames=78, down=0, up=78, eq=0, fill=3549, drop=0
#   Jalan54.csv: frames=111, down=0, up=111, eq=0, fill=4577, drop=0
#   Jalan55.csv: frames=126, down=28, up=96, eq=2, fill=2967, drop=321
#   Jalan56.csv: frames=109, down=24, up=85, eq=0, fill=2923, drop=526
#   Jalan57.csv: frames=124, down=53, up=71, eq=0, fill=2714, drop=1397
#   Jalan58.csv: frames=125, down=29, up=96, eq=0, fill=3383, drop=689
#   Jalan59.csv: frames=129, down=12, up=116, eq=1, fill=3923, drop=101
#   Jalan6.csv: frames=93, down=0, up=93, eq=0, fill=3700, drop=0
#   Jalan60.csv: frames=147, down=27, up=120, eq=0, fill=4229, drop=698
#   Jalan61.csv: frames=129, down=30, up=99, eq=0, fill=3016, drop=482
#   Jalan62.csv: frames=115, down=8, up=106, eq=1, fill=3862, drop=68
#   Jalan63.csv: frames=351, down=33, up=315, eq=3, fill=11414, drop=347
#   Jalan64.csv: frames=333, down=46, up=282, eq=5, fill=9807, drop=834
#   Jalan65.csv: frames=279, down=56, up=221, eq=2, fill=7005, drop=719
#   Jalan66.csv: frames=230, down=63, up=161, eq=6, fill=4632, drop=984
#   Jalan67.csv: frames=280, down=25, up=252, eq=3, fill=8891, drop=132
#   Jalan68.csv: frames=278, down=30, up=248, eq=0, fill=8552, drop=381
#   Jalan69.csv: frames=257, down=53, up=204, eq=0, fill=6567, drop=815
#   Jalan7.csv: frames=138, down=10, up=127, eq=1, fill=4454, drop=95
#   Jalan70.csv: frames=226, down=73, up=153, eq=0, fill=4398, drop=1237
#   Jalan71.csv: frames=557, down=58, up=494, eq=5, fill=17496, drop=710
#   Jalan72.csv: frames=601, down=143, up=453, eq=5, fill=14190, drop=4439
#   Jalan8.csv: frames=109, down=32, up=75, eq=2, fill=2713, drop=688
#   Jalan9.csv: frames=104, down=6, up=97, eq=1, fill=2855, drop=70
#
# === N=64 | Subject D | files=72 ===
#   Jalan1.csv: frames=91, down=13, up=76, eq=2, fill=2709, drop=186
#   Jalan10.csv: frames=90, down=22, up=68, eq=0, fill=2471, drop=428
#   Jalan11.csv: frames=96, down=11, up=81, eq=4, fill=2618, drop=68
#   Jalan12.csv: frames=112, down=24, up=87, eq=1, fill=2798, drop=754
#   Jalan13.csv: frames=115, down=20, up=94, eq=1, fill=2852, drop=309
#   Jalan14.csv: frames=96, down=13, up=83, eq=0, fill=2962, drop=282
#   Jalan15.csv: frames=274, down=23, up=249, eq=2, fill=10005, drop=213
#   Jalan16.csv: frames=271, down=57, up=213, eq=1, fill=7144, drop=953
#   Jalan17.csv: frames=237, down=49, up=182, eq=6, fill=5993, drop=1060
#   Jalan18.csv: frames=186, down=65, up=121, eq=0, fill=3570, drop=1238
#   Jalan19.csv: frames=264, down=24, up=235, eq=5, fill=8511, drop=383
#   Jalan2.csv: frames=101, down=47, up=52, eq=2, fill=1232, drop=1272
#   Jalan20.csv: frames=268, down=45, up=221, eq=2, fill=7751, drop=885
#   Jalan21.csv: frames=251, down=91, up=158, eq=2, fill=4636, drop=2122
#   Jalan22.csv: frames=202, down=65, up=134, eq=3, fill=3139, drop=1282
#   Jalan23.csv: frames=454, down=88, up=361, eq=5, fill=11760, drop=1521
#   Jalan24.csv: frames=465, down=106, up=357, eq=2, fill=11349, drop=3259
#   Jalan25.csv: frames=73, down=4, up=69, eq=0, fill=2108, drop=67
#   Jalan26.csv: frames=93, down=47, up=46, eq=0, fill=1097, drop=1039
#   Jalan27.csv: frames=83, down=30, up=51, eq=2, fill=1572, drop=811
#   Jalan28.csv: frames=47, down=0, up=47, eq=0, fill=2502, drop=0
#   Jalan29.csv: frames=64, down=1, up=63, eq=0, fill=2783, drop=5
#   Jalan3.csv: frames=98, down=50, up=47, eq=1, fill=1534, drop=1555
#   Jalan30.csv: frames=76, down=0, up=76, eq=0, fill=2968, drop=0
#   Jalan31.csv: frames=71, down=18, up=53, eq=0, fill=1744, drop=255
#   Jalan32.csv: frames=55, down=20, up=34, eq=1, fill=1360, drop=448
#   Jalan33.csv: frames=63, down=16, up=47, eq=0, fill=1763, drop=545
#   Jalan34.csv: frames=71, down=13, up=57, eq=1, fill=2008, drop=167
#   Jalan35.csv: frames=77, down=8, up=67, eq=2, fill=2134, drop=76
#   Jalan36.csv: frames=72, down=14, up=57, eq=1, fill=1854, drop=275
#   Jalan37.csv: frames=86, down=21, up=63, eq=2, fill=2145, drop=353
#   Jalan38.csv: frames=71, down=12, up=59, eq=0, fill=2248, drop=318
#   Jalan39.csv: frames=218, down=19, up=198, eq=1, fill=7349, drop=315
#   Jalan4.csv: frames=71, down=0, up=71, eq=0, fill=3698, drop=0
#   Jalan40.csv: frames=189, down=36, up=150, eq=3, fill=5397, drop=813
#   Jalan41.csv: frames=167, down=36, up=131, eq=0, fill=4200, drop=775
#   Jalan42.csv: frames=149, down=59, up=88, eq=2, fill=2381, drop=1559
#   Jalan43.csv: frames=221, down=23, up=197, eq=1, fill=7393, drop=335
#   Jalan44.csv: frames=208, down=40, up=166, eq=2, fill=5878, drop=970
#   Jalan45.csv: frames=190, down=44, up=141, eq=5, fill=4075, drop=1201
#   Jalan46.csv: frames=150, down=56, up=93, eq=1, fill=2526, drop=1467
#   Jalan47.csv: frames=341, down=50, up=288, eq=3, fill=9089, drop=1013
#   Jalan48.csv: frames=338, down=57, up=277, eq=4, fill=10214, drop=1726
#   Jalan49.csv: frames=104, down=12, up=88, eq=4, fill=3250, drop=203
#   Jalan5.csv: frames=67, down=1, up=66, eq=0, fill=3060, drop=2
#   Jalan50.csv: frames=116, down=61, up=50, eq=5, fill=1107, drop=1519
#   Jalan51.csv: frames=107, down=36, up=71, eq=0, fill=2246, drop=743
#   Jalan52.csv: frames=73, down=0, up=73, eq=0, fill=3839, drop=0
#   Jalan53.csv: frames=84, down=0, up=84, eq=0, fill=3975, drop=0
#   Jalan54.csv: frames=105, down=8, up=96, eq=1, fill=3383, drop=49
#   Jalan55.csv: frames=99, down=11, up=86, eq=2, fill=2730, drop=199
#   Jalan56.csv: frames=89, down=30, up=58, eq=1, fill=2329, drop=654
#   Jalan57.csv: frames=109, down=37, up=72, eq=0, fill=2544, drop=971
#   Jalan58.csv: frames=114, down=28, up=85, eq=1, fill=2961, drop=709
#   Jalan59.csv: frames=107, down=8, up=99, eq=0, fill=2967, drop=66
#   Jalan6.csv: frames=91, down=12, up=78, eq=1, fill=2724, drop=73
#   Jalan60.csv: frames=112, down=12, up=98, eq=2, fill=3105, drop=153
#   Jalan61.csv: frames=138, down=37, up=101, eq=0, fill=3203, drop=773
#   Jalan62.csv: frames=118, down=32, up=85, eq=1, fill=2489, drop=823
#   Jalan63.csv: frames=258, down=18, up=240, eq=0, fill=8930, drop=379
#   Jalan64.csv: frames=287, down=59, up=226, eq=2, fill=8638, drop=1101
#   Jalan65.csv: frames=256, down=81, up=173, eq=2, fill=5101, drop=1871
#   Jalan66.csv: frames=198, down=74, up=121, eq=3, fill=3356, drop=1403
#   Jalan67.csv: frames=290, down=42, up=246, eq=2, fill=9974, drop=943
#   Jalan68.csv: frames=277, down=50, up=223, eq=4, fill=7603, drop=1067
#   Jalan69.csv: frames=274, down=81, up=191, eq=2, fill=6170, drop=2014
#   Jalan7.csv: frames=95, down=25, up=69, eq=1, fill=2274, drop=333
#   Jalan70.csv: frames=218, down=71, up=146, eq=1, fill=3987, drop=1540
#   Jalan71.csv: frames=476, down=82, up=390, eq=4, fill=13593, drop=1558
#   Jalan72.csv: frames=507, down=106, up=398, eq=3, fill=12804, drop=3181
#   Jalan8.csv: frames=83, down=27, up=56, eq=0, fill=2123, drop=536
#   Jalan9.csv: frames=94, down=36, up=58, eq=0, fill=2178, drop=1325
#
# === N=64 | Subject E | files=72 ===
#   Jalan1.csv: frames=97, down=21, up=74, eq=2, fill=2241, drop=253
#   Jalan10.csv: frames=84, down=24, up=58, eq=2, fill=1955, drop=436
#   Jalan11.csv: frames=89, down=20, up=68, eq=1, fill=2446, drop=257
#   Jalan12.csv: frames=92, down=26, up=66, eq=0, fill=2318, drop=795
#   Jalan13.csv: frames=98, down=37, up=59, eq=2, fill=1667, drop=554
#   Jalan14.csv: frames=86, down=14, up=71, eq=1, fill=2165, drop=289
#   Jalan15.csv: frames=256, down=14, up=239, eq=3, fill=8731, drop=107
#   Jalan16.csv: frames=241, down=51, up=187, eq=3, fill=6885, drop=1069
#   Jalan17.csv: frames=241, down=63, up=177, eq=1, fill=5830, drop=1277
#   Jalan18.csv: frames=167, down=74, up=92, eq=1, fill=2449, drop=1424
#   Jalan19.csv: frames=232, down=39, up=191, eq=2, fill=7135, drop=510
#   Jalan2.csv: frames=98, down=49, up=49, eq=0, fill=1315, drop=1736
#   Jalan20.csv: frames=214, down=60, up=153, eq=1, fill=5328, drop=1211
#   Jalan21.csv: frames=191, down=39, up=148, eq=4, fill=4727, drop=969
#   Jalan22.csv: frames=159, down=79, up=79, eq=1, fill=1992, drop=1885
#   Jalan23.csv: frames=382, down=59, up=321, eq=2, fill=10868, drop=693
#   Jalan24.csv: frames=396, down=107, up=286, eq=3, fill=9051, drop=3424
#   Jalan25.csv: frames=61, down=3, up=58, eq=0, fill=1849, drop=63
#   Jalan26.csv: frames=77, down=33, up=44, eq=0, fill=1054, drop=828
#   Jalan27.csv: frames=72, down=39, up=32, eq=1, fill=989, drop=1280
#   Jalan28.csv: frames=54, down=0, up=54, eq=0, fill=2788, drop=0
#   Jalan29.csv: frames=51, down=0, up=50, eq=1, fill=1825, drop=0
#   Jalan3.csv: frames=94, down=40, up=53, eq=1, fill=1542, drop=972
#   Jalan30.csv: frames=67, down=12, up=54, eq=1, fill=1793, drop=130
#   Jalan31.csv: frames=80, down=33, up=44, eq=3, fill=1553, drop=575
#   Jalan32.csv: frames=66, down=19, up=47, eq=0, fill=2063, drop=312
#   Jalan33.csv: frames=68, down=22, up=46, eq=0, fill=1770, drop=721
#   Jalan34.csv: frames=69, down=16, up=52, eq=1, fill=1887, drop=357
#   Jalan35.csv: frames=70, down=22, up=48, eq=0, fill=1509, drop=337
#   Jalan36.csv: frames=75, down=16, up=59, eq=0, fill=1873, drop=315
#   Jalan37.csv: frames=80, down=23, up=55, eq=2, fill=1703, drop=362
#   Jalan38.csv: frames=69, down=11, up=57, eq=1, fill=1744, drop=210
#   Jalan39.csv: frames=189, down=20, up=167, eq=2, fill=6216, drop=200
#   Jalan4.csv: frames=69, down=0, up=69, eq=0, fill=3400, drop=0
#   Jalan40.csv: frames=161, down=41, up=120, eq=0, fill=4274, drop=1180
#   Jalan41.csv: frames=166, down=56, up=110, eq=0, fill=2814, drop=1224
#   Jalan42.csv: frames=141, down=79, up=61, eq=1, fill=1428, drop=2067
#   Jalan43.csv: frames=192, down=24, up=166, eq=2, fill=5924, drop=281
#   Jalan44.csv: frames=183, down=52, up=129, eq=2, fill=3987, drop=1100
#   Jalan45.csv: frames=146, down=53, up=91, eq=2, fill=2371, drop=1140
#   Jalan46.csv: frames=122, down=67, up=54, eq=1, fill=1116, drop=1830
#   Jalan47.csv: frames=305, down=68, up=234, eq=3, fill=7859, drop=1036
#   Jalan48.csv: frames=320, down=86, up=233, eq=1, fill=8262, drop=2790
#   Jalan49.csv: frames=99, down=11, up=87, eq=1, fill=2262, drop=95
#   Jalan5.csv: frames=67, down=0, up=67, eq=0, fill=2751, drop=0
#   Jalan50.csv: frames=93, down=47, up=44, eq=2, fill=1168, drop=1283
#   Jalan51.csv: frames=129, down=57, up=71, eq=1, fill=1934, drop=1001
#   Jalan52.csv: frames=83, down=0, up=83, eq=0, fill=3865, drop=0
#   Jalan53.csv: frames=102, down=1, up=101, eq=0, fill=3868, drop=6
#   Jalan54.csv: frames=111, down=8, up=101, eq=2, fill=3404, drop=40
#   Jalan55.csv: frames=135, down=50, up=85, eq=0, fill=2754, drop=1054
#   Jalan56.csv: frames=116, down=45, up=71, eq=0, fill=2689, drop=725
#   Jalan57.csv: frames=106, down=29, up=77, eq=0, fill=2364, drop=453
#   Jalan58.csv: frames=111, down=33, up=76, eq=2, fill=2633, drop=564
#   Jalan59.csv: frames=109, down=41, up=68, eq=0, fill=2389, drop=1419
#   Jalan6.csv: frames=81, down=5, up=75, eq=1, fill=2757, drop=17
#   Jalan60.csv: frames=124, down=40, up=82, eq=2, fill=2685, drop=956
#   Jalan61.csv: frames=172, down=52, up=119, eq=1, fill=3331, drop=1343
#   Jalan62.csv: frames=155, down=28, up=126, eq=1, fill=3747, drop=452
#   Jalan63.csv: frames=331, down=47, up=283, eq=1, fill=10738, drop=681
#   Jalan64.csv: frames=307, down=74, up=233, eq=0, fill=8559, drop=1347
#   Jalan65.csv: frames=269, down=73, up=193, eq=3, fill=5435, drop=1966
#   Jalan66.csv: frames=233, down=95, up=133, eq=5, fill=2898, drop=2198
#   Jalan67.csv: frames=251, down=27, up=223, eq=1, fill=7815, drop=485
#   Jalan68.csv: frames=201, down=88, up=110, eq=3, fill=2883, drop=2438
#   Jalan69.csv: frames=228, down=52, up=176, eq=0, fill=5640, drop=1302
#   Jalan7.csv: frames=86, down=28, up=57, eq=1, fill=1772, drop=433
#   Jalan70.csv: frames=163, down=87, up=74, eq=2, fill=1874, drop=2394
#   Jalan71.csv: frames=467, down=89, up=375, eq=3, fill=12659, drop=1600
#   Jalan72.csv: frames=436, down=158, up=268, eq=10, fill=7676, drop=4917
#   Jalan8.csv: frames=85, down=27, up=57, eq=1, fill=2162, drop=411
#   Jalan9.csv: frames=82, down=28, up=54, eq=0, fill=1708, drop=846
#
# === N=64 | Subject F | files=72 ===
#   Jalan1.csv: frames=75, down=19, up=54, eq=2, fill=1058, drop=199
#   Jalan10.csv: frames=97, down=16, up=79, eq=2, fill=2796, drop=346
#   Jalan11.csv: frames=97, down=28, up=69, eq=0, fill=1998, drop=511
#   Jalan12.csv: frames=95, down=18, up=76, eq=1, fill=2624, drop=511
#   Jalan13.csv: frames=105, down=30, up=72, eq=3, fill=2154, drop=463
#   Jalan14.csv: frames=105, down=14, up=91, eq=0, fill=3184, drop=160
#   Jalan15.csv: frames=245, down=20, up=222, eq=3, fill=7470, drop=292
#   Jalan16.csv: frames=269, down=44, up=219, eq=6, fill=7420, drop=679
#   Jalan17.csv: frames=238, down=70, up=164, eq=4, fill=5317, drop=1388
#   Jalan18.csv: frames=195, down=92, up=102, eq=1, fill=3011, drop=2292
#   Jalan19.csv: frames=214, down=39, up=175, eq=0, fill=6623, drop=641
#   Jalan2.csv: frames=89, down=49, up=39, eq=1, fill=939, drop=1648
#   Jalan20.csv: frames=208, down=35, up=172, eq=1, fill=5290, drop=828
#   Jalan21.csv: frames=171, down=53, up=117, eq=1, fill=3230, drop=1353
#   Jalan22.csv: frames=159, down=69, up=89, eq=1, fill=2732, drop=1910
#   Jalan23.csv: frames=398, down=79, up=314, eq=5, fill=10213, drop=1419
#   Jalan24.csv: frames=383, down=137, up=241, eq=5, fill=7709, drop=3883
#   Jalan25.csv: frames=70, down=11, up=57, eq=2, fill=1452, drop=84
#   Jalan26.csv: frames=76, down=40, up=36, eq=0, fill=1088, drop=1260
#   Jalan27.csv: frames=74, down=29, up=44, eq=1, fill=1178, drop=655
#   Jalan28.csv: frames=36, down=0, up=36, eq=0, fill=2042, drop=0
#   Jalan29.csv: frames=49, down=0, up=49, eq=0, fill=2316, drop=0
#   Jalan3.csv: frames=86, down=42, up=42, eq=2, fill=1436, drop=966
#   Jalan30.csv: frames=68, down=6, up=61, eq=1, fill=2083, drop=32
#   Jalan31.csv: frames=69, down=12, up=56, eq=1, fill=1811, drop=92
#   Jalan32.csv: frames=69, down=21, up=47, eq=1, fill=1863, drop=393
#   Jalan33.csv: frames=72, down=12, up=60, eq=0, fill=1834, drop=157
#   Jalan34.csv: frames=75, down=8, up=67, eq=0, fill=2625, drop=101
#   Jalan35.csv: frames=77, down=30, up=46, eq=1, fill=1413, drop=837
#   Jalan36.csv: frames=72, down=19, up=52, eq=1, fill=1703, drop=547
#   Jalan37.csv: frames=86, down=38, up=47, eq=1, fill=1383, drop=813
#   Jalan38.csv: frames=83, down=12, up=70, eq=1, fill=2614, drop=184
#   Jalan39.csv: frames=181, down=34, up=145, eq=2, fill=5160, drop=537
#   Jalan4.csv: frames=46, down=0, up=46, eq=0, fill=2465, drop=0
#   Jalan40.csv: frames=186, down=29, up=156, eq=1, fill=5699, drop=608
#   Jalan41.csv: frames=160, down=49, up=109, eq=2, fill=3161, drop=1010
#   Jalan42.csv: frames=133, down=58, up=74, eq=1, fill=1490, drop=1724
#   Jalan43.csv: frames=177, down=18, up=159, eq=0, fill=5909, drop=195
#   Jalan44.csv: frames=182, down=34, up=147, eq=1, fill=4878, drop=713
#   Jalan45.csv: frames=154, down=48, up=105, eq=1, fill=3268, drop=1241
#   Jalan46.csv: frames=119, down=56, up=61, eq=2, fill=1873, drop=1411
#   Jalan47.csv: frames=330, down=78, up=249, eq=3, fill=8796, drop=1523
#   Jalan48.csv: frames=302, down=91, up=208, eq=3, fill=7068, drop=2424
#   Jalan49.csv: frames=98, down=23, up=74, eq=1, fill=1792, drop=370
#   Jalan5.csv: frames=60, down=0, up=60, eq=0, fill=2742, drop=0
#   Jalan50.csv: frames=99, down=54, up=42, eq=3, fill=1064, drop=1944
#   Jalan51.csv: frames=102, down=37, up=65, eq=0, fill=2062, drop=792
#   Jalan52.csv: frames=48, down=0, up=48, eq=0, fill=2661, drop=0
#   Jalan53.csv: frames=72, down=0, up=72, eq=0, fill=3290, drop=0
#   Jalan54.csv: frames=94, down=6, up=88, eq=0, fill=2992, drop=34
#   Jalan55.csv: frames=89, down=24, up=64, eq=1, fill=2327, drop=273
#   Jalan56.csv: frames=81, down=23, up=54, eq=4, fill=2063, drop=350
#   Jalan57.csv: frames=96, down=43, up=52, eq=1, fill=1864, drop=1527
#   Jalan58.csv: frames=98, down=14, up=82, eq=2, fill=3060, drop=241
#   Jalan59.csv: frames=81, down=13, up=68, eq=0, fill=1935, drop=172
#   Jalan6.csv: frames=73, down=8, up=64, eq=1, fill=2073, drop=64
#   Jalan60.csv: frames=106, down=9, up=96, eq=1, fill=3568, drop=176
#   Jalan61.csv: frames=107, down=41, up=65, eq=1, fill=1685, drop=772
#   Jalan62.csv: frames=102, down=20, up=81, eq=1, fill=2727, drop=467
#   Jalan63.csv: frames=253, down=32, up=221, eq=0, fill=8072, drop=459
#   Jalan64.csv: frames=268, down=51, up=216, eq=1, fill=7493, drop=742
#   Jalan65.csv: frames=229, down=66, up=162, eq=1, fill=5291, drop=1372
#   Jalan66.csv: frames=180, down=87, up=90, eq=3, fill=2025, drop=2133
#   Jalan67.csv: frames=208, down=20, up=186, eq=2, fill=7030, drop=322
#   Jalan68.csv: frames=254, down=45, up=206, eq=3, fill=7535, drop=672
#   Jalan69.csv: frames=203, down=60, up=141, eq=2, fill=4307, drop=1229
#   Jalan7.csv: frames=75, down=17, up=57, eq=1, fill=1952, drop=220
#   Jalan70.csv: frames=164, down=69, up=91, eq=4, fill=2543, drop=1694
#   Jalan71.csv: frames=428, down=102, up=324, eq=2, fill=10500, drop=2009
#   Jalan72.csv: frames=400, down=162, up=236, eq=2, fill=7365, drop=4739
#   Jalan8.csv: frames=78, down=23, up=54, eq=1, fill=2192, drop=466
#   Jalan9.csv: frames=103, down=46, up=56, eq=1, fill=2063, drop=1706
#
# === N=64 | Subject G | files=72 ===
#   Jalan1.csv: frames=93, down=15, up=77, eq=1, fill=1677, drop=239
#   Jalan10.csv: frames=98, down=19, up=79, eq=0, fill=2801, drop=359
#   Jalan11.csv: frames=74, down=19, up=55, eq=0, fill=1115, drop=178
#   Jalan12.csv: frames=97, down=22, up=74, eq=1, fill=2389, drop=712
#   Jalan13.csv: frames=109, down=46, up=63, eq=0, fill=1954, drop=1105
#   Jalan14.csv: frames=106, down=18, up=85, eq=3, fill=2855, drop=190
#   Jalan15.csv: frames=235, down=27, up=204, eq=4, fill=7748, drop=417
#   Jalan16.csv: frames=236, down=53, up=183, eq=0, fill=6029, drop=911
#   Jalan17.csv: frames=214, down=59, up=152, eq=3, fill=4461, drop=1035
#   Jalan18.csv: frames=191, down=94, up=94, eq=3, fill=2592, drop=2708
#   Jalan19.csv: frames=231, down=24, up=205, eq=2, fill=7856, drop=478
#   Jalan2.csv: frames=101, down=51, up=50, eq=0, fill=1319, drop=1812
#   Jalan20.csv: frames=196, down=27, up=167, eq=2, fill=5828, drop=368
#   Jalan21.csv: frames=174, down=49, up=122, eq=3, fill=3636, drop=1078
#   Jalan22.csv: frames=155, down=77, up=77, eq=1, fill=2094, drop=2320
#   Jalan23.csv: frames=387, down=56, up=330, eq=1, fill=11637, drop=814
#   Jalan24.csv: frames=376, down=102, up=272, eq=2, fill=8399, drop=3039
#   Jalan25.csv: frames=64, down=10, up=53, eq=1, fill=1504, drop=138
#   Jalan26.csv: frames=77, down=41, up=36, eq=0, fill=818, drop=1279
#   Jalan27.csv: frames=67, down=20, up=46, eq=1, fill=1191, drop=732
#   Jalan28.csv: frames=43, down=0, up=43, eq=0, fill=2346, drop=0
#   Jalan29.csv: frames=57, down=0, up=57, eq=0, fill=2658, drop=0
#   Jalan3.csv: frames=97, down=29, up=67, eq=1, fill=1949, drop=696
#   Jalan30.csv: frames=70, down=7, up=61, eq=2, fill=2139, drop=46
#   Jalan31.csv: frames=59, down=18, up=40, eq=1, fill=974, drop=421
#   Jalan32.csv: frames=63, down=20, up=43, eq=0, fill=1580, drop=380
#   Jalan33.csv: frames=64, down=19, up=44, eq=1, fill=1604, drop=580
#   Jalan34.csv: frames=59, down=14, up=45, eq=0, fill=1484, drop=282
#   Jalan35.csv: frames=65, down=18, up=46, eq=1, fill=1290, drop=188
#   Jalan36.csv: frames=90, down=20, up=70, eq=0, fill=2473, drop=426
#   Jalan37.csv: frames=85, down=26, up=59, eq=0, fill=1570, drop=499
#   Jalan38.csv: frames=72, down=18, up=53, eq=1, fill=1706, drop=201
#   Jalan39.csv: frames=185, down=40, up=145, eq=0, fill=5417, drop=621
#   Jalan4.csv: frames=49, down=0, up=49, eq=0, fill=2768, drop=0
#   Jalan40.csv: frames=179, down=42, up=136, eq=1, fill=4947, drop=1031
#   Jalan41.csv: frames=169, down=64, up=104, eq=1, fill=3138, drop=1644
#   Jalan42.csv: frames=147, down=76, up=70, eq=1, fill=2070, drop=2617
#   Jalan43.csv: frames=171, down=37, up=134, eq=0, fill=5077, drop=646
#   Jalan44.csv: frames=176, down=42, up=132, eq=2, fill=4851, drop=596
#   Jalan45.csv: frames=149, down=51, up=95, eq=3, fill=2189, drop=1240
#   Jalan46.csv: frames=102, down=52, up=47, eq=3, fill=1184, drop=1401
#   Jalan47.csv: frames=296, down=53, up=242, eq=1, fill=7560, drop=812
#   Jalan48.csv: frames=311, down=92, up=215, eq=4, fill=6747, drop=2509
#   Jalan49.csv: frames=92, down=17, up=74, eq=1, fill=2124, drop=416
#   Jalan5.csv: frames=77, down=0, up=77, eq=0, fill=3475, drop=0
#   Jalan50.csv: frames=109, down=54, up=55, eq=0, fill=1398, drop=1931
#   Jalan51.csv: frames=109, down=49, up=56, eq=4, fill=1629, drop=1196
#   Jalan52.csv: frames=76, down=0, up=76, eq=0, fill=3710, drop=0
#   Jalan53.csv: frames=84, down=0, up=84, eq=0, fill=3769, drop=0
#   Jalan54.csv: frames=110, down=0, up=110, eq=0, fill=4689, drop=0
#   Jalan55.csv: frames=85, down=24, up=61, eq=0, fill=1647, drop=377
#   Jalan56.csv: frames=84, down=31, up=53, eq=0, fill=1889, drop=539
#   Jalan57.csv: frames=84, down=35, up=49, eq=0, fill=1609, drop=1407
#   Jalan58.csv: frames=100, down=32, up=68, eq=0, fill=1929, drop=545
#   Jalan59.csv: frames=100, down=32, up=68, eq=0, fill=1929, drop=545
#   Jalan6.csv: frames=88, down=4, up=84, eq=0, fill=3485, drop=54
#   Jalan60.csv: frames=131, down=28, up=101, eq=2, fill=3459, drop=744
#   Jalan61.csv: frames=111, down=23, up=87, eq=1, fill=2437, drop=584
#   Jalan62.csv: frames=120, down=32, up=86, eq=2, fill=2621, drop=594
#   Jalan63.csv: frames=288, down=46, up=237, eq=5, fill=8956, drop=741
#   Jalan64.csv: frames=264, down=58, up=205, eq=1, fill=7289, drop=981
#   Jalan65.csv: frames=204, down=84, up=119, eq=1, fill=2814, drop=1680
#   Jalan66.csv: frames=202, down=101, up=101, eq=0, fill=2326, drop=2741
#   Jalan67.csv: frames=248, down=47, up=201, eq=0, fill=7093, drop=639
#   Jalan68.csv: frames=225, down=56, up=169, eq=0, fill=5963, drop=1311
#   Jalan69.csv: frames=192, down=86, up=100, eq=6, fill=2346, drop=1895
#   Jalan7.csv: frames=109, down=24, up=85, eq=0, fill=2558, drop=454
#   Jalan70.csv: frames=179, down=99, up=80, eq=0, fill=2094, drop=2632
#   Jalan71.csv: frames=426, down=71, up=351, eq=4, fill=11579, drop=1124
#   Jalan72.csv: frames=414, down=100, up=312, eq=2, fill=10086, drop=2618
#   Jalan8.csv: frames=85, down=27, up=58, eq=0, fill=1897, drop=425
#   Jalan9.csv: frames=97, down=39, up=57, eq=1, fill=2013, drop=1237
#
# === N=64 | Subject H | files=72 ===
#   Jalan1.csv: frames=104, down=23, up=80, eq=1, fill=2023, drop=398
#   Jalan10.csv: frames=79, down=6, up=73, eq=0, fill=2546, drop=144
#   Jalan11.csv: frames=84, down=16, up=67, eq=1, fill=1971, drop=279
#   Jalan12.csv: frames=101, down=25, up=74, eq=2, fill=2567, drop=534
#   Jalan13.csv: frames=99, down=42, up=54, eq=3, fill=1580, drop=1047
#   Jalan14.csv: frames=87, down=8, up=79, eq=0, fill=3184, drop=211
#   Jalan15.csv: frames=262, down=32, up=230, eq=0, fill=7739, drop=501
#   Jalan16.csv: frames=253, down=52, up=199, eq=2, fill=7391, drop=937
#   Jalan17.csv: frames=215, down=83, up=130, eq=2, fill=4349, drop=1915
#   Jalan18.csv: frames=189, down=59, up=129, eq=1, fill=3582, drop=1283
#   Jalan19.csv: frames=223, down=31, up=189, eq=3, fill=6769, drop=539
#   Jalan2.csv: frames=117, down=53, up=62, eq=2, fill=1523, drop=1520
#   Jalan20.csv: frames=227, down=49, up=177, eq=1, fill=6240, drop=984
#   Jalan21.csv: frames=208, down=53, up=154, eq=1, fill=5216, drop=1475
#   Jalan22.csv: frames=184, down=65, up=116, eq=3, fill=3531, drop=1425
#   Jalan23.csv: frames=421, down=76, up=344, eq=1, fill=11011, drop=1423
#   Jalan24.csv: frames=378, down=128, up=247, eq=3, fill=8330, drop=4555
#   Jalan25.csv: frames=51, down=4, up=47, eq=0, fill=1675, drop=101
#   Jalan26.csv: frames=52, down=5, up=47, eq=0, fill=1564, drop=73
#   Jalan27.csv: frames=57, down=23, up=34, eq=0, fill=978, drop=838
#   Jalan28.csv: frames=32, down=0, up=32, eq=0, fill=1719, drop=0
#   Jalan29.csv: frames=46, down=0, up=46, eq=0, fill=2227, drop=0
#   Jalan3.csv: frames=98, down=52, up=45, eq=1, fill=1187, drop=1515
#   Jalan30.csv: frames=54, down=0, up=54, eq=0, fill=1951, drop=0
#   Jalan31.csv: frames=51, down=11, up=40, eq=0, fill=1330, drop=147
#   Jalan32.csv: frames=47, down=15, up=32, eq=0, fill=1368, drop=341
#   Jalan33.csv: frames=49, down=18, up=31, eq=0, fill=1095, drop=388
#   Jalan34.csv: frames=47, down=6, up=41, eq=0, fill=1607, drop=80
#   Jalan35.csv: frames=59, down=15, up=43, eq=1, fill=1537, drop=242
#   Jalan36.csv: frames=64, down=7, up=57, eq=0, fill=2105, drop=79
#   Jalan37.csv: frames=72, down=26, up=46, eq=0, fill=1477, drop=465
#   Jalan38.csv: frames=59, down=8, up=50, eq=1, fill=1649, drop=172
#   Jalan39.csv: frames=170, down=29, up=139, eq=2, fill=5531, drop=390
#   Jalan4.csv: frames=63, down=0, up=63, eq=0, fill=3348, drop=0
#   Jalan40.csv: frames=164, down=34, up=128, eq=2, fill=4975, drop=677
#   Jalan41.csv: frames=179, down=42, up=135, eq=2, fill=4024, drop=878
#   Jalan42.csv: frames=127, down=57, up=66, eq=4, fill=1755, drop=1218
#   Jalan43.csv: frames=159, down=29, up=129, eq=1, fill=5270, drop=451
#   Jalan44.csv: frames=161, down=34, up=125, eq=2, fill=4723, drop=677
#   Jalan45.csv: frames=163, down=41, up=121, eq=1, fill=4377, drop=1118
#   Jalan46.csv: frames=139, down=45, up=93, eq=1, fill=2731, drop=779
#   Jalan47.csv: frames=282, down=50, up=231, eq=1, fill=8262, drop=650
#   Jalan48.csv: frames=276, down=87, up=188, eq=1, fill=6328, drop=2748
#   Jalan49.csv: frames=120, down=21, up=97, eq=2, fill=2516, drop=387
#   Jalan5.csv: frames=76, down=0, up=76, eq=0, fill=3593, drop=0
#   Jalan50.csv: frames=156, down=80, up=73, eq=3, fill=2270, drop=2486
#   Jalan51.csv: frames=142, down=59, up=80, eq=3, fill=2171, drop=1187
#   Jalan52.csv: frames=75, down=0, up=75, eq=0, fill=4135, drop=0
#   Jalan53.csv: frames=89, down=0, up=89, eq=0, fill=4485, drop=0
#   Jalan54.csv: frames=111, down=1, up=109, eq=1, fill=4447, drop=2
#   Jalan55.csv: frames=132, down=25, up=107, eq=0, fill=3471, drop=432
#   Jalan56.csv: frames=142, down=41, up=98, eq=3, fill=3680, drop=985
#   Jalan57.csv: frames=130, down=59, up=70, eq=1, fill=2330, drop=1298
#   Jalan58.csv: frames=136, down=21, up=115, eq=0, fill=4403, drop=421
#   Jalan59.csv: frames=122, down=25, up=93, eq=4, fill=2900, drop=394
#   Jalan6.csv: frames=87, down=3, up=83, eq=1, fill=3047, drop=40
#   Jalan60.csv: frames=118, down=15, up=103, eq=0, fill=3833, drop=222
#   Jalan61.csv: frames=184, down=60, up=122, eq=2, fill=3559, drop=1597
#   Jalan62.csv: frames=160, down=38, up=120, eq=2, fill=3850, drop=676
#   Jalan63.csv: frames=332, down=15, up=316, eq=1, fill=11753, drop=249
#   Jalan64.csv: frames=318, down=53, up=262, eq=3, fill=9881, drop=687
#   Jalan65.csv: frames=281, down=48, up=232, eq=1, fill=8264, drop=908
#   Jalan66.csv: frames=204, down=78, up=121, eq=5, fill=3166, drop=1290
#   Jalan67.csv: frames=256, down=47, up=208, eq=1, fill=8389, drop=926
#   Jalan68.csv: frames=256, down=49, up=204, eq=3, fill=7940, drop=943
#   Jalan69.csv: frames=246, down=48, up=193, eq=5, fill=6963, drop=1023
#   Jalan7.csv: frames=78, down=14, up=63, eq=1, fill=2101, drop=144
#   Jalan70.csv: frames=253, down=81, up=167, eq=5, fill=5206, drop=1392
#   Jalan71.csv: frames=510, down=67, up=438, eq=5, fill=15558, drop=1280
#   Jalan72.csv: frames=528, down=159, up=363, eq=6, fill=11290, drop=4818
#   Jalan8.csv: frames=78, down=19, up=58, eq=1, fill=2064, drop=465
#   Jalan9.csv: frames=80, down=34, up=44, eq=2, fill=1409, drop=1158
#
# === N=64 | Subject I | files=72 ===
#   Jalan1.csv: frames=89, down=20, up=68, eq=1, fill=2201, drop=265
#   Jalan10.csv: frames=96, down=30, up=65, eq=1, fill=2113, drop=657
#   Jalan11.csv: frames=89, down=39, up=49, eq=1, fill=1860, drop=1218
#   Jalan12.csv: frames=100, down=25, up=75, eq=0, fill=2494, drop=341
#   Jalan13.csv: frames=121, down=46, up=74, eq=1, fill=2008, drop=1046
#   Jalan14.csv: frames=107, down=29, up=76, eq=2, fill=2562, drop=605
#   Jalan15.csv: frames=275, down=59, up=214, eq=2, fill=7677, drop=1240
#   Jalan16.csv: frames=269, down=83, up=186, eq=0, fill=5704, drop=1524
#   Jalan17.csv: frames=227, down=78, up=146, eq=3, fill=3966, drop=1667
#   Jalan18.csv: frames=174, down=94, up=77, eq=3, fill=1677, drop=2069
#   Jalan19.csv: frames=232, down=54, up=177, eq=1, fill=5841, drop=1467
#   Jalan2.csv: frames=98, down=58, up=39, eq=1, fill=925, drop=1698
#   Jalan20.csv: frames=213, down=60, up=150, eq=3, fill=4890, drop=1483
#   Jalan21.csv: frames=209, down=86, up=122, eq=1, fill=3190, drop=1841
#   Jalan22.csv: frames=133, down=101, up=32, eq=0, fill=662, drop=2967
#   Jalan23.csv: frames=381, down=94, up=284, eq=3, fill=8566, drop=1698
#   Jalan24.csv: frames=393, down=133, up=257, eq=3, fill=7615, drop=3936
#   Jalan25.csv: frames=71, down=19, up=52, eq=0, fill=1458, drop=349
#   Jalan26.csv: frames=79, down=35, up=42, eq=2, fill=956, drop=1220
#   Jalan27.csv: frames=78, down=35, up=43, eq=0, fill=1302, drop=1354
#   Jalan28.csv: frames=57, down=0, up=57, eq=0, fill=2868, drop=0
#   Jalan29.csv: frames=66, down=5, up=61, eq=0, fill=2384, drop=36
#   Jalan3.csv: frames=91, down=49, up=41, eq=1, fill=1063, drop=1287
#   Jalan30.csv: frames=73, down=10, up=61, eq=2, fill=1983, drop=48
#   Jalan31.csv: frames=66, down=24, up=42, eq=0, fill=1103, drop=683
#   Jalan32.csv: frames=65, down=19, up=45, eq=1, fill=1423, drop=487
#   Jalan33.csv: frames=76, down=24, up=52, eq=0, fill=1563, drop=970
#   Jalan34.csv: frames=73, down=25, up=47, eq=1, fill=1835, drop=709
#   Jalan35.csv: frames=72, down=21, up=51, eq=0, fill=1639, drop=393
#   Jalan36.csv: frames=74, down=19, up=53, eq=2, fill=1488, drop=388
#   Jalan37.csv: frames=82, down=29, up=52, eq=1, fill=1599, drop=621
#   Jalan38.csv: frames=84, down=26, up=57, eq=1, fill=2058, drop=702
#   Jalan39.csv: frames=207, down=59, up=143, eq=5, fill=5350, drop=959
#   Jalan4.csv: frames=79, down=0, up=79, eq=0, fill=3797, drop=0
#   Jalan40.csv: frames=194, down=62, up=129, eq=3, fill=4025, drop=1337
#   Jalan41.csv: frames=158, down=55, up=103, eq=0, fill=3018, drop=1284
#   Jalan42.csv: frames=124, down=69, up=51, eq=4, fill=1042, drop=2094
#   Jalan43.csv: frames=170, down=47, up=122, eq=1, fill=3737, drop=1280
#   Jalan44.csv: frames=166, down=64, up=101, eq=1, fill=2582, drop=1585
#   Jalan45.csv: frames=144, down=56, up=84, eq=4, fill=2112, drop=1489
#   Jalan46.csv: frames=128, down=78, up=47, eq=3, fill=1044, drop=2519
#   Jalan47.csv: frames=308, down=102, up=205, eq=1, fill=6337, drop=2065
#   Jalan48.csv: frames=305, down=103, up=197, eq=5, fill=6315, drop=3004
#   Jalan49.csv: frames=102, down=20, up=81, eq=1, fill=2283, drop=398
#   Jalan5.csv: frames=78, down=1, up=77, eq=0, fill=3362, drop=2
#   Jalan50.csv: frames=117, down=55, up=61, eq=1, fill=1418, drop=1578
#   Jalan51.csv: frames=110, down=53, up=56, eq=1, fill=1709, drop=1761
#   Jalan52.csv: frames=84, down=1, up=83, eq=0, fill=3972, drop=2
#   Jalan53.csv: frames=94, down=0, up=93, eq=1, fill=3779, drop=0
#   Jalan54.csv: frames=114, down=12, up=101, eq=1, fill=3559, drop=72
#   Jalan55.csv: frames=107, down=33, up=74, eq=0, fill=2128, drop=653
#   Jalan56.csv: frames=88, down=30, up=57, eq=1, fill=1913, drop=566
#   Jalan57.csv: frames=108, down=60, up=47, eq=1, fill=1692, drop=1739
#   Jalan58.csv: frames=118, down=39, up=77, eq=2, fill=2773, drop=782
#   Jalan59.csv: frames=114, down=40, up=71, eq=3, fill=2340, drop=627
#   Jalan6.csv: frames=96, down=12, up=81, eq=3, fill=2598, drop=121
#   Jalan60.csv: frames=115, down=32, up=82, eq=1, fill=3043, drop=1027
#   Jalan61.csv: frames=143, down=47, up=92, eq=4, fill=2766, drop=949
#   Jalan62.csv: frames=110, down=19, up=88, eq=3, fill=2787, drop=242
#   Jalan63.csv: frames=308, down=69, up=238, eq=1, fill=7944, drop=1685
#   Jalan64.csv: frames=264, down=82, up=181, eq=1, fill=5270, drop=2113
#   Jalan65.csv: frames=213, down=87, up=122, eq=4, fill=3316, drop=2115
#   Jalan66.csv: frames=178, down=94, up=82, eq=2, fill=1631, drop=2628
#   Jalan67.csv: frames=271, down=51, up=219, eq=1, fill=7432, drop=1302
#   Jalan68.csv: frames=242, down=59, up=179, eq=4, fill=5866, drop=1285
#   Jalan69.csv: frames=205, down=97, up=104, eq=4, fill=2103, drop=2517
#   Jalan7.csv: frames=89, down=28, up=60, eq=1, fill=1735, drop=424
#   Jalan70.csv: frames=167, down=105, up=59, eq=3, fill=1100, drop=3384
#   Jalan71.csv: frames=428, down=116, up=299, eq=13, fill=9018, drop=2324
#   Jalan72.csv: frames=454, down=167, up=282, eq=5, fill=7932, drop=4950
#   Jalan8.csv: frames=84, down=28, up=55, eq=1, fill=1773, drop=569
#   Jalan9.csv: frames=96, down=28, up=68, eq=0, fill=1966, drop=450
#
# === N=64 | Subject J | files=72 ===
#   Jalan1.csv: frames=91, down=22, up=66, eq=3, fill=1854, drop=380
#   Jalan10.csv: frames=91, down=27, up=62, eq=2, fill=2232, drop=585
#   Jalan11.csv: frames=111, down=39, up=72, eq=0, fill=2443, drop=747
#   Jalan12.csv: frames=98, down=26, up=71, eq=1, fill=2434, drop=778
#   Jalan13.csv: frames=108, down=32, up=76, eq=0, fill=2477, drop=873
#   Jalan14.csv: frames=94, down=14, up=79, eq=1, fill=2265, drop=189
#   Jalan15.csv: frames=257, down=20, up=237, eq=0, fill=8798, drop=323
#   Jalan16.csv: frames=233, down=54, up=177, eq=2, fill=6215, drop=876
#   Jalan17.csv: frames=214, down=37, up=173, eq=4, fill=5025, drop=574
#   Jalan18.csv: frames=177, down=82, up=92, eq=3, fill=2255, drop=2122
#   Jalan19.csv: frames=223, down=50, up=171, eq=2, fill=5832, drop=1037
#   Jalan2.csv: frames=100, down=45, up=54, eq=1, fill=1273, drop=1199
#   Jalan20.csv: frames=225, down=60, up=164, eq=1, fill=4266, drop=1327
#   Jalan21.csv: frames=204, down=83, up=119, eq=2, fill=2757, drop=1608
#   Jalan22.csv: frames=181, down=74, up=107, eq=0, fill=2779, drop=1817
#   Jalan23.csv: frames=475, down=58, up=416, eq=1, fill=14381, drop=641
#   Jalan24.csv: frames=468, down=129, up=337, eq=2, fill=9992, drop=4476
#   Jalan25.csv: frames=71, down=15, up=54, eq=2, fill=1489, drop=266
#   Jalan26.csv: frames=75, down=23, up=51, eq=1, fill=1030, drop=448
#   Jalan27.csv: frames=80, down=36, up=44, eq=0, fill=1434, drop=979
#   Jalan28.csv: frames=59, down=0, up=59, eq=0, fill=2913, drop=0
#   Jalan29.csv: frames=61, down=0, up=61, eq=0, fill=2543, drop=0
#   Jalan3.csv: frames=91, down=46, up=45, eq=0, fill=1371, drop=1463
#   Jalan30.csv: frames=67, down=7, up=58, eq=2, fill=2051, drop=28
#   Jalan31.csv: frames=69, down=24, up=44, eq=1, fill=1386, drop=459
#   Jalan32.csv: frames=64, down=16, up=46, eq=2, fill=1608, drop=324
#   Jalan33.csv: frames=75, down=22, up=50, eq=3, fill=1426, drop=244
#   Jalan34.csv: frames=71, down=22, up=49, eq=0, fill=1884, drop=482
#   Jalan35.csv: frames=76, down=26, up=49, eq=1, fill=1704, drop=598
#   Jalan36.csv: frames=68, down=10, up=57, eq=1, fill=1937, drop=167
#   Jalan37.csv: frames=84, down=13, up=70, eq=1, fill=2095, drop=284
#   Jalan38.csv: frames=74, down=17, up=57, eq=0, fill=1813, drop=433
#   Jalan39.csv: frames=195, down=43, up=150, eq=2, fill=4808, drop=928
#   Jalan4.csv: frames=77, down=0, up=77, eq=0, fill=3756, drop=0
#   Jalan40.csv: frames=195, down=43, up=150, eq=2, fill=4808, drop=928
#   Jalan41.csv: frames=157, down=57, up=96, eq=4, fill=2414, drop=787
#   Jalan42.csv: frames=132, down=65, up=63, eq=4, fill=1409, drop=1492
#   Jalan43.csv: frames=191, down=56, up=132, eq=3, fill=4043, drop=1280
#   Jalan44.csv: frames=189, down=74, up=112, eq=3, fill=2996, drop=1621
#   Jalan45.csv: frames=151, down=82, up=69, eq=0, fill=1428, drop=1583
#   Jalan46.csv: frames=123, down=77, up=43, eq=3, fill=765, drop=1809
#   Jalan47.csv: frames=332, down=63, up=266, eq=3, fill=8559, drop=1037
#   Jalan48.csv: frames=373, down=83, up=287, eq=3, fill=9858, drop=3156
#   Jalan49.csv: frames=112, down=23, up=89, eq=0, fill=2413, drop=432
#   Jalan5.csv: frames=78, down=0, up=78, eq=0, fill=3337, drop=0
#   Jalan50.csv: frames=109, down=37, up=70, eq=2, fill=1639, drop=896
#   Jalan51.csv: frames=113, down=48, up=62, eq=3, fill=1649, drop=984
#   Jalan52.csv: frames=88, down=0, up=88, eq=0, fill=4019, drop=0
#   Jalan53.csv: frames=98, down=0, up=98, eq=0, fill=4383, drop=0
#   Jalan54.csv: frames=104, down=2, up=101, eq=1, fill=3887, drop=13
#   Jalan55.csv: frames=109, down=49, up=59, eq=1, fill=1662, drop=933
#   Jalan56.csv: frames=97, down=22, up=71, eq=4, fill=2246, drop=276
#   Jalan57.csv: frames=108, down=34, up=71, eq=3, fill=2125, drop=469
#   Jalan58.csv: frames=104, down=22, up=81, eq=1, fill=2762, drop=487
#   Jalan59.csv: frames=112, down=46, up=65, eq=1, fill=2066, drop=1382
#   Jalan6.csv: frames=90, down=5, up=84, eq=1, fill=2843, drop=77
#   Jalan60.csv: frames=107, down=18, up=88, eq=1, fill=2975, drop=276
#   Jalan61.csv: frames=132, down=35, up=97, eq=0, fill=2896, drop=851
#   Jalan62.csv: frames=121, down=29, up=90, eq=2, fill=3020, drop=553
#   Jalan63.csv: frames=285, down=13, up=271, eq=1, fill=10594, drop=148
#   Jalan64.csv: frames=268, down=55, up=211, eq=2, fill=7052, drop=902
#   Jalan65.csv: frames=228, down=62, up=162, eq=4, fill=4673, drop=1044
#   Jalan66.csv: frames=191, down=66, up=124, eq=1, fill=3160, drop=1665
#   Jalan67.csv: frames=259, down=64, up=192, eq=3, fill=5631, drop=1415
#   Jalan68.csv: frames=232, down=78, up=150, eq=4, fill=3939, drop=1698
#   Jalan69.csv: frames=196, down=109, up=85, eq=2, fill=1909, drop=2366
#   Jalan7.csv: frames=91, down=26, up=65, eq=0, fill=2182, drop=374
#   Jalan70.csv: frames=163, down=104, up=57, eq=2, fill=1257, drop=2629
#   Jalan71.csv: frames=519, down=82, up=434, eq=3, fill=14971, drop=1225
#   Jalan72.csv: frames=488, down=160, up=318, eq=10, fill=9039, drop=4308
#   Jalan8.csv: frames=83, down=21, up=62, eq=0, fill=2012, drop=376
#   Jalan9.csv: frames=98, down=32, up=65, eq=1, fill=2373, drop=872
#
# Saved summary: E:\0.TA_Teguh\Sampling\FPS\fps_sampling_summary.csv
#           file subject   N  frames  down  up  eq  empty  total_drop  \
# 0   Jalan1.csv       A  64      82     7  74   1      0         100
# 1  Jalan10.csv       A  64      87    20  66   1      0         375
# 2  Jalan11.csv       A  64      87    33  54   0      0        1044
# 3  Jalan12.csv       A  64      98    34  62   2      0         615
# 4  Jalan13.csv       A  64     103    28  74   1      0         568
#
#    total_fill
# 0        2662
# 1        2257
# 2        2002
# 3        2085
# 4        2137

# %% [markdown]
# Cell 11 — Quick sanity checks on outputs (optional)

# %%
if len(all_stats) > 0:
    df_sum = pd.DataFrame(all_stats)
    display(df_sum.groupby(["N"]).agg(
        files=("file","count"),
        frames=("frames","sum"),
        down=("down","sum"),
        up=("up","sum"),
        eq=("eq","sum"),
        total_fill=("total_fill","sum"),
        total_drop=("total_drop","sum"),
    ).reset_index())

    display(df_sum.groupby(["N","subject"]).agg(
        files=("file","count"),
        frames=("frames","sum"),
        down=("down","sum"),
        up=("up","sum"),
        eq=("eq","sum"),
    ).reset_index())
# Out:
#     N  files  frames   down     up    eq  total_fill  total_drop
# 0  64    720  114170  28604  84497  1069     2842765      652901
#     N subject  files  frames  down     up   eq
# 0  64       A     72   10459  2787   7574   98
# 1  64       B     72   12224  3030   9080  114
# 2  64       C     72   13890  2692  11087  111
# 3  64       D     72   11861  2514   9235  112
# 4  64       E     72   11102  2931   8074   97
# 5  64       F     72   10424  2682   7639  103
# 6  64       G     72   10532  2766   7685   81
# 7  64       H     72   11352  2599   8646  107
# 8  64       I     72   10993  3589   7277  127
# 9  64       J     72   11333  3014   8200  119
