# %% [markdown]
# Cell 1 — Konfigurasi

# %%
from pathlib import Path

# ====== PATHS ======
DATASET_ROOT = Path(r"E:\0.TA_Teguh\GMM Trial 2")
HEAD1_DIR    = DATASET_ROOT / "Head 1"

FPS_ROOT     = Path(r"E:\0.TA_Teguh\Sampling\FPS")
WRS_ROOT     = Path(r"E:\0.TA_Teguh\Sampling\Weighted")

OUT_DIR      = Path(r"E:\0.TA_Teguh\EvalSampling")
OUT_DIR.mkdir(parents=True, exist_ok=True)

# ====== RUN SCOPE ======
SUBJECTS  = list("ABCDEFGHIJ")
N_TARGETS = [48, 56, 64]     # Anda bisa ubah manual

# ====== EVAL SETTINGS ======
USECOLS = ["frame","x","y","z","doppler"]   # evaluasi pakai ini
ROUND_UNIQUE_DECIMALS = 4                  # untuk hitung unique/duplikasi (stabil untuk float)

# Frame filter opsional (biar cepat dulu saat uji)
MAX_FILES_PER_SUBJECT = None   # mis. 2 untuk test cepat; None = semua
MAX_FRAMES_PER_FILE   = None   # mis. 3000 untuk test cepat; None = semua

print("HEAD1_DIR:", HEAD1_DIR)
print("FPS_ROOT :", FPS_ROOT)
print("WRS_ROOT :", WRS_ROOT)
print("OUT_DIR  :", OUT_DIR)
print("N_TARGETS:", N_TARGETS)
# Out:
# HEAD1_DIR: E:\0.TA_Teguh\GMM Trial 2\Head 1
# FPS_ROOT : E:\0.TA_Teguh\Sampling\FPS
# WRS_ROOT : E:\0.TA_Teguh\Sampling\Weighted
# OUT_DIR  : E:\0.TA_Teguh\EvalSampling
# N_TARGETS: [48, 56, 64]

# %% [markdown]
# Cell 2 — Helper I/O + Validasi file

# %%
import pandas as pd

def list_jalan_files(head1_subject_dir: Path):
    files = sorted([p.name for p in head1_subject_dir.glob("Jalan*.csv")])
    return files

def resolve_paths(subject: str, fname: str, n_target: int):
    base_path = HEAD1_DIR / subject / fname
    fps_path  = FPS_ROOT / f"N{n_target}" / subject / fname
    wrs_path  = WRS_ROOT / f"N{n_target}" / subject / fname
    return base_path, fps_path, wrs_path

def read_points_csv(path: Path) -> pd.DataFrame:
    if not path.exists():
        raise FileNotFoundError(str(path))
    df = pd.read_csv(path, usecols=USECOLS)
    # guard types
    df["frame"] = df["frame"].astype(int)
    return df

# %% [markdown]
# Cell 3 — Core metrik per frame (5 metrik)

# %%
import numpy as np
from sklearn.neighbors import NearestNeighbors

def _to_xyz(df):
    return df[["x","y","z"]].to_numpy(dtype=np.float32)

def _to_xyzd(df):
    return df[["x","y","z","doppler"]].to_numpy(dtype=np.float32)

def centroid_xyz(df):
    X = _to_xyz(df)
    return X.mean(axis=0)

def radial_quantiles(df, mu_xyz, qs=(0.5, 0.9)):
    X = _to_xyz(df)
    r = np.linalg.norm(X - mu_xyz[None, :], axis=1)
    return np.quantile(r, qs)

def nn_p95_baseline_to_sample(df_base, df_samp):
    # Nearest-neighbor distance: for each baseline point, distance to nearest sampled point
    Xb = _to_xyz(df_base)
    Xs = _to_xyz(df_samp)
    if len(Xs) == 0 or len(Xb) == 0:
        return np.nan, np.nan
    nn = NearestNeighbors(n_neighbors=1, algorithm="auto")
    nn.fit(Xs)
    d, _ = nn.kneighbors(Xb, return_distance=True)
    d = d.reshape(-1)
    return float(d.mean()), float(np.quantile(d, 0.95))

def unique_and_maxdup(df_samp, decimals=4):
    """
    Robust unique counting for float point clouds.
    Uses rounding + tuple keys, avoids numpy .view() contiguity issues.
    Unique definition: (x,y,z,doppler) rounded to `decimals`.
    """
    if df_samp is None or len(df_samp) == 0:
        return 0, 0, 0.0

    X = df_samp[["x","y","z","doppler"]].to_numpy(dtype=np.float32, copy=True)
    Xr = np.round(X, decimals=decimals)

    # Build hashable keys per row (safe)
    keys = [tuple(row) for row in Xr]
    # Count duplicates
    from collections import Counter
    c = Counter(keys)

    n_unique = len(c)
    max_dup = max(c.values()) if n_unique > 0 else 0
    unique_ratio = n_unique / len(keys)

    return int(n_unique), int(max_dup), float(unique_ratio)


def frame_metrics(df_base_f, df_samp_f):
    """
    Returns:
      shape_p50_diff, shape_p90_diff,
      centroid_drift,
      nn_mean, nn_p95,
      unique_ratio, max_dup
    """
    if len(df_base_f) == 0:
        return {
            "shape_p50_diff": np.nan, "shape_p90_diff": np.nan,
            "centroid_drift": np.nan,
            "nn_mean": np.nan, "nn_p95": np.nan,
            "unique_ratio": np.nan, "max_dup": np.nan
        }
    if len(df_samp_f) == 0:
        return {
            "shape_p50_diff": np.nan, "shape_p90_diff": np.nan,
            "centroid_drift": np.nan,
            "nn_mean": np.nan, "nn_p95": np.nan,
            "unique_ratio": 0.0, "max_dup": 0
        }

    mu_b = centroid_xyz(df_base_f)
    mu_s = centroid_xyz(df_samp_f)
    centroid_drift = float(np.linalg.norm(mu_s - mu_b))

    # Shape preservation: compare radial quantiles w.r.t baseline centroid
    q_b = radial_quantiles(df_base_f, mu_b, qs=(0.5, 0.9))
    q_s = radial_quantiles(df_samp_f, mu_b, qs=(0.5, 0.9))
    shape_p50_diff = float(abs(q_s[0] - q_b[0]))
    shape_p90_diff = float(abs(q_s[1] - q_b[1]))

    # Coverage: NN baseline -> sample
    nn_mean, nn_p95 = nn_p95_baseline_to_sample(df_base_f, df_samp_f)

    # Dup health (upsampling relevant, but we compute always)
    _, max_dup, unique_ratio = unique_and_maxdup(df_samp_f, decimals=ROUND_UNIQUE_DECIMALS)

    return {
        "shape_p50_diff": shape_p50_diff,
        "shape_p90_diff": shape_p90_diff,
        "centroid_drift": centroid_drift,
        "nn_mean": nn_mean,
        "nn_p95": nn_p95,
        "unique_ratio": unique_ratio,
        "max_dup": max_dup
    }

# %% [markdown]
# Cell 4 — Temporal metric (jitter centroid antar frame)

# %%
def temporal_jitter(df, frames_sorted):
    # std dari ||mu_t - mu_{t-1}|| (centroid step norm)
    mus = []
    for fr in frames_sorted:
        d = df[df["frame"] == fr]
        if len(d) == 0:
            mus.append(None)
        else:
            mus.append(centroid_xyz(d))

    steps = []
    prev = None
    for mu in mus:
        if mu is None:
            prev = None
            continue
        if prev is not None:
            steps.append(float(np.linalg.norm(mu - prev)))
        prev = mu
    if len(steps) == 0:
        return np.nan
    return float(np.std(np.array(steps, dtype=np.float32)))

# %% [markdown]
# Cell 5 — Evaluasi per file (baseline vs FPS vs WRS) + split downsample/upsample

# %%
def evaluate_one_file(subject: str, fname: str, n_target: int):
    base_path, fps_path, wrs_path = resolve_paths(subject, fname, n_target)

    df_b = read_points_csv(base_path)
    df_f = read_points_csv(fps_path)
    df_w = read_points_csv(wrs_path)

    # optional limit frames for quick tests
    if MAX_FRAMES_PER_FILE is not None:
        frames_all = sorted(df_b["frame"].unique())[:MAX_FRAMES_PER_FILE]
        df_b = df_b[df_b["frame"].isin(frames_all)]
        df_f = df_f[df_f["frame"].isin(frames_all)]
        df_w = df_w[df_w["frame"].isin(frames_all)]
    frames = sorted(df_b["frame"].unique())

    # per-frame counts baseline (valid frames baseline)
    cnt_b = df_b.groupby("frame").size().to_dict()

    rows = []
    for fr in frames:
        dbf = df_b[df_b["frame"] == fr]
        dff = df_f[df_f["frame"] == fr]
        dwf = df_w[df_w["frame"] == fr]

        nb = int(len(dbf))
        mode = "equal"
        if nb > n_target: mode = "down"
        elif nb < n_target: mode = "up"

        mf = frame_metrics(dbf, dff)
        mw = frame_metrics(dbf, dwf)

        rows.append({
            "subject": subject, "file": fname, "N_target": n_target, "frame": fr, "mode": mode,
            "base_n": nb,
            # FPS metrics
            "fps_shape_p50_diff": mf["shape_p50_diff"],
            "fps_shape_p90_diff": mf["shape_p90_diff"],
            "fps_centroid_drift": mf["centroid_drift"],
            "fps_nn_mean": mf["nn_mean"],
            "fps_nn_p95": mf["nn_p95"],
            "fps_unique_ratio": mf["unique_ratio"],
            "fps_max_dup": mf["max_dup"],
            # WRS metrics
            "wrs_shape_p50_diff": mw["shape_p50_diff"],
            "wrs_shape_p90_diff": mw["shape_p90_diff"],
            "wrs_centroid_drift": mw["centroid_drift"],
            "wrs_nn_mean": mw["nn_mean"],
            "wrs_nn_p95": mw["nn_p95"],
            "wrs_unique_ratio": mw["unique_ratio"],
            "wrs_max_dup": mw["max_dup"],
        })

    df_frame = pd.DataFrame(rows)

    # temporal jitter (per method)
    jitter_base = temporal_jitter(df_b, frames)
    jitter_fps  = temporal_jitter(df_f, frames)
    jitter_wrs  = temporal_jitter(df_w, frames)

    # aggregate summary (overall + per mode)
    def agg_block(d):
        return {
            "frames": int(d["frame"].nunique()),
            "shape_p50_diff_mean": float(d["fps_shape_p50_diff"].mean()),
            "shape_p90_diff_mean": float(d["fps_shape_p90_diff"].mean()),
            "centroid_drift_mean": float(d["fps_centroid_drift"].mean()),
            "nn_p95_mean": float(d["fps_nn_p95"].mean()),
            "unique_ratio_mean": float(d["fps_unique_ratio"].mean()),
            "max_dup_p95": float(np.nanquantile(d["fps_max_dup"], 0.95)),
        }

    def agg_block_w(d):
        return {
            "frames": int(d["frame"].nunique()),
            "shape_p50_diff_mean": float(d["wrs_shape_p50_diff"].mean()),
            "shape_p90_diff_mean": float(d["wrs_shape_p90_diff"].mean()),
            "centroid_drift_mean": float(d["wrs_centroid_drift"].mean()),
            "nn_p95_mean": float(d["wrs_nn_p95"].mean()),
            "unique_ratio_mean": float(d["wrs_unique_ratio"].mean()),
            "max_dup_p95": float(np.nanquantile(d["wrs_max_dup"], 0.95)),
        }

    # overall
    fps_overall = agg_block(df_frame)
    wrs_overall = agg_block_w(df_frame)

    # by mode
    fps_down = agg_block(df_frame[df_frame["mode"]=="down"]) if (df_frame["mode"]=="down").any() else None
    fps_up   = agg_block(df_frame[df_frame["mode"]=="up"])   if (df_frame["mode"]=="up").any() else None
    wrs_down = agg_block_w(df_frame[df_frame["mode"]=="down"]) if (df_frame["mode"]=="down").any() else None
    wrs_up   = agg_block_w(df_frame[df_frame["mode"]=="up"])   if (df_frame["mode"]=="up").any() else None

    summary = {
        "subject": subject, "file": fname, "N_target": n_target,
        "jitter_base": jitter_base, "jitter_fps": jitter_fps, "jitter_wrs": jitter_wrs,
        "fps_overall": fps_overall, "wrs_overall": wrs_overall,
        "fps_down": fps_down, "fps_up": fps_up,
        "wrs_down": wrs_down, "wrs_up": wrs_up,
    }
    return df_frame, summary

# %% [markdown]
# Cell 6 — Run evaluasi untuk semua subject + semua file + semua N, simpan hasil

# %%
all_summaries = []
all_frames_out = []

for n_target in N_TARGETS:
    for subj in SUBJECTS:
        subj_dir = HEAD1_DIR / subj
        files = list_jalan_files(subj_dir)
        if MAX_FILES_PER_SUBJECT is not None:
            files = files[:MAX_FILES_PER_SUBJECT]

        for fname in files:
            try:
                df_frame, summ = evaluate_one_file(subj, fname, n_target)

                # simpan per-file per-N frame metrics (opsional: besar)
                out_frame_path = OUT_DIR / f"frame_metrics_N{n_target}_{subj}_{fname.replace('.csv','')}.csv"
                df_frame.to_csv(out_frame_path, index=False)

                # siapkan ringkasan tabular untuk agregasi
                def pack(kind, block):
                    if block is None:
                        return None
                    return {
                        "subject": subj, "file": fname, "N_target": n_target, "kind": kind,
                        "frames": block["frames"],
                        "shape_p50_diff_mean": block["shape_p50_diff_mean"],
                        "shape_p90_diff_mean": block["shape_p90_diff_mean"],
                        "centroid_drift_mean": block["centroid_drift_mean"],
                        "nn_p95_mean": block["nn_p95_mean"],
                        "unique_ratio_mean": block["unique_ratio_mean"],
                        "max_dup_p95": block["max_dup_p95"],
                        "jitter_base": summ["jitter_base"],
                        "jitter_fps": summ["jitter_fps"],
                        "jitter_wrs": summ["jitter_wrs"],
                    }

                # FPS blocks
                all_summaries.append(pack("fps_overall", summ["fps_overall"]))
                all_summaries.append(pack("fps_down",    summ["fps_down"]))
                all_summaries.append(pack("fps_up",      summ["fps_up"]))

                # WRS blocks
                bw = summ["wrs_overall"]
                all_summaries.append({
                    "subject": subj, "file": fname, "N_target": n_target, "kind": "wrs_overall",
                    "frames": bw["frames"],
                    "shape_p50_diff_mean": bw["shape_p50_diff_mean"],
                    "shape_p90_diff_mean": bw["shape_p90_diff_mean"],
                    "centroid_drift_mean": bw["centroid_drift_mean"],
                    "nn_p95_mean": bw["nn_p95_mean"],
                    "unique_ratio_mean": bw["unique_ratio_mean"],
                    "max_dup_p95": bw["max_dup_p95"],
                    "jitter_base": summ["jitter_base"],
                    "jitter_fps": summ["jitter_fps"],
                    "jitter_wrs": summ["jitter_wrs"],
                })

                if summ["wrs_down"] is not None:
                    bd = summ["wrs_down"]
                    all_summaries.append({
                        "subject": subj, "file": fname, "N_target": n_target, "kind": "wrs_down",
                        "frames": bd["frames"],
                        "shape_p50_diff_mean": bd["shape_p50_diff_mean"],
                        "shape_p90_diff_mean": bd["shape_p90_diff_mean"],
                        "centroid_drift_mean": bd["centroid_drift_mean"],
                        "nn_p95_mean": bd["nn_p95_mean"],
                        "unique_ratio_mean": bd["unique_ratio_mean"],
                        "max_dup_p95": bd["max_dup_p95"],
                        "jitter_base": summ["jitter_base"],
                        "jitter_fps": summ["jitter_fps"],
                        "jitter_wrs": summ["jitter_wrs"],
                    })

                if summ["wrs_up"] is not None:
                    bu = summ["wrs_up"]
                    all_summaries.append({
                        "subject": subj, "file": fname, "N_target": n_target, "kind": "wrs_up",
                        "frames": bu["frames"],
                        "shape_p50_diff_mean": bu["shape_p50_diff_mean"],
                        "shape_p90_diff_mean": bu["shape_p90_diff_mean"],
                        "centroid_drift_mean": bu["centroid_drift_mean"],
                        "nn_p95_mean": bu["nn_p95_mean"],
                        "unique_ratio_mean": bu["unique_ratio_mean"],
                        "max_dup_p95": bu["max_dup_p95"],
                        "jitter_base": summ["jitter_base"],
                        "jitter_fps": summ["jitter_fps"],
                        "jitter_wrs": summ["jitter_wrs"],
                    })

                print(f"[OK] N{n_target} {subj} {fname}")

            except Exception as e:
                print(f"[SKIP] N{n_target} {subj} {fname} -> {type(e).__name__}: {e}")

df_summary = pd.DataFrame([r for r in all_summaries if r is not None])
out_summary_path = OUT_DIR / "summary_scorecard_all.csv"
df_summary.to_csv(out_summary_path, index=False)

print("Saved:", out_summary_path)
df_summary.head(10)
# Out:
# [OK] N48 A Jalan1.csv
# [OK] N48 A Jalan10.csv
# [OK] N48 A Jalan11.csv
# [OK] N48 A Jalan12.csv
# [OK] N48 A Jalan13.csv
# [OK] N48 A Jalan14.csv
# [OK] N48 A Jalan15.csv
# [OK] N48 A Jalan16.csv
# [OK] N48 A Jalan17.csv
# [OK] N48 A Jalan18.csv
# [OK] N48 A Jalan19.csv
# [OK] N48 A Jalan2.csv
# [OK] N48 A Jalan20.csv
# [OK] N48 A Jalan21.csv
# [OK] N48 A Jalan22.csv
# [OK] N48 A Jalan23.csv
# [OK] N48 A Jalan24.csv
# [OK] N48 A Jalan25.csv
# [OK] N48 A Jalan26.csv
# [OK] N48 A Jalan27.csv
# [OK] N48 A Jalan28.csv
# [OK] N48 A Jalan29.csv
# [OK] N48 A Jalan3.csv
# [OK] N48 A Jalan30.csv
# [OK] N48 A Jalan31.csv
# [OK] N48 A Jalan32.csv
# [OK] N48 A Jalan33.csv
# [OK] N48 A Jalan34.csv
# [OK] N48 A Jalan35.csv
# [OK] N48 A Jalan36.csv
# [OK] N48 A Jalan37.csv
# [OK] N48 A Jalan38.csv
# [OK] N48 A Jalan39.csv
# [OK] N48 A Jalan4.csv
# [OK] N48 A Jalan40.csv
# [OK] N48 A Jalan41.csv
# [OK] N48 A Jalan42.csv
# [OK] N48 A Jalan43.csv
# [OK] N48 A Jalan44.csv
# [OK] N48 A Jalan45.csv
# [OK] N48 A Jalan46.csv
# [OK] N48 A Jalan47.csv
# [OK] N48 A Jalan48.csv
# [OK] N48 A Jalan49.csv
# [OK] N48 A Jalan5.csv
# [OK] N48 A Jalan50.csv
# [OK] N48 A Jalan51.csv
# [OK] N48 A Jalan52.csv
# [OK] N48 A Jalan53.csv
# [OK] N48 A Jalan54.csv
# [OK] N48 A Jalan55.csv
# [OK] N48 A Jalan56.csv
# [OK] N48 A Jalan57.csv
# [OK] N48 A Jalan58.csv
# [OK] N48 A Jalan59.csv
# [OK] N48 A Jalan6.csv
# [OK] N48 A Jalan60.csv
# [OK] N48 A Jalan61.csv
# [OK] N48 A Jalan62.csv
# [OK] N48 A Jalan63.csv
# [OK] N48 A Jalan64.csv
# [OK] N48 A Jalan65.csv
# [OK] N48 A Jalan66.csv
# [OK] N48 A Jalan67.csv
# [OK] N48 A Jalan68.csv
# [OK] N48 A Jalan69.csv
# [OK] N48 A Jalan7.csv
# [OK] N48 A Jalan70.csv
# [OK] N48 A Jalan71.csv
# [OK] N48 A Jalan72.csv
# [OK] N48 A Jalan8.csv
# [OK] N48 A Jalan9.csv
# [OK] N48 B Jalan1.csv
# [OK] N48 B Jalan10.csv
# [OK] N48 B Jalan11.csv
# [OK] N48 B Jalan12.csv
# [OK] N48 B Jalan13.csv
# [OK] N48 B Jalan14.csv
# [OK] N48 B Jalan15.csv
# [OK] N48 B Jalan16.csv
# [OK] N48 B Jalan17.csv
# [OK] N48 B Jalan18.csv
# [OK] N48 B Jalan19.csv
# [OK] N48 B Jalan2.csv
# [OK] N48 B Jalan20.csv
# [OK] N48 B Jalan21.csv
# [OK] N48 B Jalan22.csv
# [OK] N48 B Jalan23.csv
# [OK] N48 B Jalan24.csv
# [OK] N48 B Jalan25.csv
# [OK] N48 B Jalan26.csv
# [OK] N48 B Jalan27.csv
# [OK] N48 B Jalan28.csv
# [OK] N48 B Jalan29.csv
# [OK] N48 B Jalan3.csv
# [OK] N48 B Jalan30.csv
# [OK] N48 B Jalan31.csv
# [OK] N48 B Jalan32.csv
# [OK] N48 B Jalan33.csv
# [OK] N48 B Jalan34.csv
# [OK] N48 B Jalan35.csv
# [OK] N48 B Jalan36.csv
# [OK] N48 B Jalan37.csv
# [OK] N48 B Jalan38.csv
# [OK] N48 B Jalan39.csv
# [OK] N48 B Jalan4.csv
# [OK] N48 B Jalan40.csv
# [OK] N48 B Jalan41.csv
# [OK] N48 B Jalan42.csv
# [OK] N48 B Jalan43.csv
# [OK] N48 B Jalan44.csv
# [OK] N48 B Jalan45.csv
# [OK] N48 B Jalan46.csv
# [OK] N48 B Jalan47.csv
# [OK] N48 B Jalan48.csv
# [OK] N48 B Jalan49.csv
# [OK] N48 B Jalan5.csv
# [OK] N48 B Jalan50.csv
# [OK] N48 B Jalan51.csv
# [OK] N48 B Jalan52.csv
# [OK] N48 B Jalan53.csv
# [OK] N48 B Jalan54.csv
# [OK] N48 B Jalan55.csv
# [OK] N48 B Jalan56.csv
# [OK] N48 B Jalan57.csv
# [OK] N48 B Jalan58.csv
# [OK] N48 B Jalan59.csv
# [OK] N48 B Jalan6.csv
# [OK] N48 B Jalan60.csv
# [OK] N48 B Jalan61.csv
# [OK] N48 B Jalan62.csv
# [OK] N48 B Jalan63.csv
# [OK] N48 B Jalan64.csv
# [OK] N48 B Jalan65.csv
# [OK] N48 B Jalan66.csv
# [OK] N48 B Jalan67.csv
# [OK] N48 B Jalan68.csv
# [OK] N48 B Jalan69.csv
# [OK] N48 B Jalan7.csv
# [OK] N48 B Jalan70.csv
# [OK] N48 B Jalan71.csv
# [OK] N48 B Jalan72.csv
# [OK] N48 B Jalan8.csv
# [OK] N48 B Jalan9.csv
# [OK] N48 C Jalan1.csv
# [OK] N48 C Jalan10.csv
# [OK] N48 C Jalan11.csv
# [OK] N48 C Jalan12.csv
# [OK] N48 C Jalan13.csv
# [OK] N48 C Jalan14.csv
# [OK] N48 C Jalan15.csv
# [OK] N48 C Jalan16.csv
# [OK] N48 C Jalan17.csv
# [OK] N48 C Jalan18.csv
# [OK] N48 C Jalan19.csv
# [OK] N48 C Jalan2.csv
# [OK] N48 C Jalan20.csv
# [OK] N48 C Jalan21.csv
# [OK] N48 C Jalan22.csv
# [OK] N48 C Jalan23.csv
# [OK] N48 C Jalan24.csv
# [OK] N48 C Jalan25.csv
# [OK] N48 C Jalan26.csv
# [OK] N48 C Jalan27.csv
# [OK] N48 C Jalan28.csv
# [OK] N48 C Jalan29.csv
# [OK] N48 C Jalan3.csv
# [OK] N48 C Jalan30.csv
# [OK] N48 C Jalan31.csv
# [OK] N48 C Jalan32.csv
# [OK] N48 C Jalan33.csv
# [OK] N48 C Jalan34.csv
# [OK] N48 C Jalan35.csv
# [OK] N48 C Jalan36.csv
# [OK] N48 C Jalan37.csv
# [OK] N48 C Jalan38.csv
# [OK] N48 C Jalan39.csv
# [OK] N48 C Jalan4.csv
# [OK] N48 C Jalan40.csv
# [OK] N48 C Jalan41.csv
# [OK] N48 C Jalan42.csv
# [OK] N48 C Jalan43.csv
# [OK] N48 C Jalan44.csv
# [OK] N48 C Jalan45.csv
# [OK] N48 C Jalan46.csv
# [OK] N48 C Jalan47.csv
# [OK] N48 C Jalan48.csv
# [OK] N48 C Jalan49.csv
# [OK] N48 C Jalan5.csv
# [OK] N48 C Jalan50.csv
# [OK] N48 C Jalan51.csv
# [OK] N48 C Jalan52.csv
# [OK] N48 C Jalan53.csv
# [OK] N48 C Jalan54.csv
# [OK] N48 C Jalan55.csv
# [OK] N48 C Jalan56.csv
# [OK] N48 C Jalan57.csv
# [OK] N48 C Jalan58.csv
# [OK] N48 C Jalan59.csv
# [OK] N48 C Jalan6.csv
# [OK] N48 C Jalan60.csv
# [OK] N48 C Jalan61.csv
# [OK] N48 C Jalan62.csv
# [OK] N48 C Jalan63.csv
# [OK] N48 C Jalan64.csv
# [OK] N48 C Jalan65.csv
# [OK] N48 C Jalan66.csv
# [OK] N48 C Jalan67.csv
# [OK] N48 C Jalan68.csv
# [OK] N48 C Jalan69.csv
# [OK] N48 C Jalan7.csv
# [OK] N48 C Jalan70.csv
# [OK] N48 C Jalan71.csv
# [OK] N48 C Jalan72.csv
# [OK] N48 C Jalan8.csv
# [OK] N48 C Jalan9.csv
# [OK] N48 D Jalan1.csv
# [OK] N48 D Jalan10.csv
# [OK] N48 D Jalan11.csv
# [OK] N48 D Jalan12.csv
# [OK] N48 D Jalan13.csv
# [OK] N48 D Jalan14.csv
# [OK] N48 D Jalan15.csv
# [OK] N48 D Jalan16.csv
# [OK] N48 D Jalan17.csv
# [OK] N48 D Jalan18.csv
# [OK] N48 D Jalan19.csv
# [OK] N48 D Jalan2.csv
# [OK] N48 D Jalan20.csv
# [OK] N48 D Jalan21.csv
# [OK] N48 D Jalan22.csv
# [OK] N48 D Jalan23.csv
# [OK] N48 D Jalan24.csv
# [OK] N48 D Jalan25.csv
# [OK] N48 D Jalan26.csv
# [OK] N48 D Jalan27.csv
# [OK] N48 D Jalan28.csv
# [OK] N48 D Jalan29.csv
# [OK] N48 D Jalan3.csv
# [OK] N48 D Jalan30.csv
# [OK] N48 D Jalan31.csv
# [OK] N48 D Jalan32.csv
# [OK] N48 D Jalan33.csv
# [OK] N48 D Jalan34.csv
# [OK] N48 D Jalan35.csv
# [OK] N48 D Jalan36.csv
# [OK] N48 D Jalan37.csv
# [OK] N48 D Jalan38.csv
# [OK] N48 D Jalan39.csv
# [OK] N48 D Jalan4.csv
# [OK] N48 D Jalan40.csv
# [OK] N48 D Jalan41.csv
# [OK] N48 D Jalan42.csv
# [OK] N48 D Jalan43.csv
# [OK] N48 D Jalan44.csv
# [OK] N48 D Jalan45.csv
# [OK] N48 D Jalan46.csv
# [OK] N48 D Jalan47.csv
# [OK] N48 D Jalan48.csv
# [OK] N48 D Jalan49.csv
# [OK] N48 D Jalan5.csv
# [OK] N48 D Jalan50.csv
# [OK] N48 D Jalan51.csv
# [OK] N48 D Jalan52.csv
# [OK] N48 D Jalan53.csv
# [OK] N48 D Jalan54.csv
# [OK] N48 D Jalan55.csv
# [OK] N48 D Jalan56.csv
# [OK] N48 D Jalan57.csv
# [OK] N48 D Jalan58.csv
# [OK] N48 D Jalan59.csv
# [OK] N48 D Jalan6.csv
# [OK] N48 D Jalan60.csv
# [OK] N48 D Jalan61.csv
# [OK] N48 D Jalan62.csv
# [OK] N48 D Jalan63.csv
# [OK] N48 D Jalan64.csv
# [OK] N48 D Jalan65.csv
# [OK] N48 D Jalan66.csv
# [OK] N48 D Jalan67.csv
# [OK] N48 D Jalan68.csv
# [OK] N48 D Jalan69.csv
# [OK] N48 D Jalan7.csv
# [OK] N48 D Jalan70.csv
# [OK] N48 D Jalan71.csv
# [OK] N48 D Jalan72.csv
# [OK] N48 D Jalan8.csv
# [OK] N48 D Jalan9.csv
# [OK] N48 E Jalan1.csv
# [OK] N48 E Jalan10.csv
# [OK] N48 E Jalan11.csv
# [OK] N48 E Jalan12.csv
# [OK] N48 E Jalan13.csv
# [OK] N48 E Jalan14.csv
# [OK] N48 E Jalan15.csv
# [OK] N48 E Jalan16.csv
# [OK] N48 E Jalan17.csv
# [OK] N48 E Jalan18.csv
# [OK] N48 E Jalan19.csv
# [OK] N48 E Jalan2.csv
# [OK] N48 E Jalan20.csv
# [OK] N48 E Jalan21.csv
# [OK] N48 E Jalan22.csv
# [OK] N48 E Jalan23.csv
# [OK] N48 E Jalan24.csv
# [OK] N48 E Jalan25.csv
# [OK] N48 E Jalan26.csv
# [OK] N48 E Jalan27.csv
# [OK] N48 E Jalan28.csv
# [OK] N48 E Jalan29.csv
# [OK] N48 E Jalan3.csv
# [OK] N48 E Jalan30.csv
# [OK] N48 E Jalan31.csv
# [OK] N48 E Jalan32.csv
# [OK] N48 E Jalan33.csv
# [OK] N48 E Jalan34.csv
# [OK] N48 E Jalan35.csv
# [OK] N48 E Jalan36.csv
# [OK] N48 E Jalan37.csv
# [OK] N48 E Jalan38.csv
# [OK] N48 E Jalan39.csv
# [OK] N48 E Jalan4.csv
# [OK] N48 E Jalan40.csv
# [OK] N48 E Jalan41.csv
# [OK] N48 E Jalan42.csv
# [OK] N48 E Jalan43.csv
# [OK] N48 E Jalan44.csv
# [OK] N48 E Jalan45.csv
# [OK] N48 E Jalan46.csv
# [OK] N48 E Jalan47.csv
# [OK] N48 E Jalan48.csv
# [OK] N48 E Jalan49.csv
# [OK] N48 E Jalan5.csv
# [OK] N48 E Jalan50.csv
# [OK] N48 E Jalan51.csv
# [OK] N48 E Jalan52.csv
# [OK] N48 E Jalan53.csv
# [OK] N48 E Jalan54.csv
# [OK] N48 E Jalan55.csv
# [OK] N48 E Jalan56.csv
# [OK] N48 E Jalan57.csv
# [OK] N48 E Jalan58.csv
# [OK] N48 E Jalan59.csv
# [OK] N48 E Jalan6.csv
# [OK] N48 E Jalan60.csv
# [OK] N48 E Jalan61.csv
# [OK] N48 E Jalan62.csv
# [OK] N48 E Jalan63.csv
# [OK] N48 E Jalan64.csv
# [OK] N48 E Jalan65.csv
# [OK] N48 E Jalan66.csv
# [OK] N48 E Jalan67.csv
# [OK] N48 E Jalan68.csv
# [OK] N48 E Jalan69.csv
# [OK] N48 E Jalan7.csv
# [OK] N48 E Jalan70.csv
# [OK] N48 E Jalan71.csv
# [OK] N48 E Jalan72.csv
# [OK] N48 E Jalan8.csv
# [OK] N48 E Jalan9.csv
# [OK] N48 F Jalan1.csv
# [OK] N48 F Jalan10.csv
# [OK] N48 F Jalan11.csv
# [OK] N48 F Jalan12.csv
# [OK] N48 F Jalan13.csv
# [OK] N48 F Jalan14.csv
# [OK] N48 F Jalan15.csv
# [OK] N48 F Jalan16.csv
# [OK] N48 F Jalan17.csv
# [OK] N48 F Jalan18.csv
# [OK] N48 F Jalan19.csv
# [OK] N48 F Jalan2.csv
# [OK] N48 F Jalan20.csv
# [OK] N48 F Jalan21.csv
# [OK] N48 F Jalan22.csv
# [OK] N48 F Jalan23.csv
# [OK] N48 F Jalan24.csv
# [OK] N48 F Jalan25.csv
# [OK] N48 F Jalan26.csv
# [OK] N48 F Jalan27.csv
# [OK] N48 F Jalan28.csv
# [OK] N48 F Jalan29.csv
# [OK] N48 F Jalan3.csv
# [OK] N48 F Jalan30.csv
# [OK] N48 F Jalan31.csv
# [OK] N48 F Jalan32.csv
# [OK] N48 F Jalan33.csv
# [OK] N48 F Jalan34.csv
# [OK] N48 F Jalan35.csv
# [OK] N48 F Jalan36.csv
# [OK] N48 F Jalan37.csv
# [OK] N48 F Jalan38.csv
# [OK] N48 F Jalan39.csv
# [OK] N48 F Jalan4.csv
# [OK] N48 F Jalan40.csv
# [OK] N48 F Jalan41.csv
# [OK] N48 F Jalan42.csv
# [OK] N48 F Jalan43.csv
# [OK] N48 F Jalan44.csv
# [OK] N48 F Jalan45.csv
# [OK] N48 F Jalan46.csv
# [OK] N48 F Jalan47.csv
# [OK] N48 F Jalan48.csv
# [OK] N48 F Jalan49.csv
# [OK] N48 F Jalan5.csv
# [OK] N48 F Jalan50.csv
# [OK] N48 F Jalan51.csv
# [OK] N48 F Jalan52.csv
# [OK] N48 F Jalan53.csv
# [OK] N48 F Jalan54.csv
# [OK] N48 F Jalan55.csv
# [OK] N48 F Jalan56.csv
# [OK] N48 F Jalan57.csv
# [OK] N48 F Jalan58.csv
# [OK] N48 F Jalan59.csv
# [OK] N48 F Jalan6.csv
# [OK] N48 F Jalan60.csv
# [OK] N48 F Jalan61.csv
# [OK] N48 F Jalan62.csv
# [OK] N48 F Jalan63.csv
# [OK] N48 F Jalan64.csv
# [OK] N48 F Jalan65.csv
# [OK] N48 F Jalan66.csv
# [OK] N48 F Jalan67.csv
# [OK] N48 F Jalan68.csv
# [OK] N48 F Jalan69.csv
# [OK] N48 F Jalan7.csv
# [OK] N48 F Jalan70.csv
# [OK] N48 F Jalan71.csv
# [OK] N48 F Jalan72.csv
# [OK] N48 F Jalan8.csv
# [OK] N48 F Jalan9.csv
# [OK] N48 G Jalan1.csv
# [OK] N48 G Jalan10.csv
# [OK] N48 G Jalan11.csv
# [OK] N48 G Jalan12.csv
# [OK] N48 G Jalan13.csv
# [OK] N48 G Jalan14.csv
# [OK] N48 G Jalan15.csv
# [OK] N48 G Jalan16.csv
# [OK] N48 G Jalan17.csv
# [OK] N48 G Jalan18.csv
# [OK] N48 G Jalan19.csv
# [OK] N48 G Jalan2.csv
# [OK] N48 G Jalan20.csv
# [OK] N48 G Jalan21.csv
# [OK] N48 G Jalan22.csv
# [OK] N48 G Jalan23.csv
# [OK] N48 G Jalan24.csv
# [OK] N48 G Jalan25.csv
# [OK] N48 G Jalan26.csv
# [OK] N48 G Jalan27.csv
# [OK] N48 G Jalan28.csv
# [OK] N48 G Jalan29.csv
# [OK] N48 G Jalan3.csv
# [OK] N48 G Jalan30.csv
# [OK] N48 G Jalan31.csv
# [OK] N48 G Jalan32.csv
# [OK] N48 G Jalan33.csv
# [OK] N48 G Jalan34.csv
# [OK] N48 G Jalan35.csv
# [OK] N48 G Jalan36.csv
# [OK] N48 G Jalan37.csv
# [OK] N48 G Jalan38.csv
# [OK] N48 G Jalan39.csv
# [OK] N48 G Jalan4.csv
# [OK] N48 G Jalan40.csv
# [OK] N48 G Jalan41.csv
# [OK] N48 G Jalan42.csv
# [OK] N48 G Jalan43.csv
# [OK] N48 G Jalan44.csv
# [OK] N48 G Jalan45.csv
# [OK] N48 G Jalan46.csv
# [OK] N48 G Jalan47.csv
# [OK] N48 G Jalan48.csv
# [OK] N48 G Jalan49.csv
# [OK] N48 G Jalan5.csv
# [OK] N48 G Jalan50.csv
# [OK] N48 G Jalan51.csv
# [OK] N48 G Jalan52.csv
# [OK] N48 G Jalan53.csv
# [OK] N48 G Jalan54.csv
# [OK] N48 G Jalan55.csv
# [OK] N48 G Jalan56.csv
# [OK] N48 G Jalan57.csv
# [OK] N48 G Jalan58.csv
# [OK] N48 G Jalan59.csv
# [OK] N48 G Jalan6.csv
# [OK] N48 G Jalan60.csv
# [OK] N48 G Jalan61.csv
# [OK] N48 G Jalan62.csv
# [OK] N48 G Jalan63.csv
# [OK] N48 G Jalan64.csv
# [OK] N48 G Jalan65.csv
# [OK] N48 G Jalan66.csv
# [OK] N48 G Jalan67.csv
# [OK] N48 G Jalan68.csv
# [OK] N48 G Jalan69.csv
# [OK] N48 G Jalan7.csv
# [OK] N48 G Jalan70.csv
# [OK] N48 G Jalan71.csv
# [OK] N48 G Jalan72.csv
# [OK] N48 G Jalan8.csv
# [OK] N48 G Jalan9.csv
# [OK] N48 H Jalan1.csv
# [OK] N48 H Jalan10.csv
# [OK] N48 H Jalan11.csv
# [OK] N48 H Jalan12.csv
# [OK] N48 H Jalan13.csv
# [OK] N48 H Jalan14.csv
# [OK] N48 H Jalan15.csv
# [OK] N48 H Jalan16.csv
# [OK] N48 H Jalan17.csv
# [OK] N48 H Jalan18.csv
# [OK] N48 H Jalan19.csv
# [OK] N48 H Jalan2.csv
# [OK] N48 H Jalan20.csv
# [OK] N48 H Jalan21.csv
# [OK] N48 H Jalan22.csv
# [OK] N48 H Jalan23.csv
# [OK] N48 H Jalan24.csv
# [OK] N48 H Jalan25.csv
# [OK] N48 H Jalan26.csv
# [OK] N48 H Jalan27.csv
# [OK] N48 H Jalan28.csv
# [OK] N48 H Jalan29.csv
# [OK] N48 H Jalan3.csv
# [OK] N48 H Jalan30.csv
# [OK] N48 H Jalan31.csv
# [OK] N48 H Jalan32.csv
# [OK] N48 H Jalan33.csv
# [OK] N48 H Jalan34.csv
# [OK] N48 H Jalan35.csv
# [OK] N48 H Jalan36.csv
# [OK] N48 H Jalan37.csv
# [OK] N48 H Jalan38.csv
# [OK] N48 H Jalan39.csv
# [OK] N48 H Jalan4.csv
# [OK] N48 H Jalan40.csv
# [OK] N48 H Jalan41.csv
# [OK] N48 H Jalan42.csv
# [OK] N48 H Jalan43.csv
# [OK] N48 H Jalan44.csv
# [OK] N48 H Jalan45.csv
# [OK] N48 H Jalan46.csv
# [OK] N48 H Jalan47.csv
# [OK] N48 H Jalan48.csv
# [OK] N48 H Jalan49.csv
# [OK] N48 H Jalan5.csv
# [OK] N48 H Jalan50.csv
# [OK] N48 H Jalan51.csv
# [OK] N48 H Jalan52.csv
# [OK] N48 H Jalan53.csv
# [OK] N48 H Jalan54.csv
# [OK] N48 H Jalan55.csv
# [OK] N48 H Jalan56.csv
# [OK] N48 H Jalan57.csv
# [OK] N48 H Jalan58.csv
# [OK] N48 H Jalan59.csv
# [OK] N48 H Jalan6.csv
# [OK] N48 H Jalan60.csv
# [OK] N48 H Jalan61.csv
# [OK] N48 H Jalan62.csv
# [OK] N48 H Jalan63.csv
# [OK] N48 H Jalan64.csv
# [OK] N48 H Jalan65.csv
# [OK] N48 H Jalan66.csv
# [OK] N48 H Jalan67.csv
# [OK] N48 H Jalan68.csv
# [OK] N48 H Jalan69.csv
# [OK] N48 H Jalan7.csv
# [OK] N48 H Jalan70.csv
# [OK] N48 H Jalan71.csv
# [OK] N48 H Jalan72.csv
# [OK] N48 H Jalan8.csv
# [OK] N48 H Jalan9.csv
# [OK] N48 I Jalan1.csv
# [OK] N48 I Jalan10.csv
# [OK] N48 I Jalan11.csv
# [OK] N48 I Jalan12.csv
# [OK] N48 I Jalan13.csv
# [OK] N48 I Jalan14.csv
# [OK] N48 I Jalan15.csv
# [OK] N48 I Jalan16.csv
# [OK] N48 I Jalan17.csv
# [OK] N48 I Jalan18.csv
# [OK] N48 I Jalan19.csv
# [OK] N48 I Jalan2.csv
# [OK] N48 I Jalan20.csv
# [OK] N48 I Jalan21.csv
# [OK] N48 I Jalan22.csv
# [OK] N48 I Jalan23.csv
# [OK] N48 I Jalan24.csv
# [OK] N48 I Jalan25.csv
# [OK] N48 I Jalan26.csv
# [OK] N48 I Jalan27.csv
# [OK] N48 I Jalan28.csv
# [OK] N48 I Jalan29.csv
# [OK] N48 I Jalan3.csv
# [OK] N48 I Jalan30.csv
# [OK] N48 I Jalan31.csv
# [OK] N48 I Jalan32.csv
# [OK] N48 I Jalan33.csv
# [OK] N48 I Jalan34.csv
# [OK] N48 I Jalan35.csv
# [OK] N48 I Jalan36.csv
# [OK] N48 I Jalan37.csv
# [OK] N48 I Jalan38.csv
# [OK] N48 I Jalan39.csv
# [OK] N48 I Jalan4.csv
# [OK] N48 I Jalan40.csv
# [OK] N48 I Jalan41.csv
# [OK] N48 I Jalan42.csv
# [OK] N48 I Jalan43.csv
# [OK] N48 I Jalan44.csv
# [OK] N48 I Jalan45.csv
# [OK] N48 I Jalan46.csv
# [OK] N48 I Jalan47.csv
# [OK] N48 I Jalan48.csv
# [OK] N48 I Jalan49.csv
# [OK] N48 I Jalan5.csv
# [OK] N48 I Jalan50.csv
# [OK] N48 I Jalan51.csv
# [OK] N48 I Jalan52.csv
# [OK] N48 I Jalan53.csv
# [OK] N48 I Jalan54.csv
# [OK] N48 I Jalan55.csv
# [OK] N48 I Jalan56.csv
# [OK] N48 I Jalan57.csv
# [OK] N48 I Jalan58.csv
# [OK] N48 I Jalan59.csv
# [OK] N48 I Jalan6.csv
# [OK] N48 I Jalan60.csv
# [OK] N48 I Jalan61.csv
# [OK] N48 I Jalan62.csv
# [OK] N48 I Jalan63.csv
# [OK] N48 I Jalan64.csv
# [OK] N48 I Jalan65.csv
# [OK] N48 I Jalan66.csv
# [OK] N48 I Jalan67.csv
# [OK] N48 I Jalan68.csv
# [OK] N48 I Jalan69.csv
# [OK] N48 I Jalan7.csv
# [OK] N48 I Jalan70.csv
# [OK] N48 I Jalan71.csv
# [OK] N48 I Jalan72.csv
# [OK] N48 I Jalan8.csv
# [OK] N48 I Jalan9.csv
# [OK] N48 J Jalan1.csv
# [OK] N48 J Jalan10.csv
# [OK] N48 J Jalan11.csv
# [OK] N48 J Jalan12.csv
# [OK] N48 J Jalan13.csv
# [OK] N48 J Jalan14.csv
# [OK] N48 J Jalan15.csv
# [OK] N48 J Jalan16.csv
# [OK] N48 J Jalan17.csv
# [OK] N48 J Jalan18.csv
# [OK] N48 J Jalan19.csv
# [OK] N48 J Jalan2.csv
# [OK] N48 J Jalan20.csv
# [OK] N48 J Jalan21.csv
# [OK] N48 J Jalan22.csv
# [OK] N48 J Jalan23.csv
# [OK] N48 J Jalan24.csv
# [OK] N48 J Jalan25.csv
# [OK] N48 J Jalan26.csv
# [OK] N48 J Jalan27.csv
# [OK] N48 J Jalan28.csv
# [OK] N48 J Jalan29.csv
# [OK] N48 J Jalan3.csv
# [OK] N48 J Jalan30.csv
# [OK] N48 J Jalan31.csv
# [OK] N48 J Jalan32.csv
# [OK] N48 J Jalan33.csv
# [OK] N48 J Jalan34.csv
# [OK] N48 J Jalan35.csv
# [OK] N48 J Jalan36.csv
# [OK] N48 J Jalan37.csv
# [OK] N48 J Jalan38.csv
# [OK] N48 J Jalan39.csv
# [OK] N48 J Jalan4.csv
# [OK] N48 J Jalan40.csv
# [OK] N48 J Jalan41.csv
# [OK] N48 J Jalan42.csv
# [OK] N48 J Jalan43.csv
# [OK] N48 J Jalan44.csv
# [OK] N48 J Jalan45.csv
# [OK] N48 J Jalan46.csv
# [OK] N48 J Jalan47.csv
# [OK] N48 J Jalan48.csv
# [OK] N48 J Jalan49.csv
# [OK] N48 J Jalan5.csv
# [OK] N48 J Jalan50.csv
# [OK] N48 J Jalan51.csv
# [OK] N48 J Jalan52.csv
# [OK] N48 J Jalan53.csv
# [OK] N48 J Jalan54.csv
# [OK] N48 J Jalan55.csv
# [OK] N48 J Jalan56.csv
# [OK] N48 J Jalan57.csv
# [OK] N48 J Jalan58.csv
# [OK] N48 J Jalan59.csv
# [OK] N48 J Jalan6.csv
# [OK] N48 J Jalan60.csv
# [OK] N48 J Jalan61.csv
# [OK] N48 J Jalan62.csv
# [OK] N48 J Jalan63.csv
# [OK] N48 J Jalan64.csv
# [OK] N48 J Jalan65.csv
# [OK] N48 J Jalan66.csv
# [OK] N48 J Jalan67.csv
# [OK] N48 J Jalan68.csv
# [OK] N48 J Jalan69.csv
# [OK] N48 J Jalan7.csv
# [OK] N48 J Jalan70.csv
# [OK] N48 J Jalan71.csv
# [OK] N48 J Jalan72.csv
# [OK] N48 J Jalan8.csv
# [OK] N48 J Jalan9.csv
# [OK] N56 A Jalan1.csv
# [OK] N56 A Jalan10.csv
# [OK] N56 A Jalan11.csv
# [OK] N56 A Jalan12.csv
# [OK] N56 A Jalan13.csv
# [OK] N56 A Jalan14.csv
# [OK] N56 A Jalan15.csv
# [OK] N56 A Jalan16.csv
# [OK] N56 A Jalan17.csv
# [OK] N56 A Jalan18.csv
# [OK] N56 A Jalan19.csv
# [OK] N56 A Jalan2.csv
# [OK] N56 A Jalan20.csv
# [OK] N56 A Jalan21.csv
# [OK] N56 A Jalan22.csv
# [OK] N56 A Jalan23.csv
# [OK] N56 A Jalan24.csv
# [OK] N56 A Jalan25.csv
# [OK] N56 A Jalan26.csv
# [OK] N56 A Jalan27.csv
# [OK] N56 A Jalan28.csv
# [OK] N56 A Jalan29.csv
# [OK] N56 A Jalan3.csv
# [OK] N56 A Jalan30.csv
# [OK] N56 A Jalan31.csv
# [OK] N56 A Jalan32.csv
# [OK] N56 A Jalan33.csv
# [OK] N56 A Jalan34.csv
# [OK] N56 A Jalan35.csv
# [OK] N56 A Jalan36.csv
# [OK] N56 A Jalan37.csv
# [OK] N56 A Jalan38.csv
# [OK] N56 A Jalan39.csv
# [OK] N56 A Jalan4.csv
# [OK] N56 A Jalan40.csv
# [OK] N56 A Jalan41.csv
# [OK] N56 A Jalan42.csv
# [OK] N56 A Jalan43.csv
# [OK] N56 A Jalan44.csv
# [OK] N56 A Jalan45.csv
# [OK] N56 A Jalan46.csv
# [OK] N56 A Jalan47.csv
# [OK] N56 A Jalan48.csv
# [OK] N56 A Jalan49.csv
# [OK] N56 A Jalan5.csv
# [OK] N56 A Jalan50.csv
# [OK] N56 A Jalan51.csv
# [OK] N56 A Jalan52.csv
# [OK] N56 A Jalan53.csv
# [OK] N56 A Jalan54.csv
# [OK] N56 A Jalan55.csv
# [OK] N56 A Jalan56.csv
# [OK] N56 A Jalan57.csv
# [OK] N56 A Jalan58.csv
# [OK] N56 A Jalan59.csv
# [OK] N56 A Jalan6.csv
# [OK] N56 A Jalan60.csv
# [OK] N56 A Jalan61.csv
# [OK] N56 A Jalan62.csv
# [OK] N56 A Jalan63.csv
# [OK] N56 A Jalan64.csv
# [OK] N56 A Jalan65.csv
# [OK] N56 A Jalan66.csv
# [OK] N56 A Jalan67.csv
# [OK] N56 A Jalan68.csv
# [OK] N56 A Jalan69.csv
# [OK] N56 A Jalan7.csv
# [OK] N56 A Jalan70.csv
# [OK] N56 A Jalan71.csv
# [OK] N56 A Jalan72.csv
# [OK] N56 A Jalan8.csv
# [OK] N56 A Jalan9.csv
# [OK] N56 B Jalan1.csv
# [OK] N56 B Jalan10.csv
# [OK] N56 B Jalan11.csv
# [OK] N56 B Jalan12.csv
# [OK] N56 B Jalan13.csv
# [OK] N56 B Jalan14.csv
# [OK] N56 B Jalan15.csv
# [OK] N56 B Jalan16.csv
# [OK] N56 B Jalan17.csv
# [OK] N56 B Jalan18.csv
# [OK] N56 B Jalan19.csv
# [OK] N56 B Jalan2.csv
# [OK] N56 B Jalan20.csv
# [OK] N56 B Jalan21.csv
# [OK] N56 B Jalan22.csv
# [OK] N56 B Jalan23.csv
# [OK] N56 B Jalan24.csv
# [OK] N56 B Jalan25.csv
# [OK] N56 B Jalan26.csv
# [OK] N56 B Jalan27.csv
# [OK] N56 B Jalan28.csv
# [OK] N56 B Jalan29.csv
# [OK] N56 B Jalan3.csv
# [OK] N56 B Jalan30.csv
# [OK] N56 B Jalan31.csv
# [OK] N56 B Jalan32.csv
# [OK] N56 B Jalan33.csv
# [OK] N56 B Jalan34.csv
# [OK] N56 B Jalan35.csv
# [OK] N56 B Jalan36.csv
# [OK] N56 B Jalan37.csv
# [OK] N56 B Jalan38.csv
# [OK] N56 B Jalan39.csv
# [OK] N56 B Jalan4.csv
# [OK] N56 B Jalan40.csv
# [OK] N56 B Jalan41.csv
# [OK] N56 B Jalan42.csv
# [OK] N56 B Jalan43.csv
# [OK] N56 B Jalan44.csv
# [OK] N56 B Jalan45.csv
# [OK] N56 B Jalan46.csv
# [OK] N56 B Jalan47.csv
# [OK] N56 B Jalan48.csv
# [OK] N56 B Jalan49.csv
# [OK] N56 B Jalan5.csv
# [OK] N56 B Jalan50.csv
# [OK] N56 B Jalan51.csv
# [OK] N56 B Jalan52.csv
# [OK] N56 B Jalan53.csv
# [OK] N56 B Jalan54.csv
# [OK] N56 B Jalan55.csv
# [OK] N56 B Jalan56.csv
# [OK] N56 B Jalan57.csv
# [OK] N56 B Jalan58.csv
# [OK] N56 B Jalan59.csv
# [OK] N56 B Jalan6.csv
# [OK] N56 B Jalan60.csv
# [OK] N56 B Jalan61.csv
# [OK] N56 B Jalan62.csv
# [OK] N56 B Jalan63.csv
# [OK] N56 B Jalan64.csv
# [OK] N56 B Jalan65.csv
# [OK] N56 B Jalan66.csv
# [OK] N56 B Jalan67.csv
# [OK] N56 B Jalan68.csv
# [OK] N56 B Jalan69.csv
# [OK] N56 B Jalan7.csv
# [OK] N56 B Jalan70.csv
# [OK] N56 B Jalan71.csv
# [OK] N56 B Jalan72.csv
# [OK] N56 B Jalan8.csv
# [OK] N56 B Jalan9.csv
# [OK] N56 C Jalan1.csv
# [OK] N56 C Jalan10.csv
# [OK] N56 C Jalan11.csv
# [OK] N56 C Jalan12.csv
# [OK] N56 C Jalan13.csv
# [OK] N56 C Jalan14.csv
# [OK] N56 C Jalan15.csv
# [OK] N56 C Jalan16.csv
# [OK] N56 C Jalan17.csv
# [OK] N56 C Jalan18.csv
# [OK] N56 C Jalan19.csv
# [OK] N56 C Jalan2.csv
# [OK] N56 C Jalan20.csv
# [OK] N56 C Jalan21.csv
# [OK] N56 C Jalan22.csv
# [OK] N56 C Jalan23.csv
# [OK] N56 C Jalan24.csv
# [OK] N56 C Jalan25.csv
# [OK] N56 C Jalan26.csv
# [OK] N56 C Jalan27.csv
# [OK] N56 C Jalan28.csv
# [OK] N56 C Jalan29.csv
# [OK] N56 C Jalan3.csv
# [OK] N56 C Jalan30.csv
# [OK] N56 C Jalan31.csv
# [OK] N56 C Jalan32.csv
# [OK] N56 C Jalan33.csv
# [OK] N56 C Jalan34.csv
# [OK] N56 C Jalan35.csv
# [OK] N56 C Jalan36.csv
# [OK] N56 C Jalan37.csv
# [OK] N56 C Jalan38.csv
# [OK] N56 C Jalan39.csv
# [OK] N56 C Jalan4.csv
# [OK] N56 C Jalan40.csv
# [OK] N56 C Jalan41.csv
# [OK] N56 C Jalan42.csv
# [OK] N56 C Jalan43.csv
# [OK] N56 C Jalan44.csv
# [OK] N56 C Jalan45.csv
# [OK] N56 C Jalan46.csv
# [OK] N56 C Jalan47.csv
# [OK] N56 C Jalan48.csv
# [OK] N56 C Jalan49.csv
# [OK] N56 C Jalan5.csv
# [OK] N56 C Jalan50.csv
# [OK] N56 C Jalan51.csv
# [OK] N56 C Jalan52.csv
# [OK] N56 C Jalan53.csv
# [OK] N56 C Jalan54.csv
# [OK] N56 C Jalan55.csv
# [OK] N56 C Jalan56.csv
# [OK] N56 C Jalan57.csv
# [OK] N56 C Jalan58.csv
# [OK] N56 C Jalan59.csv
# [OK] N56 C Jalan6.csv
# [OK] N56 C Jalan60.csv
# [OK] N56 C Jalan61.csv
# [OK] N56 C Jalan62.csv
# [OK] N56 C Jalan63.csv
# [OK] N56 C Jalan64.csv
# [OK] N56 C Jalan65.csv
# [OK] N56 C Jalan66.csv
# [OK] N56 C Jalan67.csv
# [OK] N56 C Jalan68.csv
# [OK] N56 C Jalan69.csv
# [OK] N56 C Jalan7.csv
# [OK] N56 C Jalan70.csv
# [OK] N56 C Jalan71.csv
# [OK] N56 C Jalan72.csv
# [OK] N56 C Jalan8.csv
# [OK] N56 C Jalan9.csv
# [OK] N56 D Jalan1.csv
# [OK] N56 D Jalan10.csv
# [OK] N56 D Jalan11.csv
# [OK] N56 D Jalan12.csv
# [OK] N56 D Jalan13.csv
# [OK] N56 D Jalan14.csv
# [OK] N56 D Jalan15.csv
# [OK] N56 D Jalan16.csv
# [OK] N56 D Jalan17.csv
# [OK] N56 D Jalan18.csv
# [OK] N56 D Jalan19.csv
# [OK] N56 D Jalan2.csv
# [OK] N56 D Jalan20.csv
# [OK] N56 D Jalan21.csv
# [OK] N56 D Jalan22.csv
# [OK] N56 D Jalan23.csv
# [OK] N56 D Jalan24.csv
# [OK] N56 D Jalan25.csv
# [OK] N56 D Jalan26.csv
# [OK] N56 D Jalan27.csv
# [OK] N56 D Jalan28.csv
# [OK] N56 D Jalan29.csv
# [OK] N56 D Jalan3.csv
# [OK] N56 D Jalan30.csv
# [OK] N56 D Jalan31.csv
# [OK] N56 D Jalan32.csv
# [OK] N56 D Jalan33.csv
# [OK] N56 D Jalan34.csv
# [OK] N56 D Jalan35.csv
# [OK] N56 D Jalan36.csv
# [OK] N56 D Jalan37.csv
# [OK] N56 D Jalan38.csv
# [OK] N56 D Jalan39.csv
# [OK] N56 D Jalan4.csv
# [OK] N56 D Jalan40.csv
# [OK] N56 D Jalan41.csv
# [OK] N56 D Jalan42.csv
# [OK] N56 D Jalan43.csv
# [OK] N56 D Jalan44.csv
# [OK] N56 D Jalan45.csv
# [OK] N56 D Jalan46.csv
# [OK] N56 D Jalan47.csv
# [OK] N56 D Jalan48.csv
# [OK] N56 D Jalan49.csv
# [OK] N56 D Jalan5.csv
# [OK] N56 D Jalan50.csv
# [OK] N56 D Jalan51.csv
# [OK] N56 D Jalan52.csv
# [OK] N56 D Jalan53.csv
# [OK] N56 D Jalan54.csv
# [OK] N56 D Jalan55.csv
# [OK] N56 D Jalan56.csv
# [OK] N56 D Jalan57.csv
# [OK] N56 D Jalan58.csv
# [OK] N56 D Jalan59.csv
# [OK] N56 D Jalan6.csv
# [OK] N56 D Jalan60.csv
# [OK] N56 D Jalan61.csv
# [OK] N56 D Jalan62.csv
# [OK] N56 D Jalan63.csv
# [OK] N56 D Jalan64.csv
# [OK] N56 D Jalan65.csv
# [OK] N56 D Jalan66.csv
# [OK] N56 D Jalan67.csv
# [OK] N56 D Jalan68.csv
# [OK] N56 D Jalan69.csv
# [OK] N56 D Jalan7.csv
# [OK] N56 D Jalan70.csv
# [OK] N56 D Jalan71.csv
# [OK] N56 D Jalan72.csv
# [OK] N56 D Jalan8.csv
# [OK] N56 D Jalan9.csv
# [OK] N56 E Jalan1.csv
# [OK] N56 E Jalan10.csv
# [OK] N56 E Jalan11.csv
# [OK] N56 E Jalan12.csv
# [OK] N56 E Jalan13.csv
# [OK] N56 E Jalan14.csv
# [OK] N56 E Jalan15.csv
# [OK] N56 E Jalan16.csv
# [OK] N56 E Jalan17.csv
# [OK] N56 E Jalan18.csv
# [OK] N56 E Jalan19.csv
# [OK] N56 E Jalan2.csv
# [OK] N56 E Jalan20.csv
# [OK] N56 E Jalan21.csv
# [OK] N56 E Jalan22.csv
# [OK] N56 E Jalan23.csv
# [OK] N56 E Jalan24.csv
# [OK] N56 E Jalan25.csv
# [OK] N56 E Jalan26.csv
# [OK] N56 E Jalan27.csv
# [OK] N56 E Jalan28.csv
# [OK] N56 E Jalan29.csv
# [OK] N56 E Jalan3.csv
# [OK] N56 E Jalan30.csv
# [OK] N56 E Jalan31.csv
# [OK] N56 E Jalan32.csv
# [OK] N56 E Jalan33.csv
# [OK] N56 E Jalan34.csv
# [OK] N56 E Jalan35.csv
# [OK] N56 E Jalan36.csv
# [OK] N56 E Jalan37.csv
# [OK] N56 E Jalan38.csv
# [OK] N56 E Jalan39.csv
# [OK] N56 E Jalan4.csv
# [OK] N56 E Jalan40.csv
# [OK] N56 E Jalan41.csv
# [OK] N56 E Jalan42.csv
# [OK] N56 E Jalan43.csv
# [OK] N56 E Jalan44.csv
# [OK] N56 E Jalan45.csv
# [OK] N56 E Jalan46.csv
# [OK] N56 E Jalan47.csv
# [OK] N56 E Jalan48.csv
# [OK] N56 E Jalan49.csv
# [OK] N56 E Jalan5.csv
# [OK] N56 E Jalan50.csv
# [OK] N56 E Jalan51.csv
# [OK] N56 E Jalan52.csv
# [OK] N56 E Jalan53.csv
# [OK] N56 E Jalan54.csv
# [OK] N56 E Jalan55.csv
# [OK] N56 E Jalan56.csv
# [OK] N56 E Jalan57.csv
# [OK] N56 E Jalan58.csv
# [OK] N56 E Jalan59.csv
# [OK] N56 E Jalan6.csv
# [OK] N56 E Jalan60.csv
# [OK] N56 E Jalan61.csv
# [OK] N56 E Jalan62.csv
# [OK] N56 E Jalan63.csv
# [OK] N56 E Jalan64.csv
# [OK] N56 E Jalan65.csv
# [OK] N56 E Jalan66.csv
# [OK] N56 E Jalan67.csv
# [OK] N56 E Jalan68.csv
# [OK] N56 E Jalan69.csv
# [OK] N56 E Jalan7.csv
# [OK] N56 E Jalan70.csv
# [OK] N56 E Jalan71.csv
# [OK] N56 E Jalan72.csv
# [OK] N56 E Jalan8.csv
# [OK] N56 E Jalan9.csv
# [OK] N56 F Jalan1.csv
# [OK] N56 F Jalan10.csv
# [OK] N56 F Jalan11.csv
# [OK] N56 F Jalan12.csv
# [OK] N56 F Jalan13.csv
# [OK] N56 F Jalan14.csv
# [OK] N56 F Jalan15.csv
# [OK] N56 F Jalan16.csv
# [OK] N56 F Jalan17.csv
# [OK] N56 F Jalan18.csv
# [OK] N56 F Jalan19.csv
# [OK] N56 F Jalan2.csv
# [OK] N56 F Jalan20.csv
# [OK] N56 F Jalan21.csv
# [OK] N56 F Jalan22.csv
# [OK] N56 F Jalan23.csv
# [OK] N56 F Jalan24.csv
# [OK] N56 F Jalan25.csv
# [OK] N56 F Jalan26.csv
# [OK] N56 F Jalan27.csv
# [OK] N56 F Jalan28.csv
# [OK] N56 F Jalan29.csv
# [OK] N56 F Jalan3.csv
# [OK] N56 F Jalan30.csv
# [OK] N56 F Jalan31.csv
# [OK] N56 F Jalan32.csv
# [OK] N56 F Jalan33.csv
# [OK] N56 F Jalan34.csv
# [OK] N56 F Jalan35.csv
# [OK] N56 F Jalan36.csv
# [OK] N56 F Jalan37.csv
# [OK] N56 F Jalan38.csv
# [OK] N56 F Jalan39.csv
# [OK] N56 F Jalan4.csv
# [OK] N56 F Jalan40.csv
# [OK] N56 F Jalan41.csv
# [OK] N56 F Jalan42.csv
# [OK] N56 F Jalan43.csv
# [OK] N56 F Jalan44.csv
# [OK] N56 F Jalan45.csv
# [OK] N56 F Jalan46.csv
# [OK] N56 F Jalan47.csv
# [OK] N56 F Jalan48.csv
# [OK] N56 F Jalan49.csv
# [OK] N56 F Jalan5.csv
# [OK] N56 F Jalan50.csv
# [OK] N56 F Jalan51.csv
# [OK] N56 F Jalan52.csv
# [OK] N56 F Jalan53.csv
# [OK] N56 F Jalan54.csv
# [OK] N56 F Jalan55.csv
# [OK] N56 F Jalan56.csv
# [OK] N56 F Jalan57.csv
# [OK] N56 F Jalan58.csv
# [OK] N56 F Jalan59.csv
# [OK] N56 F Jalan6.csv
# [OK] N56 F Jalan60.csv
# [OK] N56 F Jalan61.csv
# [OK] N56 F Jalan62.csv
# [OK] N56 F Jalan63.csv
# [OK] N56 F Jalan64.csv
# [OK] N56 F Jalan65.csv
# [OK] N56 F Jalan66.csv
# [OK] N56 F Jalan67.csv
# [OK] N56 F Jalan68.csv
# [OK] N56 F Jalan69.csv
# [OK] N56 F Jalan7.csv
# [OK] N56 F Jalan70.csv
# [OK] N56 F Jalan71.csv
# [OK] N56 F Jalan72.csv
# [OK] N56 F Jalan8.csv
# [OK] N56 F Jalan9.csv
# [OK] N56 G Jalan1.csv
# [OK] N56 G Jalan10.csv
# [OK] N56 G Jalan11.csv
# [OK] N56 G Jalan12.csv
# [OK] N56 G Jalan13.csv
# [OK] N56 G Jalan14.csv
# [OK] N56 G Jalan15.csv
# [OK] N56 G Jalan16.csv
# [OK] N56 G Jalan17.csv
# [OK] N56 G Jalan18.csv
# [OK] N56 G Jalan19.csv
# [OK] N56 G Jalan2.csv
# [OK] N56 G Jalan20.csv
# [OK] N56 G Jalan21.csv
# [OK] N56 G Jalan22.csv
# [OK] N56 G Jalan23.csv
# [OK] N56 G Jalan24.csv
# [OK] N56 G Jalan25.csv
# [OK] N56 G Jalan26.csv
# [OK] N56 G Jalan27.csv
# [OK] N56 G Jalan28.csv
# [OK] N56 G Jalan29.csv
# [OK] N56 G Jalan3.csv
# [OK] N56 G Jalan30.csv
# [OK] N56 G Jalan31.csv
# [OK] N56 G Jalan32.csv
# [OK] N56 G Jalan33.csv
# [OK] N56 G Jalan34.csv
# [OK] N56 G Jalan35.csv
# [OK] N56 G Jalan36.csv
# [OK] N56 G Jalan37.csv
# [OK] N56 G Jalan38.csv
# [OK] N56 G Jalan39.csv
# [OK] N56 G Jalan4.csv
# [OK] N56 G Jalan40.csv
# [OK] N56 G Jalan41.csv
# [OK] N56 G Jalan42.csv
# [OK] N56 G Jalan43.csv
# [OK] N56 G Jalan44.csv
# [OK] N56 G Jalan45.csv
# [OK] N56 G Jalan46.csv
# [OK] N56 G Jalan47.csv
# [OK] N56 G Jalan48.csv
# [OK] N56 G Jalan49.csv
# [OK] N56 G Jalan5.csv
# [OK] N56 G Jalan50.csv
# [OK] N56 G Jalan51.csv
# [OK] N56 G Jalan52.csv
# [OK] N56 G Jalan53.csv
# [OK] N56 G Jalan54.csv
# [OK] N56 G Jalan55.csv
# [OK] N56 G Jalan56.csv
# [OK] N56 G Jalan57.csv
# [OK] N56 G Jalan58.csv
# [OK] N56 G Jalan59.csv
# [OK] N56 G Jalan6.csv
# [OK] N56 G Jalan60.csv
# [OK] N56 G Jalan61.csv
# [OK] N56 G Jalan62.csv
# [OK] N56 G Jalan63.csv
# [OK] N56 G Jalan64.csv
# [OK] N56 G Jalan65.csv
# [OK] N56 G Jalan66.csv
# [OK] N56 G Jalan67.csv
# [OK] N56 G Jalan68.csv
# [OK] N56 G Jalan69.csv
# [OK] N56 G Jalan7.csv
# [OK] N56 G Jalan70.csv
# [OK] N56 G Jalan71.csv
# [OK] N56 G Jalan72.csv
# [OK] N56 G Jalan8.csv
# [OK] N56 G Jalan9.csv
# [OK] N56 H Jalan1.csv
# [OK] N56 H Jalan10.csv
# [OK] N56 H Jalan11.csv
# [OK] N56 H Jalan12.csv
# [OK] N56 H Jalan13.csv
# [OK] N56 H Jalan14.csv
# [OK] N56 H Jalan15.csv
# [OK] N56 H Jalan16.csv
# [OK] N56 H Jalan17.csv
# [OK] N56 H Jalan18.csv
# [OK] N56 H Jalan19.csv
# [OK] N56 H Jalan2.csv
# [OK] N56 H Jalan20.csv
# [OK] N56 H Jalan21.csv
# [OK] N56 H Jalan22.csv
# [OK] N56 H Jalan23.csv
# [OK] N56 H Jalan24.csv
# [OK] N56 H Jalan25.csv
# [OK] N56 H Jalan26.csv
# [OK] N56 H Jalan27.csv
# [OK] N56 H Jalan28.csv
# [OK] N56 H Jalan29.csv
# [OK] N56 H Jalan3.csv
# [OK] N56 H Jalan30.csv
# [OK] N56 H Jalan31.csv
# [OK] N56 H Jalan32.csv
# [OK] N56 H Jalan33.csv
# [OK] N56 H Jalan34.csv
# [OK] N56 H Jalan35.csv
# [OK] N56 H Jalan36.csv
# [OK] N56 H Jalan37.csv
# [OK] N56 H Jalan38.csv
# [OK] N56 H Jalan39.csv
# [OK] N56 H Jalan4.csv
# [OK] N56 H Jalan40.csv
# [OK] N56 H Jalan41.csv
# [OK] N56 H Jalan42.csv
# [OK] N56 H Jalan43.csv
# [OK] N56 H Jalan44.csv
# [OK] N56 H Jalan45.csv
# [OK] N56 H Jalan46.csv
# [OK] N56 H Jalan47.csv
# [OK] N56 H Jalan48.csv
# [OK] N56 H Jalan49.csv
# [OK] N56 H Jalan5.csv
# [OK] N56 H Jalan50.csv
# [OK] N56 H Jalan51.csv
# [OK] N56 H Jalan52.csv
# [OK] N56 H Jalan53.csv
# [OK] N56 H Jalan54.csv
# [OK] N56 H Jalan55.csv
# [OK] N56 H Jalan56.csv
# [OK] N56 H Jalan57.csv
# [OK] N56 H Jalan58.csv
# [OK] N56 H Jalan59.csv
# [OK] N56 H Jalan6.csv
# [OK] N56 H Jalan60.csv
# [OK] N56 H Jalan61.csv
# [OK] N56 H Jalan62.csv
# [OK] N56 H Jalan63.csv
# [OK] N56 H Jalan64.csv
# [OK] N56 H Jalan65.csv
# [OK] N56 H Jalan66.csv
# [OK] N56 H Jalan67.csv
# [OK] N56 H Jalan68.csv
# [OK] N56 H Jalan69.csv
# [OK] N56 H Jalan7.csv
# [OK] N56 H Jalan70.csv
# [OK] N56 H Jalan71.csv
# [OK] N56 H Jalan72.csv
# [OK] N56 H Jalan8.csv
# [OK] N56 H Jalan9.csv
# [OK] N56 I Jalan1.csv
# [OK] N56 I Jalan10.csv
# [OK] N56 I Jalan11.csv
# [OK] N56 I Jalan12.csv
# [OK] N56 I Jalan13.csv
# [OK] N56 I Jalan14.csv
# [OK] N56 I Jalan15.csv
# [OK] N56 I Jalan16.csv
# [OK] N56 I Jalan17.csv
# [OK] N56 I Jalan18.csv
# [OK] N56 I Jalan19.csv
# [OK] N56 I Jalan2.csv
# [OK] N56 I Jalan20.csv
# [OK] N56 I Jalan21.csv
# [OK] N56 I Jalan22.csv
# [OK] N56 I Jalan23.csv
# [OK] N56 I Jalan24.csv
# [OK] N56 I Jalan25.csv
# [OK] N56 I Jalan26.csv
# [OK] N56 I Jalan27.csv
# [OK] N56 I Jalan28.csv
# [OK] N56 I Jalan29.csv
# [OK] N56 I Jalan3.csv
# [OK] N56 I Jalan30.csv
# [OK] N56 I Jalan31.csv
# [OK] N56 I Jalan32.csv
# [OK] N56 I Jalan33.csv
# [OK] N56 I Jalan34.csv
# [OK] N56 I Jalan35.csv
# [OK] N56 I Jalan36.csv
# [OK] N56 I Jalan37.csv
# [OK] N56 I Jalan38.csv
# [OK] N56 I Jalan39.csv
# [OK] N56 I Jalan4.csv
# [OK] N56 I Jalan40.csv
# [OK] N56 I Jalan41.csv
# [OK] N56 I Jalan42.csv
# [OK] N56 I Jalan43.csv
# [OK] N56 I Jalan44.csv
# [OK] N56 I Jalan45.csv
# [OK] N56 I Jalan46.csv
# [OK] N56 I Jalan47.csv
# [OK] N56 I Jalan48.csv
# [OK] N56 I Jalan49.csv
# [OK] N56 I Jalan5.csv
# [OK] N56 I Jalan50.csv
# [OK] N56 I Jalan51.csv
# [OK] N56 I Jalan52.csv
# [OK] N56 I Jalan53.csv
# [OK] N56 I Jalan54.csv
# [OK] N56 I Jalan55.csv
# [OK] N56 I Jalan56.csv
# [OK] N56 I Jalan57.csv
# [OK] N56 I Jalan58.csv
# [OK] N56 I Jalan59.csv
# [OK] N56 I Jalan6.csv
# [OK] N56 I Jalan60.csv
# [OK] N56 I Jalan61.csv
# [OK] N56 I Jalan62.csv
# [OK] N56 I Jalan63.csv
# [OK] N56 I Jalan64.csv
# [OK] N56 I Jalan65.csv
# [OK] N56 I Jalan66.csv
# [OK] N56 I Jalan67.csv
# [OK] N56 I Jalan68.csv
# [OK] N56 I Jalan69.csv
# [OK] N56 I Jalan7.csv
# [OK] N56 I Jalan70.csv
# [OK] N56 I Jalan71.csv
# [OK] N56 I Jalan72.csv
# [OK] N56 I Jalan8.csv
# [OK] N56 I Jalan9.csv
# [OK] N56 J Jalan1.csv
# [OK] N56 J Jalan10.csv
# [OK] N56 J Jalan11.csv
# [OK] N56 J Jalan12.csv
# [OK] N56 J Jalan13.csv
# [OK] N56 J Jalan14.csv
# [OK] N56 J Jalan15.csv
# [OK] N56 J Jalan16.csv
# [OK] N56 J Jalan17.csv
# [OK] N56 J Jalan18.csv
# [OK] N56 J Jalan19.csv
# [OK] N56 J Jalan2.csv
# [OK] N56 J Jalan20.csv
# [OK] N56 J Jalan21.csv
# [OK] N56 J Jalan22.csv
# [OK] N56 J Jalan23.csv
# [OK] N56 J Jalan24.csv
# [OK] N56 J Jalan25.csv
# [OK] N56 J Jalan26.csv
# [OK] N56 J Jalan27.csv
# [OK] N56 J Jalan28.csv
# [OK] N56 J Jalan29.csv
# [OK] N56 J Jalan3.csv
# [OK] N56 J Jalan30.csv
# [OK] N56 J Jalan31.csv
# [OK] N56 J Jalan32.csv
# [OK] N56 J Jalan33.csv
# [OK] N56 J Jalan34.csv
# [OK] N56 J Jalan35.csv
# [OK] N56 J Jalan36.csv
# [OK] N56 J Jalan37.csv
# [OK] N56 J Jalan38.csv
# [OK] N56 J Jalan39.csv
# [OK] N56 J Jalan4.csv
# [OK] N56 J Jalan40.csv
# [OK] N56 J Jalan41.csv
# [OK] N56 J Jalan42.csv
# [OK] N56 J Jalan43.csv
# [OK] N56 J Jalan44.csv
# [OK] N56 J Jalan45.csv
# [OK] N56 J Jalan46.csv
# [OK] N56 J Jalan47.csv
# [OK] N56 J Jalan48.csv
# [OK] N56 J Jalan49.csv
# [OK] N56 J Jalan5.csv
# [OK] N56 J Jalan50.csv
# [OK] N56 J Jalan51.csv
# [OK] N56 J Jalan52.csv
# [OK] N56 J Jalan53.csv
# [OK] N56 J Jalan54.csv
# [OK] N56 J Jalan55.csv
# [OK] N56 J Jalan56.csv
# [OK] N56 J Jalan57.csv
# [OK] N56 J Jalan58.csv
# [OK] N56 J Jalan59.csv
# [OK] N56 J Jalan6.csv
# [OK] N56 J Jalan60.csv
# [OK] N56 J Jalan61.csv
# [OK] N56 J Jalan62.csv
# [OK] N56 J Jalan63.csv
# [OK] N56 J Jalan64.csv
# [OK] N56 J Jalan65.csv
# [OK] N56 J Jalan66.csv
# [OK] N56 J Jalan67.csv
# [OK] N56 J Jalan68.csv
# [OK] N56 J Jalan69.csv
# [OK] N56 J Jalan7.csv
# [OK] N56 J Jalan70.csv
# [OK] N56 J Jalan71.csv
# [OK] N56 J Jalan72.csv
# [OK] N56 J Jalan8.csv
# [OK] N56 J Jalan9.csv
# [OK] N64 A Jalan1.csv
# [OK] N64 A Jalan10.csv
# [OK] N64 A Jalan11.csv
# [OK] N64 A Jalan12.csv
# [OK] N64 A Jalan13.csv
# [OK] N64 A Jalan14.csv
# [OK] N64 A Jalan15.csv
# [OK] N64 A Jalan16.csv
# [OK] N64 A Jalan17.csv
# [OK] N64 A Jalan18.csv
# [OK] N64 A Jalan19.csv
# [OK] N64 A Jalan2.csv
# [OK] N64 A Jalan20.csv
# [OK] N64 A Jalan21.csv
# [OK] N64 A Jalan22.csv
# [OK] N64 A Jalan23.csv
# [OK] N64 A Jalan24.csv
# [OK] N64 A Jalan25.csv
# [OK] N64 A Jalan26.csv
# [OK] N64 A Jalan27.csv
# [OK] N64 A Jalan28.csv
# [OK] N64 A Jalan29.csv
# [OK] N64 A Jalan3.csv
# [OK] N64 A Jalan30.csv
# [OK] N64 A Jalan31.csv
# [OK] N64 A Jalan32.csv
# [OK] N64 A Jalan33.csv
# [OK] N64 A Jalan34.csv
# [OK] N64 A Jalan35.csv
# [OK] N64 A Jalan36.csv
# [OK] N64 A Jalan37.csv
# [OK] N64 A Jalan38.csv
# [OK] N64 A Jalan39.csv
# [OK] N64 A Jalan4.csv
# [OK] N64 A Jalan40.csv
# [OK] N64 A Jalan41.csv
# [OK] N64 A Jalan42.csv
# [OK] N64 A Jalan43.csv
# [OK] N64 A Jalan44.csv
# [OK] N64 A Jalan45.csv
# [OK] N64 A Jalan46.csv
# [OK] N64 A Jalan47.csv
# [OK] N64 A Jalan48.csv
# [OK] N64 A Jalan49.csv
# [OK] N64 A Jalan5.csv
# [OK] N64 A Jalan50.csv
# [OK] N64 A Jalan51.csv
# [OK] N64 A Jalan52.csv
# [OK] N64 A Jalan53.csv
# [OK] N64 A Jalan54.csv
# [OK] N64 A Jalan55.csv
# [OK] N64 A Jalan56.csv
# [OK] N64 A Jalan57.csv
# [OK] N64 A Jalan58.csv
# [OK] N64 A Jalan59.csv
# [OK] N64 A Jalan6.csv
# [OK] N64 A Jalan60.csv
# [OK] N64 A Jalan61.csv
# [OK] N64 A Jalan62.csv
# [OK] N64 A Jalan63.csv
# [OK] N64 A Jalan64.csv
# [OK] N64 A Jalan65.csv
# [OK] N64 A Jalan66.csv
# [OK] N64 A Jalan67.csv
# [OK] N64 A Jalan68.csv
# [OK] N64 A Jalan69.csv
# [OK] N64 A Jalan7.csv
# [OK] N64 A Jalan70.csv
# [OK] N64 A Jalan71.csv
# [OK] N64 A Jalan72.csv
# [OK] N64 A Jalan8.csv
# [OK] N64 A Jalan9.csv
# [OK] N64 B Jalan1.csv
# [OK] N64 B Jalan10.csv
# [OK] N64 B Jalan11.csv
# [OK] N64 B Jalan12.csv
# [OK] N64 B Jalan13.csv
# [OK] N64 B Jalan14.csv
# [OK] N64 B Jalan15.csv
# [OK] N64 B Jalan16.csv
# [OK] N64 B Jalan17.csv
# [OK] N64 B Jalan18.csv
# [OK] N64 B Jalan19.csv
# [OK] N64 B Jalan2.csv
# [OK] N64 B Jalan20.csv
# [OK] N64 B Jalan21.csv
# [OK] N64 B Jalan22.csv
# [OK] N64 B Jalan23.csv
# [OK] N64 B Jalan24.csv
# [OK] N64 B Jalan25.csv
# [OK] N64 B Jalan26.csv
# [OK] N64 B Jalan27.csv
# [OK] N64 B Jalan28.csv
# [OK] N64 B Jalan29.csv
# [OK] N64 B Jalan3.csv
# [OK] N64 B Jalan30.csv
# [OK] N64 B Jalan31.csv
# [OK] N64 B Jalan32.csv
# [OK] N64 B Jalan33.csv
# [OK] N64 B Jalan34.csv
# [OK] N64 B Jalan35.csv
# [OK] N64 B Jalan36.csv
# [OK] N64 B Jalan37.csv
# [OK] N64 B Jalan38.csv
# [OK] N64 B Jalan39.csv
# [OK] N64 B Jalan4.csv
# [OK] N64 B Jalan40.csv
# [OK] N64 B Jalan41.csv
# [OK] N64 B Jalan42.csv
# [OK] N64 B Jalan43.csv
# [OK] N64 B Jalan44.csv
# [OK] N64 B Jalan45.csv
# [OK] N64 B Jalan46.csv
# [OK] N64 B Jalan47.csv
# [OK] N64 B Jalan48.csv
# [OK] N64 B Jalan49.csv
# [OK] N64 B Jalan5.csv
# [OK] N64 B Jalan50.csv
# [OK] N64 B Jalan51.csv
# [OK] N64 B Jalan52.csv
# [OK] N64 B Jalan53.csv
# [OK] N64 B Jalan54.csv
# [OK] N64 B Jalan55.csv
# [OK] N64 B Jalan56.csv
# [OK] N64 B Jalan57.csv
# [OK] N64 B Jalan58.csv
# [OK] N64 B Jalan59.csv
# [OK] N64 B Jalan6.csv
# [OK] N64 B Jalan60.csv
# [OK] N64 B Jalan61.csv
# [OK] N64 B Jalan62.csv
# [OK] N64 B Jalan63.csv
# [OK] N64 B Jalan64.csv
# [OK] N64 B Jalan65.csv
# [OK] N64 B Jalan66.csv
# [OK] N64 B Jalan67.csv
# [OK] N64 B Jalan68.csv
# [OK] N64 B Jalan69.csv
# [OK] N64 B Jalan7.csv
# [OK] N64 B Jalan70.csv
# [OK] N64 B Jalan71.csv
# [OK] N64 B Jalan72.csv
# [OK] N64 B Jalan8.csv
# [OK] N64 B Jalan9.csv
# [OK] N64 C Jalan1.csv
# [OK] N64 C Jalan10.csv
# [OK] N64 C Jalan11.csv
# [OK] N64 C Jalan12.csv
# [OK] N64 C Jalan13.csv
# [OK] N64 C Jalan14.csv
# [OK] N64 C Jalan15.csv
# [OK] N64 C Jalan16.csv
# [OK] N64 C Jalan17.csv
# [OK] N64 C Jalan18.csv
# [OK] N64 C Jalan19.csv
# [OK] N64 C Jalan2.csv
# [OK] N64 C Jalan20.csv
# [OK] N64 C Jalan21.csv
# [OK] N64 C Jalan22.csv
# [OK] N64 C Jalan23.csv
# [OK] N64 C Jalan24.csv
# [OK] N64 C Jalan25.csv
# [OK] N64 C Jalan26.csv
# [OK] N64 C Jalan27.csv
# [OK] N64 C Jalan28.csv
# [OK] N64 C Jalan29.csv
# [OK] N64 C Jalan3.csv
# [OK] N64 C Jalan30.csv
# [OK] N64 C Jalan31.csv
# [OK] N64 C Jalan32.csv
# [OK] N64 C Jalan33.csv
# [OK] N64 C Jalan34.csv
# [OK] N64 C Jalan35.csv
# [OK] N64 C Jalan36.csv
# [OK] N64 C Jalan37.csv
# [OK] N64 C Jalan38.csv
# [OK] N64 C Jalan39.csv
# [OK] N64 C Jalan4.csv
# [OK] N64 C Jalan40.csv
# [OK] N64 C Jalan41.csv
# [OK] N64 C Jalan42.csv
# [OK] N64 C Jalan43.csv
# [OK] N64 C Jalan44.csv
# [OK] N64 C Jalan45.csv
# [OK] N64 C Jalan46.csv
# [OK] N64 C Jalan47.csv
# [OK] N64 C Jalan48.csv
# [OK] N64 C Jalan49.csv
# [OK] N64 C Jalan5.csv
# [OK] N64 C Jalan50.csv
# [OK] N64 C Jalan51.csv
# [OK] N64 C Jalan52.csv
# [OK] N64 C Jalan53.csv
# [OK] N64 C Jalan54.csv
# [OK] N64 C Jalan55.csv
# [OK] N64 C Jalan56.csv
# [OK] N64 C Jalan57.csv
# [OK] N64 C Jalan58.csv
# [OK] N64 C Jalan59.csv
# [OK] N64 C Jalan6.csv
# [OK] N64 C Jalan60.csv
# [OK] N64 C Jalan61.csv
# [OK] N64 C Jalan62.csv
# [OK] N64 C Jalan63.csv
# [OK] N64 C Jalan64.csv
# [OK] N64 C Jalan65.csv
# [OK] N64 C Jalan66.csv
# [OK] N64 C Jalan67.csv
# [OK] N64 C Jalan68.csv
# [OK] N64 C Jalan69.csv
# [OK] N64 C Jalan7.csv
# [OK] N64 C Jalan70.csv
# [OK] N64 C Jalan71.csv
# [OK] N64 C Jalan72.csv
# [OK] N64 C Jalan8.csv
# [OK] N64 C Jalan9.csv
# [OK] N64 D Jalan1.csv
# [OK] N64 D Jalan10.csv
# [OK] N64 D Jalan11.csv
# [OK] N64 D Jalan12.csv
# [OK] N64 D Jalan13.csv
# [OK] N64 D Jalan14.csv
# [OK] N64 D Jalan15.csv
# [OK] N64 D Jalan16.csv
# [OK] N64 D Jalan17.csv
# [OK] N64 D Jalan18.csv
# [OK] N64 D Jalan19.csv
# [OK] N64 D Jalan2.csv
# [OK] N64 D Jalan20.csv
# [OK] N64 D Jalan21.csv
# [OK] N64 D Jalan22.csv
# [OK] N64 D Jalan23.csv
# [OK] N64 D Jalan24.csv
# [OK] N64 D Jalan25.csv
# [OK] N64 D Jalan26.csv
# [OK] N64 D Jalan27.csv
# [OK] N64 D Jalan28.csv
# [OK] N64 D Jalan29.csv
# [OK] N64 D Jalan3.csv
# [OK] N64 D Jalan30.csv
# [OK] N64 D Jalan31.csv
# [OK] N64 D Jalan32.csv
# [OK] N64 D Jalan33.csv
# [OK] N64 D Jalan34.csv
# [OK] N64 D Jalan35.csv
# [OK] N64 D Jalan36.csv
# [OK] N64 D Jalan37.csv
# [OK] N64 D Jalan38.csv
# [OK] N64 D Jalan39.csv
# [OK] N64 D Jalan4.csv
# [OK] N64 D Jalan40.csv
# [OK] N64 D Jalan41.csv
# [OK] N64 D Jalan42.csv
# [OK] N64 D Jalan43.csv
# [OK] N64 D Jalan44.csv
# [OK] N64 D Jalan45.csv
# [OK] N64 D Jalan46.csv
# [OK] N64 D Jalan47.csv
# [OK] N64 D Jalan48.csv
# [OK] N64 D Jalan49.csv
# [OK] N64 D Jalan5.csv
# [OK] N64 D Jalan50.csv
# [OK] N64 D Jalan51.csv
# [OK] N64 D Jalan52.csv
# [OK] N64 D Jalan53.csv
# [OK] N64 D Jalan54.csv
# [OK] N64 D Jalan55.csv
# [OK] N64 D Jalan56.csv
# [OK] N64 D Jalan57.csv
# [OK] N64 D Jalan58.csv
# [OK] N64 D Jalan59.csv
# [OK] N64 D Jalan6.csv
# [OK] N64 D Jalan60.csv
# [OK] N64 D Jalan61.csv
# [OK] N64 D Jalan62.csv
# [OK] N64 D Jalan63.csv
# [OK] N64 D Jalan64.csv
# [OK] N64 D Jalan65.csv
# [OK] N64 D Jalan66.csv
# [OK] N64 D Jalan67.csv
# [OK] N64 D Jalan68.csv
# [OK] N64 D Jalan69.csv
# [OK] N64 D Jalan7.csv
# [OK] N64 D Jalan70.csv
# [OK] N64 D Jalan71.csv
# [OK] N64 D Jalan72.csv
# [OK] N64 D Jalan8.csv
# [OK] N64 D Jalan9.csv
# [OK] N64 E Jalan1.csv
# [OK] N64 E Jalan10.csv
# [OK] N64 E Jalan11.csv
# [OK] N64 E Jalan12.csv
# [OK] N64 E Jalan13.csv
# [OK] N64 E Jalan14.csv
# [OK] N64 E Jalan15.csv
# [OK] N64 E Jalan16.csv
# [OK] N64 E Jalan17.csv
# [OK] N64 E Jalan18.csv
# [OK] N64 E Jalan19.csv
# [OK] N64 E Jalan2.csv
# [OK] N64 E Jalan20.csv
# [OK] N64 E Jalan21.csv
# [OK] N64 E Jalan22.csv
# [OK] N64 E Jalan23.csv
# [OK] N64 E Jalan24.csv
# [OK] N64 E Jalan25.csv
# [OK] N64 E Jalan26.csv
# [OK] N64 E Jalan27.csv
# [OK] N64 E Jalan28.csv
# [OK] N64 E Jalan29.csv
# [OK] N64 E Jalan3.csv
# [OK] N64 E Jalan30.csv
# [OK] N64 E Jalan31.csv
# [OK] N64 E Jalan32.csv
# [OK] N64 E Jalan33.csv
# [OK] N64 E Jalan34.csv
# [OK] N64 E Jalan35.csv
# [OK] N64 E Jalan36.csv
# [OK] N64 E Jalan37.csv
# [OK] N64 E Jalan38.csv
# [OK] N64 E Jalan39.csv
# [OK] N64 E Jalan4.csv
# [OK] N64 E Jalan40.csv
# [OK] N64 E Jalan41.csv
# [OK] N64 E Jalan42.csv
# [OK] N64 E Jalan43.csv
# [OK] N64 E Jalan44.csv
# [OK] N64 E Jalan45.csv
# [OK] N64 E Jalan46.csv
# [OK] N64 E Jalan47.csv
# [OK] N64 E Jalan48.csv
# [OK] N64 E Jalan49.csv
# [OK] N64 E Jalan5.csv
# [OK] N64 E Jalan50.csv
# [OK] N64 E Jalan51.csv
# [OK] N64 E Jalan52.csv
# [OK] N64 E Jalan53.csv
# [OK] N64 E Jalan54.csv
# [OK] N64 E Jalan55.csv
# [OK] N64 E Jalan56.csv
# [OK] N64 E Jalan57.csv
# [OK] N64 E Jalan58.csv
# [OK] N64 E Jalan59.csv
# [OK] N64 E Jalan6.csv
# [OK] N64 E Jalan60.csv
# [OK] N64 E Jalan61.csv
# [OK] N64 E Jalan62.csv
# [OK] N64 E Jalan63.csv
# [OK] N64 E Jalan64.csv
# [OK] N64 E Jalan65.csv
# [OK] N64 E Jalan66.csv
# [OK] N64 E Jalan67.csv
# [OK] N64 E Jalan68.csv
# [OK] N64 E Jalan69.csv
# [OK] N64 E Jalan7.csv
# [OK] N64 E Jalan70.csv
# [OK] N64 E Jalan71.csv
# [OK] N64 E Jalan72.csv
# [OK] N64 E Jalan8.csv
# [OK] N64 E Jalan9.csv
# [OK] N64 F Jalan1.csv
# [OK] N64 F Jalan10.csv
# [OK] N64 F Jalan11.csv
# [OK] N64 F Jalan12.csv
# [OK] N64 F Jalan13.csv
# [OK] N64 F Jalan14.csv
# [OK] N64 F Jalan15.csv
# [OK] N64 F Jalan16.csv
# [OK] N64 F Jalan17.csv
# [OK] N64 F Jalan18.csv
# [OK] N64 F Jalan19.csv
# [OK] N64 F Jalan2.csv
# [OK] N64 F Jalan20.csv
# [OK] N64 F Jalan21.csv
# [OK] N64 F Jalan22.csv
# [OK] N64 F Jalan23.csv
# [OK] N64 F Jalan24.csv
# [OK] N64 F Jalan25.csv
# [OK] N64 F Jalan26.csv
# [OK] N64 F Jalan27.csv
# [OK] N64 F Jalan28.csv
# [OK] N64 F Jalan29.csv
# [OK] N64 F Jalan3.csv
# [OK] N64 F Jalan30.csv
# [OK] N64 F Jalan31.csv
# [OK] N64 F Jalan32.csv
# [OK] N64 F Jalan33.csv
# [OK] N64 F Jalan34.csv
# [OK] N64 F Jalan35.csv
# [OK] N64 F Jalan36.csv
# [OK] N64 F Jalan37.csv
# [OK] N64 F Jalan38.csv
# [OK] N64 F Jalan39.csv
# [OK] N64 F Jalan4.csv
# [OK] N64 F Jalan40.csv
# [OK] N64 F Jalan41.csv
# [OK] N64 F Jalan42.csv
# [OK] N64 F Jalan43.csv
# [OK] N64 F Jalan44.csv
# [OK] N64 F Jalan45.csv
# [OK] N64 F Jalan46.csv
# [OK] N64 F Jalan47.csv
# [OK] N64 F Jalan48.csv
# [OK] N64 F Jalan49.csv
# [OK] N64 F Jalan5.csv
# [OK] N64 F Jalan50.csv
# [OK] N64 F Jalan51.csv
# [OK] N64 F Jalan52.csv
# [OK] N64 F Jalan53.csv
# [OK] N64 F Jalan54.csv
# [OK] N64 F Jalan55.csv
# [OK] N64 F Jalan56.csv
# [OK] N64 F Jalan57.csv
# [OK] N64 F Jalan58.csv
# [OK] N64 F Jalan59.csv
# [OK] N64 F Jalan6.csv
# [OK] N64 F Jalan60.csv
# [OK] N64 F Jalan61.csv
# [OK] N64 F Jalan62.csv
# [OK] N64 F Jalan63.csv
# [OK] N64 F Jalan64.csv
# [OK] N64 F Jalan65.csv
# [OK] N64 F Jalan66.csv
# [OK] N64 F Jalan67.csv
# [OK] N64 F Jalan68.csv
# [OK] N64 F Jalan69.csv
# [OK] N64 F Jalan7.csv
# [OK] N64 F Jalan70.csv
# [OK] N64 F Jalan71.csv
# [OK] N64 F Jalan72.csv
# [OK] N64 F Jalan8.csv
# [OK] N64 F Jalan9.csv
# [OK] N64 G Jalan1.csv
# [OK] N64 G Jalan10.csv
# [OK] N64 G Jalan11.csv
# [OK] N64 G Jalan12.csv
# [OK] N64 G Jalan13.csv
# [OK] N64 G Jalan14.csv
# [OK] N64 G Jalan15.csv
# [OK] N64 G Jalan16.csv
# [OK] N64 G Jalan17.csv
# [OK] N64 G Jalan18.csv
# [OK] N64 G Jalan19.csv
# [OK] N64 G Jalan2.csv
# [OK] N64 G Jalan20.csv
# [OK] N64 G Jalan21.csv
# [OK] N64 G Jalan22.csv
# [OK] N64 G Jalan23.csv
# [OK] N64 G Jalan24.csv
# [OK] N64 G Jalan25.csv
# [OK] N64 G Jalan26.csv
# [OK] N64 G Jalan27.csv
# [OK] N64 G Jalan28.csv
# [OK] N64 G Jalan29.csv
# [OK] N64 G Jalan3.csv
# [OK] N64 G Jalan30.csv
# [OK] N64 G Jalan31.csv
# [OK] N64 G Jalan32.csv
# [OK] N64 G Jalan33.csv
# [OK] N64 G Jalan34.csv
# [OK] N64 G Jalan35.csv
# [OK] N64 G Jalan36.csv
# [OK] N64 G Jalan37.csv
# [OK] N64 G Jalan38.csv
# [OK] N64 G Jalan39.csv
# [OK] N64 G Jalan4.csv
# [OK] N64 G Jalan40.csv
# [OK] N64 G Jalan41.csv
# [OK] N64 G Jalan42.csv
# [OK] N64 G Jalan43.csv
# [OK] N64 G Jalan44.csv
# [OK] N64 G Jalan45.csv
# [OK] N64 G Jalan46.csv
# [OK] N64 G Jalan47.csv
# [OK] N64 G Jalan48.csv
# [OK] N64 G Jalan49.csv
# [OK] N64 G Jalan5.csv
# [OK] N64 G Jalan50.csv
# [OK] N64 G Jalan51.csv
# [OK] N64 G Jalan52.csv
# [OK] N64 G Jalan53.csv
# [OK] N64 G Jalan54.csv
# [OK] N64 G Jalan55.csv
# [OK] N64 G Jalan56.csv
# [OK] N64 G Jalan57.csv
# [OK] N64 G Jalan58.csv
# [OK] N64 G Jalan59.csv
# [OK] N64 G Jalan6.csv
# [OK] N64 G Jalan60.csv
# [OK] N64 G Jalan61.csv
# [OK] N64 G Jalan62.csv
# [OK] N64 G Jalan63.csv
# [OK] N64 G Jalan64.csv
# [OK] N64 G Jalan65.csv
# [OK] N64 G Jalan66.csv
# [OK] N64 G Jalan67.csv
# [OK] N64 G Jalan68.csv
# [OK] N64 G Jalan69.csv
# [OK] N64 G Jalan7.csv
# [OK] N64 G Jalan70.csv
# [OK] N64 G Jalan71.csv
# [OK] N64 G Jalan72.csv
# [OK] N64 G Jalan8.csv
# [OK] N64 G Jalan9.csv
# [OK] N64 H Jalan1.csv
# [OK] N64 H Jalan10.csv
# [OK] N64 H Jalan11.csv
# [OK] N64 H Jalan12.csv
# [OK] N64 H Jalan13.csv
# [OK] N64 H Jalan14.csv
# [OK] N64 H Jalan15.csv
# [OK] N64 H Jalan16.csv
# [OK] N64 H Jalan17.csv
# [OK] N64 H Jalan18.csv
# [OK] N64 H Jalan19.csv
# [OK] N64 H Jalan2.csv
# [OK] N64 H Jalan20.csv
# [OK] N64 H Jalan21.csv
# [OK] N64 H Jalan22.csv
# [OK] N64 H Jalan23.csv
# [OK] N64 H Jalan24.csv
# [OK] N64 H Jalan25.csv
# [OK] N64 H Jalan26.csv
# [OK] N64 H Jalan27.csv
# [OK] N64 H Jalan28.csv
# [OK] N64 H Jalan29.csv
# [OK] N64 H Jalan3.csv
# [OK] N64 H Jalan30.csv
# [OK] N64 H Jalan31.csv
# [OK] N64 H Jalan32.csv
# [OK] N64 H Jalan33.csv
# [OK] N64 H Jalan34.csv
# [OK] N64 H Jalan35.csv
# [OK] N64 H Jalan36.csv
# [OK] N64 H Jalan37.csv
# [OK] N64 H Jalan38.csv
# [OK] N64 H Jalan39.csv
# [OK] N64 H Jalan4.csv
# [OK] N64 H Jalan40.csv
# [OK] N64 H Jalan41.csv
# [OK] N64 H Jalan42.csv
# [OK] N64 H Jalan43.csv
# [OK] N64 H Jalan44.csv
# [OK] N64 H Jalan45.csv
# [OK] N64 H Jalan46.csv
# [OK] N64 H Jalan47.csv
# [OK] N64 H Jalan48.csv
# [OK] N64 H Jalan49.csv
# [OK] N64 H Jalan5.csv
# [OK] N64 H Jalan50.csv
# [OK] N64 H Jalan51.csv
# [OK] N64 H Jalan52.csv
# [OK] N64 H Jalan53.csv
# [OK] N64 H Jalan54.csv
# [OK] N64 H Jalan55.csv
# [OK] N64 H Jalan56.csv
# [OK] N64 H Jalan57.csv
# [OK] N64 H Jalan58.csv
# [OK] N64 H Jalan59.csv
# [OK] N64 H Jalan6.csv
# [OK] N64 H Jalan60.csv
# [OK] N64 H Jalan61.csv
# [OK] N64 H Jalan62.csv
# [OK] N64 H Jalan63.csv
# [OK] N64 H Jalan64.csv
# [OK] N64 H Jalan65.csv
# [OK] N64 H Jalan66.csv
# [OK] N64 H Jalan67.csv
# [OK] N64 H Jalan68.csv
# [OK] N64 H Jalan69.csv
# [OK] N64 H Jalan7.csv
# [OK] N64 H Jalan70.csv
# [OK] N64 H Jalan71.csv
# [OK] N64 H Jalan72.csv
# [OK] N64 H Jalan8.csv
# [OK] N64 H Jalan9.csv
# [OK] N64 I Jalan1.csv
# [OK] N64 I Jalan10.csv
# [OK] N64 I Jalan11.csv
# [OK] N64 I Jalan12.csv
# [OK] N64 I Jalan13.csv
# [OK] N64 I Jalan14.csv
# [OK] N64 I Jalan15.csv
# [OK] N64 I Jalan16.csv
# [OK] N64 I Jalan17.csv
# [OK] N64 I Jalan18.csv
# [OK] N64 I Jalan19.csv
# [OK] N64 I Jalan2.csv
# [OK] N64 I Jalan20.csv
# [OK] N64 I Jalan21.csv
# [OK] N64 I Jalan22.csv
# [OK] N64 I Jalan23.csv
# [OK] N64 I Jalan24.csv
# [OK] N64 I Jalan25.csv
# [OK] N64 I Jalan26.csv
# [OK] N64 I Jalan27.csv
# [OK] N64 I Jalan28.csv
# [OK] N64 I Jalan29.csv
# [OK] N64 I Jalan3.csv
# [OK] N64 I Jalan30.csv
# [OK] N64 I Jalan31.csv
# [OK] N64 I Jalan32.csv
# [OK] N64 I Jalan33.csv
# [OK] N64 I Jalan34.csv
# [OK] N64 I Jalan35.csv
# [OK] N64 I Jalan36.csv
# [OK] N64 I Jalan37.csv
# [OK] N64 I Jalan38.csv
# [OK] N64 I Jalan39.csv
# [OK] N64 I Jalan4.csv
# [OK] N64 I Jalan40.csv
# [OK] N64 I Jalan41.csv
# [OK] N64 I Jalan42.csv
# [OK] N64 I Jalan43.csv
# [OK] N64 I Jalan44.csv
# [OK] N64 I Jalan45.csv
# [OK] N64 I Jalan46.csv
# [OK] N64 I Jalan47.csv
# [OK] N64 I Jalan48.csv
# [OK] N64 I Jalan49.csv
# [OK] N64 I Jalan5.csv
# [OK] N64 I Jalan50.csv
# [OK] N64 I Jalan51.csv
# [OK] N64 I Jalan52.csv
# [OK] N64 I Jalan53.csv
# [OK] N64 I Jalan54.csv
# [OK] N64 I Jalan55.csv
# [OK] N64 I Jalan56.csv
# [OK] N64 I Jalan57.csv
# [OK] N64 I Jalan58.csv
# [OK] N64 I Jalan59.csv
# [OK] N64 I Jalan6.csv
# [OK] N64 I Jalan60.csv
# [OK] N64 I Jalan61.csv
# [OK] N64 I Jalan62.csv
# [OK] N64 I Jalan63.csv
# [OK] N64 I Jalan64.csv
# [OK] N64 I Jalan65.csv
# [OK] N64 I Jalan66.csv
# [OK] N64 I Jalan67.csv
# [OK] N64 I Jalan68.csv
# [OK] N64 I Jalan69.csv
# [OK] N64 I Jalan7.csv
# [OK] N64 I Jalan70.csv
# [OK] N64 I Jalan71.csv
# [OK] N64 I Jalan72.csv
# [OK] N64 I Jalan8.csv
# [OK] N64 I Jalan9.csv
# [OK] N64 J Jalan1.csv
# [OK] N64 J Jalan10.csv
# [OK] N64 J Jalan11.csv
# [OK] N64 J Jalan12.csv
# [OK] N64 J Jalan13.csv
# [OK] N64 J Jalan14.csv
# [OK] N64 J Jalan15.csv
# [OK] N64 J Jalan16.csv
# [OK] N64 J Jalan17.csv
# [OK] N64 J Jalan18.csv
# [OK] N64 J Jalan19.csv
# [OK] N64 J Jalan2.csv
# [OK] N64 J Jalan20.csv
# [OK] N64 J Jalan21.csv
# [OK] N64 J Jalan22.csv
# [OK] N64 J Jalan23.csv
# [OK] N64 J Jalan24.csv
# [OK] N64 J Jalan25.csv
# [OK] N64 J Jalan26.csv
# [OK] N64 J Jalan27.csv
# [OK] N64 J Jalan28.csv
# [OK] N64 J Jalan29.csv
# [OK] N64 J Jalan3.csv
# [OK] N64 J Jalan30.csv
# [OK] N64 J Jalan31.csv
# [OK] N64 J Jalan32.csv
# [OK] N64 J Jalan33.csv
# [OK] N64 J Jalan34.csv
# [OK] N64 J Jalan35.csv
# [OK] N64 J Jalan36.csv
# [OK] N64 J Jalan37.csv
# [OK] N64 J Jalan38.csv
# [OK] N64 J Jalan39.csv
# [OK] N64 J Jalan4.csv
# [OK] N64 J Jalan40.csv
# [OK] N64 J Jalan41.csv
# [OK] N64 J Jalan42.csv
# [OK] N64 J Jalan43.csv
# [OK] N64 J Jalan44.csv
# [OK] N64 J Jalan45.csv
# [OK] N64 J Jalan46.csv
# [OK] N64 J Jalan47.csv
# [OK] N64 J Jalan48.csv
# [OK] N64 J Jalan49.csv
# [OK] N64 J Jalan5.csv
# [OK] N64 J Jalan50.csv
# [OK] N64 J Jalan51.csv
# [OK] N64 J Jalan52.csv
# [OK] N64 J Jalan53.csv
# [OK] N64 J Jalan54.csv
# [OK] N64 J Jalan55.csv
# [OK] N64 J Jalan56.csv
# [OK] N64 J Jalan57.csv
# [OK] N64 J Jalan58.csv
# [OK] N64 J Jalan59.csv
# [OK] N64 J Jalan6.csv
# [OK] N64 J Jalan60.csv
# [OK] N64 J Jalan61.csv
# [OK] N64 J Jalan62.csv
# [OK] N64 J Jalan63.csv
# [OK] N64 J Jalan64.csv
# [OK] N64 J Jalan65.csv
# [OK] N64 J Jalan66.csv
# [OK] N64 J Jalan67.csv
# [OK] N64 J Jalan68.csv
# [OK] N64 J Jalan69.csv
# [OK] N64 J Jalan7.csv
# [OK] N64 J Jalan70.csv
# [OK] N64 J Jalan71.csv
# [OK] N64 J Jalan72.csv
# [OK] N64 J Jalan8.csv
# [OK] N64 J Jalan9.csv
# Saved: E:\0.TA_Teguh\EvalSampling\summary_scorecard_all.csv
#   subject         file  N_target         kind  frames  shape_p50_diff_mean  \
# 0       A   Jalan1.csv        48  fps_overall      82             0.010388
# 1       A   Jalan1.csv        48     fps_down      17             0.007994
# 2       A   Jalan1.csv        48       fps_up      63             0.011364
# 3       A   Jalan1.csv        48  wrs_overall      82             0.009740
# 4       A   Jalan1.csv        48     wrs_down      17             0.004867
# 5       A   Jalan1.csv        48       wrs_up      63             0.011364
# 6       A  Jalan10.csv        48  fps_overall      87             0.009342
# 7       A  Jalan10.csv        48     fps_down      35             0.013015
# 8       A  Jalan10.csv        48       fps_up      51             0.007004
# 9       A  Jalan10.csv        48  wrs_overall      87             0.011861
#
#    shape_p90_diff_mean  centroid_drift_mean  nn_p95_mean  unique_ratio_mean  \
# 0             0.042235             0.026423     0.007001           0.617378
# 1             0.010804             0.023426     0.033768           1.000000
# 2             0.052057             0.028070     0.000000           0.501984
# 3             0.041647             0.024779     0.009542           0.617378
# 4             0.007967             0.015495     0.046025           1.000000
# 5             0.052057             0.028070     0.000000           0.501984
# 6             0.027652             0.030168     0.010827           0.691331
# 7             0.034640             0.044480     0.026914           1.000000
# 8             0.023398             0.020939     0.000000           0.473448
# 9             0.023205             0.020838     0.019672           0.691331
#
#    max_dup_p95  jitter_base  jitter_fps  jitter_wrs
# 0        12.95     0.615389    0.608574    0.608526
# 1         1.00     0.615389    0.608574    0.608526
# 2        13.00     0.615389    0.608574    0.608526
# 3        12.95     0.615389    0.608574    0.608526
# 4         1.00     0.615389    0.608574    0.608526
# 5        13.00     0.615389    0.608574    0.608526
# 6        13.00     0.500190    0.508407    0.503886
# 7         1.00     0.500190    0.508407    0.503886
# 8        13.00     0.500190    0.508407    0.503886
# 9        13.00     0.500190    0.508407    0.503886

# %% [markdown]
# Cell 7 — Tampilkan perbandingan FPS vs WRS

# %%
def summarize_compare(df_summary, n_target, kind_suffix="overall"):
    fps = df_summary[(df_summary["N_target"]==n_target) & (df_summary["kind"]==f"fps_{kind_suffix}")]
    wrs = df_summary[(df_summary["N_target"]==n_target) & (df_summary["kind"]==f"wrs_{kind_suffix}")]

    # gabung per subject+file
    merged = fps.merge(
        wrs,
        on=["subject","file","N_target","frames","jitter_base","jitter_fps","jitter_wrs"],
        suffixes=("_fps","_wrs"),
        how="inner"
    )
    # agregasi global (mean)
    out = {
        "N_target": n_target,
        "kind": kind_suffix,
        "shape_p50_diff_mean_fps": float(merged["shape_p50_diff_mean_fps"].mean()),
        "shape_p50_diff_mean_wrs": float(merged["shape_p50_diff_mean_wrs"].mean()),
        "shape_p90_diff_mean_fps": float(merged["shape_p90_diff_mean_fps"].mean()),
        "shape_p90_diff_mean_wrs": float(merged["shape_p90_diff_mean_wrs"].mean()),
        "centroid_drift_mean_fps": float(merged["centroid_drift_mean_fps"].mean()),
        "centroid_drift_mean_wrs": float(merged["centroid_drift_mean_wrs"].mean()),
        "nn_p95_mean_fps": float(merged["nn_p95_mean_fps"].mean()),
        "nn_p95_mean_wrs": float(merged["nn_p95_mean_wrs"].mean()),
        "unique_ratio_mean_fps": float(merged["unique_ratio_mean_fps"].mean()),
        "unique_ratio_mean_wrs": float(merged["unique_ratio_mean_wrs"].mean()),
        "max_dup_p95_fps": float(merged["max_dup_p95_fps"].mean()),
        "max_dup_p95_wrs": float(merged["max_dup_p95_wrs"].mean()),
        "jitter_ratio_fps": float((merged["jitter_fps"] / (merged["jitter_base"] + 1e-9)).mean()),
        "jitter_ratio_wrs": float((merged["jitter_wrs"] / (merged["jitter_base"] + 1e-9)).mean()),
        "n_files": int(len(merged))
    }
    return out

rows = []
for n in N_TARGETS:
    rows.append(summarize_compare(df_summary, n, "overall"))
    rows.append(summarize_compare(df_summary, n, "down"))
    rows.append(summarize_compare(df_summary, n, "up"))

df_compare = pd.DataFrame(rows)
out_compare_path = OUT_DIR / "compare_fps_vs_wrs.csv"
df_compare.to_csv(out_compare_path, index=False)

print("Saved:", out_compare_path)
df_compare
# Out:
# Saved: E:\0.TA_Teguh\EvalSampling\compare_fps_vs_wrs.csv
#    N_target     kind  shape_p50_diff_mean_fps  shape_p50_diff_mean_wrs  \
# 0        48  overall                 0.011009                 0.010432
# 1        48     down                 0.010893                 0.009169
# 2        48       up                 0.010829                 0.010829
# 3        56  overall                 0.010511                 0.009708
# 4        56     down                 0.010721                 0.008158
# 5        56       up                 0.010040                 0.010040
# 6        64  overall                 0.010074                 0.009210
# 7        64     down                 0.010986                 0.007686
# 8        64       up                 0.009450                 0.009450
#
#    shape_p90_diff_mean_fps  shape_p90_diff_mean_wrs  centroid_drift_mean_fps  \
# 0                 0.051058                 0.052331                 0.034050
# 1                 0.022765                 0.025700                 0.031921
# 2                 0.067040                 0.067040                 0.034782
# 3                 0.049412                 0.049739                 0.032865
# 4                 0.021796                 0.022686                 0.033651
# 5                 0.059826                 0.059826                 0.031677
# 6                 0.049555                 0.049170                 0.031481
# 7                 0.022077                 0.020953                 0.035118
# 8                 0.056159                 0.056159                 0.029455
#
#    centroid_drift_mean_wrs  nn_p95_mean_fps  nn_p95_mean_wrs  \
# 0                 0.030560         0.012112         0.021832
# 1                 0.022577         0.029156         0.050647
# 2                 0.034782         0.000000         0.000000
# 3                 0.028823         0.008328         0.014776
# 4                 0.020773         0.025564         0.043356
# 5                 0.031677         0.000000         0.000000
# 6                 0.027352         0.005619         0.009731
# 7                 0.018666         0.022201         0.037017
# 8                 0.029455         0.000000         0.000000
#
#    unique_ratio_mean_fps  unique_ratio_mean_wrs  max_dup_p95_fps  \
# 0               0.692589               0.692589        11.409028
# 1               1.000000               1.000000         1.000000
# 2               0.488042               0.488042        12.762917
# 3               0.646926               0.646926        13.019653
# 4               1.000000               1.000000         1.000000
# 5               0.486627               0.486627        14.319375
# 6               0.602552               0.602552        14.661667
# 7               1.000000               1.000000         1.000000
# 8               0.478446               0.478446        15.755417
#
#    max_dup_p95_wrs  jitter_ratio_fps  jitter_ratio_wrs  n_files
# 0        11.409028          0.995412          0.997628      720
# 1         1.000000          0.996021          0.998304      699
# 2        12.762917          0.995412          0.997628      720
# 3        13.019653          0.995250          0.997135      720
# 4         1.000000          0.996607          0.998594      683
# 5        14.319375          0.995250          0.997135      720
# 6        14.661667          0.994959          0.996422      720
# 7         1.000000          0.996594          0.998173      667
# 8        15.755417          0.994959          0.996422      720
