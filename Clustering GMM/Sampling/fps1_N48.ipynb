# %% [markdown]
# Cell 1 — Imports & Config

# %%
from pathlib import Path
import numpy as np
import pandas as pd
from typing import Dict, Tuple, List

# Paths
DATASET_ROOT = Path(r"E:\0.TA_Teguh\GMM Trial 2")
HEAD1_DIR = DATASET_ROOT / "Head 1"
OUT_ROOT = Path(r"E:\0.TA_Teguh\Sampling\FPS")     

# Subjects A..J
SUBJECTS = list("ABCDEFGHIJ")

# Candidates
N_TARGETS = [48, 56, 64]
RUN_N_TARGETS = [48]  # start with one; change to [48,56,64] after sanity check

# Must-match Head-1 columns
COLS_EXPECTED = ["timestamp","frame","x","y","z","doppler","SNR","w_snr","d2","is_inlier"]
COLS_OUT = COLS_EXPECTED[:]  # keep order

# Sampling settings
START_MODE = "centroid_nearest"
EPS_W = 1e-12

# Read/write config
CSV_READ_KWARGS = dict(dtype={
    "timestamp": str,
    "frame": np.int32,
    "x": np.float32,
    "y": np.float32,
    "z": np.float32,
    "doppler": np.float32,
    "SNR": np.float32,
    "w_snr": np.float32,
    "d2": np.float32,
    "is_inlier": np.int8,
})
CSV_WRITE_KWARGS = dict(index=False)

print("OK | HEAD1_DIR:", HEAD1_DIR)
print("OK | OUT_ROOT :", OUT_ROOT)
print("RUN_N_TARGETS :", RUN_N_TARGETS)
# Out:
# OK | HEAD1_DIR: E:\0.TA_Teguh\GMM Trial 2\Head 1
# OK | OUT_ROOT : E:\0.TA_Teguh\Sampling\FPS
# RUN_N_TARGETS : [48]

# %% [markdown]
# Cell 2 — Deterministic seed helper

# %%
import hashlib

def stable_seed(subject: str, file_name: str, frame: int, n_target: int) -> int:
    """
    Stable seed across runs/machines for weighted resampling.
    """
    s = f"{subject}|{file_name}|{frame}|{n_target}"
    h = hashlib.sha256(s.encode("utf-8")).hexdigest()
    # Take first 8 hex chars -> 32-bit
    return int(h[:8], 16)

# %% [markdown]
# Cell 3 — IO helpers (list files, read head1)

# %%
def list_jalan_csvs(subject_dir: Path) -> List[Path]:
    if not subject_dir.exists():
        return []
    return sorted(subject_dir.glob("Jalan*.csv"))

def read_head1_csv(path: Path) -> pd.DataFrame:
    df = pd.read_csv(path, **CSV_READ_KWARGS)
    missing = [c for c in COLS_EXPECTED if c not in df.columns]
    if missing:
        raise ValueError(f"Missing columns in {path.name}: {missing}")
    # Ensure correct column order (and drop extras if any)
    df = df[COLS_EXPECTED].copy()
    return df

# %% [markdown]
# Cell 4 — Frame extraction & sanitization

# %%
def get_frame_df(df: pd.DataFrame, frame_id: int) -> pd.DataFrame:
    f = df[df["frame"] == frame_id].copy()
    if f.empty:
        return f
    # Drop NaN/Inf just in case (should be clean already)
    num_cols = ["x","y","z","doppler","SNR","w_snr","d2"]
    for c in num_cols:
        v = f[c].to_numpy()
        ok = np.isfinite(v)
        if not ok.all():
            f = f.loc[ok].copy()
    return f

def xyz_array(frame_df: pd.DataFrame) -> np.ndarray:
    return frame_df[["x","y","z"]].to_numpy(dtype=np.float32, copy=False)

# %% [markdown]
# Cell 5 — FPS core (downsample only)

# %%
def fps_indices(xyz: np.ndarray, n_select: int, start_idx: int) -> np.ndarray:
    """
    xyz: [M,3], n_select <= M
    Returns indices length n_select using farthest point sampling.
    """
    M = xyz.shape[0]
    if n_select >= M:
        return np.arange(M, dtype=np.int32)

    selected = np.empty(n_select, dtype=np.int32)
    selected[0] = start_idx

    # min squared distance to the selected set for each point
    diff0 = xyz - xyz[start_idx]
    min_dist2 = np.einsum("ij,ij->i", diff0, diff0).astype(np.float32)

    for i in range(1, n_select):
        nxt = int(np.argmax(min_dist2))
        selected[i] = nxt
        diff = xyz - xyz[nxt]
        dist2 = np.einsum("ij,ij->i", diff, diff).astype(np.float32)
        min_dist2 = np.minimum(min_dist2, dist2)

    return selected

# %% [markdown]
# Cell 6 — Start point selection (centroid-nearest)

# %%
def start_index_centroid_nearest(xyz: np.ndarray) -> int:
    c = xyz.mean(axis=0)
    diff = xyz - c
    dist2 = np.einsum("ij,ij->i", diff, diff)
    return int(np.argmin(dist2))

# %% [markdown]
# Cell 7 — Shared upsample (weighted replacement by w_snr)

# %%
def weighted_resample_indices(w: np.ndarray, k: int, seed: int) -> np.ndarray:
    """
    Sample k indices with replacement using probability ∝ w.
    """
    if k <= 0:
        return np.empty((0,), dtype=np.int32)

    w = np.asarray(w, dtype=np.float64)
    w = np.clip(w, 0.0, None)
    s = w.sum()
    if not np.isfinite(s) or s <= EPS_W:
        # fallback to uniform if weights degenerate
        p = None
    else:
        p = w / s

    rng = np.random.default_rng(seed)
    return rng.choice(len(w), size=k, replace=True, p=p).astype(np.int32)

# %% [markdown]
# Cell 8 — Per-frame sampler (FPS + shared upsample)

# %%
def sample_frame_fps(frame_df: pd.DataFrame, n_target: int, subject: str, file_name: str) -> Tuple[pd.DataFrame, Dict]:
    """
    Returns sampled_frame_df with SAME columns as input (COLS_OUT).
    """
    M = len(frame_df)
    meta = {"M": M, "N": n_target, "action": None, "n_drop": 0, "n_fill": 0}

    if M == 0:
        meta["action"] = "empty"
        return frame_df[COLS_OUT].copy(), meta

    if M == n_target:
        meta["action"] = "equal"
        return frame_df[COLS_OUT].copy(), meta

    if M > n_target:
        xyz = xyz_array(frame_df)
        start_idx = start_index_centroid_nearest(xyz)
        idx = fps_indices(xyz, n_target, start_idx)
        out = frame_df.iloc[idx].copy()
        meta["action"] = "downsample"
        meta["n_drop"] = M - n_target
        return out[COLS_OUT], meta

    # M < n_target → upsample with replacement using w_snr
    k = n_target - M
    seed = stable_seed(subject, file_name, int(frame_df["frame"].iloc[0]), n_target)
    add_idx = weighted_resample_indices(frame_df["w_snr"].to_numpy(), k=k, seed=seed)
    add = frame_df.iloc[add_idx].copy()
    out = pd.concat([frame_df, add], axis=0, ignore_index=True)
    meta["action"] = "upsample"
    meta["n_fill"] = k
    return out[COLS_OUT], meta

# %% [markdown]
# Cell 9 — Per-file processing (loop frames, save CSV)

# %%
def process_one_file(head1_path: Path, subject: str, n_target: int) -> Dict:
    """
    Process one Jalan*.csv from Head-1 and write sampled output CSV.
    """
    df = read_head1_csv(head1_path)

    file_name = head1_path.name
    out_dir = OUT_ROOT / f"N{n_target}" / subject
    out_dir.mkdir(parents=True, exist_ok=True)
    out_path = out_dir / file_name

    frames = df["frame"].unique()
    frames.sort()

    out_chunks = []
    stats = {"file": file_name, "subject": subject, "N": n_target,
             "frames": int(len(frames)), "down": 0, "up": 0, "eq": 0, "empty": 0,
             "total_drop": 0, "total_fill": 0}

    for fr in frames:
        fdf = get_frame_df(df, int(fr))
        sampled, meta = sample_frame_fps(fdf, n_target=n_target, subject=subject, file_name=file_name)

        out_chunks.append(sampled)

        act = meta["action"]
        if act == "downsample":
            stats["down"] += 1
            stats["total_drop"] += int(meta["n_drop"])
        elif act == "upsample":
            stats["up"] += 1
            stats["total_fill"] += int(meta["n_fill"])
        elif act == "equal":
            stats["eq"] += 1
        else:
            stats["empty"] += 1

    out_df = pd.concat(out_chunks, axis=0, ignore_index=True)
    out_df.to_csv(out_path, **CSV_WRITE_KWARGS)
    return stats

# %% [markdown]
# Cell 10 — Run all (batch: subject → file), plus summary CSV

# %%
all_stats = []

for n_target in RUN_N_TARGETS:
    for subject in SUBJECTS:
        subj_dir = HEAD1_DIR / subject
        files = list_jalan_csvs(subj_dir)
        if not files:
            print(f"[WARN] No files for subject {subject} in {subj_dir}")
            continue

        print(f"\n=== N={n_target} | Subject {subject} | files={len(files)} ===")
        for p in files:
            st = process_one_file(p, subject=subject, n_target=n_target)
            all_stats.append(st)
            print(f"  {st['file']}: frames={st['frames']}, down={st['down']}, up={st['up']}, eq={st['eq']}, "
                  f"fill={st['total_fill']}, drop={st['total_drop']}")

# Save summary
summary_df = pd.DataFrame(all_stats)
summary_path = OUT_ROOT / "fps_sampling_summary.csv"
summary_df.to_csv(summary_path, index=False)
print("\nSaved summary:", summary_path)
summary_df.head()
# Out:
# === N=48 | Subject A | files=72 ===
#   Jalan1.csv: frames=82, down=17, up=63, eq=2, fill=1506, drop=256
#   Jalan10.csv: frames=87, down=35, up=51, eq=1, fill=1289, drop=799
#   Jalan11.csv: frames=87, down=42, up=44, eq=1, fill=1219, drop=1653
#   Jalan12.csv: frames=98, down=51, up=46, eq=1, fill=1205, drop=1303
#   Jalan13.csv: frames=103, down=47, up=53, eq=3, fill=1084, drop=1163
#   Jalan14.csv: frames=81, down=11, up=69, eq=1, fill=1769, drop=131
#   Jalan15.csv: frames=239, down=86, up=152, eq=1, fill=4187, drop=1674
#   Jalan16.csv: frames=229, down=84, up=142, eq=3, fill=3651, drop=1796
#   Jalan17.csv: frames=194, down=97, up=94, eq=3, fill=1869, drop=2920
#   Jalan18.csv: frames=166, down=125, up=40, eq=1, fill=780, drop=4954
#   Jalan19.csv: frames=222, down=86, up=134, eq=2, fill=3192, drop=2386
#   Jalan2.csv: frames=85, down=58, up=26, eq=1, fill=462, drop=1815
#   Jalan20.csv: frames=174, down=97, up=75, eq=2, fill=2118, drop=2167
#   Jalan21.csv: frames=149, down=75, up=71, eq=3, fill=1846, drop=2518
#   Jalan22.csv: frames=125, down=93, up=31, eq=1, fill=626, drop=3496
#   Jalan23.csv: frames=424, down=104, up=317, eq=3, fill=8448, drop=1776
#   Jalan24.csv: frames=433, down=220, up=203, eq=10, fill=4687, drop=5332
#   Jalan25.csv: frames=74, down=13, up=60, eq=1, fill=1308, drop=148
#   Jalan26.csv: frames=76, down=57, up=19, eq=0, fill=354, drop=1569
#   Jalan27.csv: frames=71, down=48, up=20, eq=3, fill=495, drop=1872
#   Jalan28.csv: frames=52, down=8, up=44, eq=0, fill=1196, drop=101
#   Jalan29.csv: frames=48, down=25, up=23, eq=0, fill=628, drop=724
#   Jalan3.csv: frames=85, down=61, up=23, eq=1, fill=417, drop=2196
#   Jalan30.csv: frames=66, down=28, up=37, eq=1, fill=880, drop=607
#   Jalan31.csv: frames=64, down=8, up=55, eq=1, fill=1289, drop=110
#   Jalan32.csv: frames=53, down=1, up=52, eq=0, fill=1493, drop=19
#   Jalan33.csv: frames=66, down=15, up=49, eq=2, fill=1230, drop=181
#   Jalan34.csv: frames=63, down=24, up=39, eq=0, fill=861, drop=414
#   Jalan35.csv: frames=61, down=29, up=32, eq=0, fill=997, drop=925
#   Jalan36.csv: frames=71, down=33, up=38, eq=0, fill=1024, drop=872
#   Jalan37.csv: frames=77, down=28, up=49, eq=0, fill=1418, drop=614
#   Jalan38.csv: frames=60, down=20, up=40, eq=0, fill=929, drop=367
#   Jalan39.csv: frames=182, down=70, up=110, eq=2, fill=3163, drop=1435
#   Jalan4.csv: frames=60, down=10, up=50, eq=0, fill=1298, drop=150
#   Jalan40.csv: frames=178, down=83, up=94, eq=1, fill=2437, drop=2629
#   Jalan41.csv: frames=162, down=87, up=74, eq=1, fill=1658, drop=2926
#   Jalan42.csv: frames=112, down=70, up=42, eq=0, fill=1066, drop=2417
#   Jalan43.csv: frames=161, down=61, up=96, eq=4, fill=2698, drop=1897
#   Jalan44.csv: frames=135, down=68, up=66, eq=1, fill=1799, drop=2022
#   Jalan45.csv: frames=123, down=65, up=57, eq=1, fill=1444, drop=2585
#   Jalan46.csv: frames=96, down=69, up=26, eq=1, fill=452, drop=2920
#   Jalan47.csv: frames=295, down=93, up=201, eq=1, fill=5311, drop=1914
#   Jalan48.csv: frames=312, down=161, up=149, eq=2, fill=4088, drop=4383
#   Jalan49.csv: frames=96, down=21, up=69, eq=6, fill=1680, drop=354
#   Jalan5.csv: frames=67, down=0, up=67, eq=0, fill=1926, drop=0
#   Jalan50.csv: frames=114, down=84, up=29, eq=1, fill=465, drop=2738
#   Jalan51.csv: frames=117, down=76, up=41, eq=0, fill=805, drop=2101
#   Jalan52.csv: frames=76, down=21, up=55, eq=0, fill=1740, drop=214
#   Jalan53.csv: frames=73, down=33, up=39, eq=1, fill=845, drop=821
#   Jalan54.csv: frames=105, down=49, up=55, eq=1, fill=1497, drop=1036
#   Jalan55.csv: frames=85, down=15, up=67, eq=3, fill=1731, drop=245
#   Jalan56.csv: frames=76, down=4, up=72, eq=0, fill=2302, drop=12
#   Jalan57.csv: frames=90, down=23, up=65, eq=2, fill=1639, drop=290
#   Jalan58.csv: frames=119, down=53, up=66, eq=0, fill=1597, drop=1220
#   Jalan59.csv: frames=117, down=60, up=57, eq=0, fill=1399, drop=2061
#   Jalan6.csv: frames=71, down=17, up=51, eq=3, fill=1398, drop=222
#   Jalan60.csv: frames=118, down=13, up=104, eq=1, fill=2953, drop=194
#   Jalan61.csv: frames=141, down=52, up=88, eq=1, fill=2028, drop=937
#   Jalan62.csv: frames=132, down=76, up=55, eq=1, fill=1096, drop=2187
#   Jalan63.csv: frames=332, down=128, up=201, eq=3, fill=5422, drop=2554
#   Jalan64.csv: frames=310, down=120, up=188, eq=2, fill=5122, drop=2830
#   Jalan65.csv: frames=207, down=110, up=95, eq=2, fill=2073, drop=3059
#   Jalan66.csv: frames=179, down=119, up=59, eq=1, fill=1142, drop=4774
#   Jalan67.csv: frames=273, down=108, up=161, eq=4, fill=4377, drop=3142
#   Jalan68.csv: frames=202, down=103, up=96, eq=3, fill=2243, drop=3514
#   Jalan69.csv: frames=158, down=107, up=49, eq=2, fill=1133, drop=3586
#   Jalan7.csv: frames=87, down=30, up=57, eq=0, fill=1479, drop=603
#   Jalan70.csv: frames=133, down=85, up=46, eq=2, fill=1038, drop=3547
#   Jalan71.csv: frames=534, down=147, up=378, eq=9, fill=10306, drop=2266
#   Jalan72.csv: frames=538, down=244, up=290, eq=4, fill=7138, drop=6578
#   Jalan8.csv: frames=55, down=29, up=25, eq=1, fill=558, drop=730
#   Jalan9.csv: frames=73, down=11, up=62, eq=0, fill=1628, drop=165
#
# === N=48 | Subject B | files=72 ===
#   Jalan1.csv: frames=94, down=26, up=68, eq=0, fill=1428, drop=465
#   Jalan10.csv: frames=96, down=43, up=53, eq=0, fill=1466, drop=1165
#   Jalan11.csv: frames=98, down=37, up=60, eq=1, fill=1443, drop=562
#   Jalan12.csv: frames=106, down=43, up=60, eq=3, fill=1595, drop=1426
#   Jalan13.csv: frames=112, down=66, up=42, eq=4, fill=946, drop=1829
#   Jalan14.csv: frames=105, down=41, up=63, eq=1, fill=1776, drop=910
#   Jalan15.csv: frames=296, down=79, up=215, eq=2, fill=6050, drop=1688
#   Jalan16.csv: frames=264, down=104, up=156, eq=4, fill=4097, drop=2719
#   Jalan17.csv: frames=229, down=116, up=107, eq=6, fill=2159, drop=2846
#   Jalan18.csv: frames=191, down=147, up=43, eq=1, fill=825, drop=4933
#   Jalan19.csv: frames=276, down=65, up=210, eq=1, fill=6025, drop=1609
#   Jalan2.csv: frames=111, down=79, up=31, eq=1, fill=584, drop=2919
#   Jalan20.csv: frames=248, down=83, up=161, eq=4, fill=4539, drop=1640
#   Jalan21.csv: frames=208, down=133, up=73, eq=2, fill=1449, drop=4053
#   Jalan22.csv: frames=184, down=138, up=45, eq=1, fill=854, drop=4989
#   Jalan23.csv: frames=471, down=180, up=288, eq=3, fill=7001, drop=3450
#   Jalan24.csv: frames=475, down=161, up=307, eq=7, fill=7751, drop=6370
#   Jalan25.csv: frames=77, down=26, up=50, eq=1, fill=1081, drop=333
#   Jalan26.csv: frames=84, down=56, up=28, eq=0, fill=539, drop=2165
#   Jalan27.csv: frames=80, down=58, up=20, eq=2, fill=525, drop=2162
#   Jalan28.csv: frames=59, down=1, up=58, eq=0, fill=2202, drop=17
#   Jalan29.csv: frames=70, down=6, up=64, eq=0, fill=1833, drop=48
#   Jalan3.csv: frames=98, down=77, up=21, eq=0, fill=482, drop=2715
#   Jalan30.csv: frames=73, down=21, up=51, eq=1, fill=1518, drop=308
#   Jalan31.csv: frames=77, down=32, up=44, eq=1, fill=949, drop=560
#   Jalan32.csv: frames=66, down=32, up=34, eq=0, fill=1009, drop=843
#   Jalan33.csv: frames=73, down=31, up=41, eq=1, fill=1259, drop=1061
#   Jalan34.csv: frames=71, down=28, up=43, eq=0, fill=1123, drop=670
#   Jalan35.csv: frames=71, down=19, up=51, eq=1, fill=1050, drop=292
#   Jalan36.csv: frames=74, down=23, up=51, eq=0, fill=1231, drop=402
#   Jalan37.csv: frames=85, down=37, up=48, eq=0, fill=1198, drop=853
#   Jalan38.csv: frames=77, down=32, up=45, eq=0, fill=1334, drop=634
#   Jalan39.csv: frames=237, down=75, up=158, eq=4, fill=4771, drop=1325
#   Jalan4.csv: frames=67, down=0, up=67, eq=0, fill=2420, drop=0
#   Jalan40.csv: frames=217, down=65, up=151, eq=1, fill=4139, drop=1726
#   Jalan41.csv: frames=192, down=90, up=97, eq=5, fill=2029, drop=2656
#   Jalan42.csv: frames=146, down=97, up=48, eq=1, fill=829, drop=3090
#   Jalan43.csv: frames=218, down=48, up=170, eq=0, fill=5235, drop=987
#   Jalan44.csv: frames=202, down=80, up=121, eq=1, fill=2864, drop=2266
#   Jalan45.csv: frames=185, down=107, up=78, eq=0, fill=1588, drop=2885
#   Jalan46.csv: frames=155, down=137, up=17, eq=1, fill=221, drop=6090
#   Jalan47.csv: frames=370, down=143, up=220, eq=7, fill=5810, drop=3078
#   Jalan48.csv: frames=402, down=162, up=234, eq=6, fill=5991, drop=5346
#   Jalan49.csv: frames=86, down=10, up=75, eq=1, fill=1975, drop=81
#   Jalan5.csv: frames=78, down=4, up=73, eq=1, fill=2122, drop=26
#   Jalan50.csv: frames=116, down=82, up=32, eq=2, fill=767, drop=2717
#   Jalan51.csv: frames=116, down=79, up=36, eq=1, fill=838, drop=2214
#   Jalan52.csv: frames=85, down=0, up=85, eq=0, fill=3001, drop=0
#   Jalan53.csv: frames=72, down=1, up=71, eq=0, fill=2368, drop=2
#   Jalan54.csv: frames=106, down=14, up=89, eq=3, fill=2222, drop=148
#   Jalan55.csv: frames=110, down=48, up=62, eq=0, fill=1666, drop=1153
#   Jalan56.csv: frames=95, down=42, up=52, eq=1, fill=1272, drop=1145
#   Jalan57.csv: frames=104, down=57, up=47, eq=0, fill=1246, drop=2152
#   Jalan58.csv: frames=116, down=46, up=69, eq=1, fill=1854, drop=1079
#   Jalan59.csv: frames=106, down=41, up=64, eq=1, fill=1497, drop=537
#   Jalan6.csv: frames=95, down=15, up=76, eq=4, fill=2033, drop=125
#   Jalan60.csv: frames=105, down=30, up=75, eq=0, fill=1863, drop=520
#   Jalan61.csv: frames=125, down=44, up=78, eq=3, fill=1833, drop=1133
#   Jalan62.csv: frames=120, down=52, up=66, eq=2, fill=1673, drop=1209
#   Jalan63.csv: frames=337, down=90, up=244, eq=3, fill=6987, drop=1531
#   Jalan64.csv: frames=304, down=98, up=203, eq=3, fill=5206, drop=2191
#   Jalan65.csv: frames=244, down=123, up=118, eq=3, fill=2468, drop=3190
#   Jalan66.csv: frames=208, down=111, up=95, eq=2, fill=1843, drop=3842
#   Jalan67.csv: frames=353, down=79, up=273, eq=1, fill=7878, drop=1861
#   Jalan68.csv: frames=276, down=101, up=173, eq=2, fill=4498, drop=2451
#   Jalan69.csv: frames=259, down=122, up=133, eq=4, fill=2897, drop=3157
#   Jalan7.csv: frames=93, down=49, up=43, eq=1, fill=993, drop=1162
#   Jalan70.csv: frames=216, down=144, up=68, eq=4, fill=1343, drop=4058
#   Jalan71.csv: frames=520, down=151, up=361, eq=8, fill=8945, drop=3199
#   Jalan72.csv: frames=515, down=186, up=328, eq=1, fill=8843, drop=5674
#   Jalan8.csv: frames=78, down=29, up=49, eq=0, fill=1142, drop=495
#   Jalan9.csv: frames=96, down=48, up=46, eq=2, fill=1337, drop=1463
#
# === N=48 | Subject C | files=72 ===
#   Jalan1.csv: frames=130, down=36, up=93, eq=1, fill=2367, drop=561
#   Jalan10.csv: frames=114, down=45, up=68, eq=1, fill=1814, drop=1145
#   Jalan11.csv: frames=110, down=52, up=57, eq=1, fill=1584, drop=1546
#   Jalan12.csv: frames=124, down=46, up=78, eq=0, fill=1932, drop=1161
#   Jalan13.csv: frames=139, down=64, up=74, eq=1, fill=1663, drop=1276
#   Jalan14.csv: frames=119, down=33, up=86, eq=0, fill=2282, drop=595
#   Jalan15.csv: frames=361, down=93, up=264, eq=4, fill=7006, drop=1451
#   Jalan16.csv: frames=333, down=126, up=205, eq=2, fill=5038, drop=2931
#   Jalan17.csv: frames=305, down=138, up=163, eq=4, fill=3499, drop=3011
#   Jalan18.csv: frames=224, down=114, up=105, eq=5, fill=2284, drop=3248
#   Jalan19.csv: frames=326, down=92, up=230, eq=4, fill=5637, drop=1787
#   Jalan2.csv: frames=128, down=73, up=53, eq=2, fill=1075, drop=1941
#   Jalan20.csv: frames=302, down=74, up=220, eq=8, fill=5353, drop=1731
#   Jalan21.csv: frames=261, down=140, up=120, eq=1, fill=2616, drop=3750
#   Jalan22.csv: frames=224, down=140, up=83, eq=1, fill=1662, drop=4371
#   Jalan23.csv: frames=519, down=119, up=396, eq=4, fill=10549, drop=1994
#   Jalan24.csv: frames=576, down=202, up=370, eq=4, fill=9065, drop=5075
#   Jalan25.csv: frames=90, down=25, up=65, eq=0, fill=1467, drop=364
#   Jalan26.csv: frames=127, down=74, up=53, eq=0, fill=1052, drop=2070
#   Jalan27.csv: frames=94, down=58, up=36, eq=0, fill=802, drop=1728
#   Jalan28.csv: frames=64, down=0, up=64, eq=0, fill=2337, drop=0
#   Jalan29.csv: frames=60, down=3, up=57, eq=0, fill=1933, drop=15
#   Jalan3.csv: frames=147, down=103, up=40, eq=4, fill=848, drop=3220
#   Jalan30.csv: frames=77, down=5, up=72, eq=0, fill=2125, drop=42
#   Jalan31.csv: frames=95, down=22, up=73, eq=0, fill=2125, drop=235
#   Jalan32.csv: frames=80, down=45, up=34, eq=1, fill=856, drop=1508
#   Jalan33.csv: frames=85, down=35, up=48, eq=2, fill=1256, drop=1177
#   Jalan34.csv: frames=88, down=29, up=59, eq=0, fill=1708, drop=631
#   Jalan35.csv: frames=88, down=15, up=72, eq=1, fill=1727, drop=190
#   Jalan36.csv: frames=102, down=36, up=66, eq=0, fill=1605, drop=1363
#   Jalan37.csv: frames=94, down=40, up=52, eq=2, fill=1047, drop=705
#   Jalan38.csv: frames=78, down=20, up=58, eq=0, fill=1632, drop=314
#   Jalan39.csv: frames=241, down=66, up=171, eq=4, fill=4874, drop=1156
#   Jalan4.csv: frames=80, down=1, up=79, eq=0, fill=2700, drop=16
#   Jalan40.csv: frames=247, down=98, up=146, eq=3, fill=3792, drop=2260
#   Jalan41.csv: frames=200, down=91, up=109, eq=0, fill=2238, drop=1917
#   Jalan42.csv: frames=144, down=90, up=52, eq=2, fill=1071, drop=2208
#   Jalan43.csv: frames=237, down=76, up=158, eq=3, fill=4189, drop=1818
#   Jalan44.csv: frames=251, down=110, up=137, eq=4, fill=3054, drop=2537
#   Jalan45.csv: frames=206, down=89, up=115, eq=2, fill=2584, drop=2120
#   Jalan46.csv: frames=198, down=116, up=79, eq=3, fill=1737, drop=3347
#   Jalan47.csv: frames=395, down=88, up=303, eq=4, fill=8698, drop=1518
#   Jalan48.csv: frames=429, down=125, up=297, eq=7, fill=7356, drop=3745
#   Jalan49.csv: frames=122, down=41, up=78, eq=3, fill=1912, drop=713
#   Jalan5.csv: frames=65, down=0, up=64, eq=1, fill=1995, drop=0
#   Jalan50.csv: frames=155, down=78, up=77, eq=0, fill=1785, drop=2028
#   Jalan51.csv: frames=140, down=104, up=36, eq=0, fill=861, drop=3137
#   Jalan52.csv: frames=87, down=0, up=87, eq=0, fill=2758, drop=0
#   Jalan53.csv: frames=78, down=0, up=78, eq=0, fill=2301, drop=0
#   Jalan54.csv: frames=111, down=13, up=98, eq=0, fill=2891, drop=90
#   Jalan55.csv: frames=126, down=59, up=66, eq=1, fill=1650, drop=1020
#   Jalan56.csv: frames=109, down=40, up=68, eq=1, fill=1752, drop=1099
#   Jalan57.csv: frames=124, down=61, up=62, eq=1, fill=1651, drop=2318
#   Jalan58.csv: frames=125, down=48, up=76, eq=1, fill=1977, drop=1283
#   Jalan59.csv: frames=129, down=34, up=92, eq=3, fill=2230, drop=472
#   Jalan6.csv: frames=93, down=11, up=81, eq=1, fill=2267, drop=55
#   Jalan60.csv: frames=147, down=45, up=100, eq=2, fill=2438, drop=1259
#   Jalan61.csv: frames=129, down=57, up=72, eq=0, fill=1683, drop=1213
#   Jalan62.csv: frames=115, down=28, up=87, eq=0, fill=2305, drop=351
#   Jalan63.csv: frames=351, down=94, up=254, eq=3, fill=6786, drop=1335
#   Jalan64.csv: frames=333, down=102, up=229, eq=2, fill=5666, drop=2021
#   Jalan65.csv: frames=279, down=105, up=170, eq=4, fill=3835, drop=2013
#   Jalan66.csv: frames=230, down=117, up=109, eq=4, fill=2430, drop=2462
#   Jalan67.csv: frames=280, down=71, up=205, eq=4, fill=5176, drop=897
#   Jalan68.csv: frames=278, down=79, up=195, eq=4, fill=4983, drop=1260
#   Jalan69.csv: frames=257, down=95, up=159, eq=3, fill=3634, drop=1994
#   Jalan7.csv: frames=138, down=34, up=103, eq=1, fill=2574, drop=423
#   Jalan70.csv: frames=226, down=112, up=112, eq=2, fill=2261, drop=2716
#   Jalan71.csv: frames=557, down=153, up=399, eq=5, fill=10325, drop=2451
#   Jalan72.csv: frames=601, down=263, up=329, eq=9, fill=7943, drop=7808
#   Jalan8.csv: frames=109, down=45, up=59, eq=5, fill=1580, drop=1299
#   Jalan9.csv: frames=104, down=36, up=67, eq=1, fill=1503, drop=382
#
# === N=48 | Subject D | files=72 ===
#   Jalan1.csv: frames=91, down=28, up=63, eq=0, fill=1577, drop=510
#   Jalan10.csv: frames=90, down=36, up=53, eq=1, fill=1476, drop=873
#   Jalan11.csv: frames=96, down=36, up=56, eq=4, fill=1455, drop=441
#   Jalan12.csv: frames=112, down=43, up=68, eq=1, fill=1541, drop=1289
#   Jalan13.csv: frames=115, down=54, up=60, eq=1, fill=1568, drop=865
#   Jalan14.csv: frames=96, down=30, up=66, eq=0, fill=1769, drop=625
#   Jalan15.csv: frames=274, down=58, up=210, eq=6, fill=6202, drop=794
#   Jalan16.csv: frames=271, down=106, up=163, eq=2, fill=4075, drop=2220
#   Jalan17.csv: frames=237, down=94, up=140, eq=3, fill=3398, drop=2257
#   Jalan18.csv: frames=186, down=99, up=82, eq=5, fill=1865, drop=2509
#   Jalan19.csv: frames=264, down=64, up=196, eq=4, fill=5033, drop=1129
#   Jalan2.csv: frames=101, down=73, up=26, eq=2, fill=602, drop=2258
#   Jalan20.csv: frames=268, down=79, up=187, eq=2, fill=4426, drop=1848
#   Jalan21.csv: frames=251, down=136, up=111, eq=4, fill=2437, drop=3939
#   Jalan22.csv: frames=202, down=127, up=74, eq=1, fill=1451, drop=2826
#   Jalan23.csv: frames=454, down=176, up=274, eq=4, fill=6529, drop=3554
#   Jalan24.csv: frames=465, down=192, up=266, eq=7, fill=6272, drop=5622
#   Jalan25.csv: frames=73, down=22, up=50, eq=1, fill=1130, drop=257
#   Jalan26.csv: frames=93, down=65, up=28, eq=0, fill=475, drop=1905
#   Jalan27.csv: frames=83, down=46, up=36, eq=1, fill=825, drop=1392
#   Jalan28.csv: frames=47, down=0, up=47, eq=0, fill=1750, drop=0
#   Jalan29.csv: frames=64, down=2, up=62, eq=0, fill=1779, drop=25
#   Jalan3.csv: frames=98, down=64, up=34, eq=0, fill=853, drop=2442
#   Jalan30.csv: frames=76, down=7, up=68, eq=1, fill=1789, drop=37
#   Jalan31.csv: frames=71, down=34, up=36, eq=1, fill=1028, drop=675
#   Jalan32.csv: frames=55, down=27, up=28, eq=0, fill=885, drop=853
#   Jalan33.csv: frames=63, down=22, up=41, eq=0, fill=1058, drop=848
#   Jalan34.csv: frames=71, down=29, up=42, eq=0, fill=1196, drop=491
#   Jalan35.csv: frames=77, down=29, up=46, eq=2, fill=1226, drop=400
#   Jalan36.csv: frames=72, down=28, up=43, eq=1, fill=1050, drop=623
#   Jalan37.csv: frames=86, down=32, up=53, eq=1, fill=1217, drop=801
#   Jalan38.csv: frames=71, down=20, up=51, eq=0, fill=1356, drop=562
#   Jalan39.csv: frames=218, down=55, up=161, eq=2, fill=4451, drop=905
#   Jalan4.csv: frames=71, down=0, up=71, eq=0, fill=2562, drop=0
#   Jalan40.csv: frames=189, down=69, up=118, eq=2, fill=3246, drop=1686
#   Jalan41.csv: frames=167, down=60, up=106, eq=1, fill=2295, drop=1542
#   Jalan42.csv: frames=149, down=87, up=61, eq=1, fill=1190, drop=2752
#   Jalan43.csv: frames=221, down=50, up=167, eq=4, fill=4399, drop=877
#   Jalan44.csv: frames=208, down=67, up=136, eq=5, fill=3397, drop=1817
#   Jalan45.csv: frames=190, down=81, up=106, eq=3, fill=2077, drop=2243
#   Jalan46.csv: frames=150, down=80, up=67, eq=3, fill=1241, drop=2582
#   Jalan47.csv: frames=341, down=119, up=216, eq=6, fill=5044, drop=2424
#   Jalan48.csv: frames=338, down=104, up=230, eq=4, fill=6077, drop=2997
#   Jalan49.csv: frames=104, down=29, up=73, eq=2, fill=1920, drop=537
#   Jalan5.csv: frames=67, down=2, up=64, eq=1, fill=2015, drop=29
#   Jalan50.csv: frames=116, down=88, up=27, eq=1, fill=503, drop=2771
#   Jalan51.csv: frames=107, down=57, up=50, eq=0, fill=1257, drop=1466
#   Jalan52.csv: frames=73, down=2, up=70, eq=1, fill=2679, drop=8
#   Jalan53.csv: frames=84, down=2, up=81, eq=1, fill=2634, drop=3
#   Jalan54.csv: frames=105, down=27, up=78, eq=0, fill=1984, drop=330
#   Jalan55.csv: frames=99, down=36, up=60, eq=3, fill=1493, drop=546
#   Jalan56.csv: frames=89, down=37, up=52, eq=0, fill=1434, drop=1183
#   Jalan57.csv: frames=109, down=51, up=57, eq=1, fill=1495, drop=1666
#   Jalan58.csv: frames=114, down=43, up=68, eq=3, fill=1711, drop=1283
#   Jalan59.csv: frames=107, down=32, up=72, eq=3, fill=1547, drop=358
#   Jalan6.csv: frames=91, down=30, up=60, eq=1, fill=1569, drop=374
#   Jalan60.csv: frames=112, down=36, up=72, eq=4, fill=1675, drop=515
#   Jalan61.csv: frames=138, down=59, up=77, eq=2, fill=1752, drop=1530
#   Jalan62.csv: frames=118, down=56, up=60, eq=2, fill=1304, drop=1526
#   Jalan63.csv: frames=258, down=64, up=192, eq=2, fill=5409, drop=986
#   Jalan64.csv: frames=287, down=97, up=187, eq=3, fill=5278, drop=2333
#   Jalan65.csv: frames=256, down=131, up=123, eq=2, fill=2748, drop=3614
#   Jalan66.csv: frames=198, down=114, up=77, eq=7, fill=1653, drop=2868
#   Jalan67.csv: frames=290, down=62, up=226, eq=2, fill=6133, drop=1742
#   Jalan68.csv: frames=277, down=93, up=179, eq=5, fill=4344, drop=2240
#   Jalan69.csv: frames=274, down=124, up=148, eq=2, fill=3445, drop=3673
#   Jalan7.csv: frames=95, down=42, up=51, eq=2, fill=1283, drop=862
#   Jalan70.csv: frames=218, down=112, up=102, eq=4, fill=1984, drop=3025
#   Jalan71.csv: frames=476, down=155, up=317, eq=4, fill=7909, drop=3490
#   Jalan72.csv: frames=507, down=187, up=315, eq=5, fill=6933, drop=5422
#   Jalan8.csv: frames=83, down=34, up=48, eq=1, fill=1290, drop=1031
#   Jalan9.csv: frames=94, down=49, up=45, eq=0, fill=1341, drop=1992
#
# === N=48 | Subject E | files=72 ===
#   Jalan1.csv: frames=97, down=38, up=59, eq=0, fill=1154, drop=718
#   Jalan10.csv: frames=84, down=38, up=46, eq=0, fill=1127, drop=952
#   Jalan11.csv: frames=89, down=33, up=56, eq=0, fill=1459, drop=694
#   Jalan12.csv: frames=92, down=36, up=56, eq=0, fill=1330, drop=1279
#   Jalan13.csv: frames=98, down=61, up=37, eq=0, fill=886, drop=1341
#   Jalan14.csv: frames=86, down=32, up=52, eq=2, fill=1163, drop=663
#   Jalan15.csv: frames=256, down=60, up=192, eq=4, fill=5206, drop=678
#   Jalan16.csv: frames=241, down=90, up=148, eq=3, fill=4150, drop=2190
#   Jalan17.csv: frames=241, down=108, up=132, eq=1, fill=3309, drop=2612
#   Jalan18.csv: frames=167, down=102, up=64, eq=1, fill=1212, drop=2859
#   Jalan19.csv: frames=232, down=64, up=165, eq=3, fill=4241, drop=1328
#   Jalan2.csv: frames=98, down=63, up=34, eq=1, fill=661, drop=2650
#   Jalan20.csv: frames=214, down=86, up=126, eq=2, fill=3071, drop=2378
#   Jalan21.csv: frames=191, down=80, up=111, eq=0, fill=2605, drop=1903
#   Jalan22.csv: frames=159, down=111, up=46, eq=2, fill=970, drop=3407
#   Jalan23.csv: frames=382, down=136, up=241, eq=5, fill=6335, drop=2272
#   Jalan24.csv: frames=396, down=171, up=219, eq=6, fill=4886, drop=5595
#   Jalan25.csv: frames=61, down=14, up=45, eq=2, fill=976, drop=166
#   Jalan26.csv: frames=77, down=47, up=28, eq=2, fill=507, drop=1513
#   Jalan27.csv: frames=72, down=48, up=22, eq=2, fill=534, drop=1977
#   Jalan28.csv: frames=54, down=0, up=54, eq=0, fill=1924, drop=0
#   Jalan29.csv: frames=51, down=5, up=45, eq=1, fill=1054, drop=45
#   Jalan3.csv: frames=94, down=53, up=37, eq=4, fill=794, drop=1728
#   Jalan30.csv: frames=67, down=24, up=43, eq=0, fill=1006, drop=415
#   Jalan31.csv: frames=80, down=45, up=34, eq=1, fill=937, drop=1239
#   Jalan32.csv: frames=66, down=23, up=43, eq=0, fill=1362, drop=667
#   Jalan33.csv: frames=68, down=24, up=42, eq=2, fill=1054, drop=1093
#   Jalan34.csv: frames=69, down=27, up=40, eq=2, fill=1131, drop=705
#   Jalan35.csv: frames=70, down=34, up=36, eq=0, fill=835, drop=783
#   Jalan36.csv: frames=75, down=27, up=48, eq=0, fill=1043, drop=685
#   Jalan37.csv: frames=80, down=39, up=41, eq=0, fill=928, drop=867
#   Jalan38.csv: frames=69, down=27, up=41, eq=1, fill=922, drop=492
#   Jalan39.csv: frames=189, down=57, up=131, eq=1, fill=3842, drop=850
#   Jalan4.csv: frames=69, down=1, up=68, eq=0, fill=2297, drop=1
#   Jalan40.csv: frames=161, down=68, up=93, eq=0, fill=2528, drop=2010
#   Jalan41.csv: frames=166, down=93, up=71, eq=2, fill=1361, drop=2427
#   Jalan42.csv: frames=141, down=103, up=36, eq=2, fill=640, drop=3535
#   Jalan43.csv: frames=192, down=52, up=136, eq=4, fill=3480, drop=909
#   Jalan44.csv: frames=183, down=86, up=96, eq=1, fill=2138, drop=2179
#   Jalan45.csv: frames=146, down=86, up=60, eq=0, fill=1146, drop=2251
#   Jalan46.csv: frames=122, down=93, up=29, eq=0, fill=452, drop=3118
#   Jalan47.csv: frames=305, down=117, up=184, eq=4, fill=4462, drop=2519
#   Jalan48.csv: frames=320, down=117, up=201, eq=2, fill=4751, drop=4399
#   Jalan49.csv: frames=99, down=34, up=61, eq=4, fill=1023, drop=440
#   Jalan5.csv: frames=67, down=6, up=61, eq=0, fill=1712, drop=33
#   Jalan50.csv: frames=93, down=64, up=28, eq=1, fill=597, drop=2200
#   Jalan51.csv: frames=129, down=83, up=45, eq=1, fill=999, drop=2130
#   Jalan52.csv: frames=83, down=1, up=82, eq=0, fill=2540, drop=3
#   Jalan53.csv: frames=102, down=13, up=88, eq=1, fill=2328, drop=98
#   Jalan54.csv: frames=111, down=34, up=74, eq=3, fill=1965, drop=377
#   Jalan55.csv: frames=135, down=72, up=63, eq=0, fill=1552, drop=2012
#   Jalan56.csv: frames=116, down=57, up=59, eq=0, fill=1656, drop=1548
#   Jalan57.csv: frames=106, down=53, up=51, eq=2, fill=1304, drop=1089
#   Jalan58.csv: frames=111, down=49, up=61, eq=1, fill=1539, drop=1246
#   Jalan59.csv: frames=109, down=55, up=54, eq=0, fill=1419, drop=2193
#   Jalan6.csv: frames=81, down=19, up=61, eq=1, fill=1643, drop=199
#   Jalan60.csv: frames=124, down=59, up=64, eq=1, fill=1509, drop=1764
#   Jalan61.csv: frames=172, down=85, up=84, eq=3, fill=1708, drop=2472
#   Jalan62.csv: frames=155, down=60, up=91, eq=4, fill=1950, drop=1135
#   Jalan63.csv: frames=331, down=98, up=230, eq=3, fill=6626, drop=1865
#   Jalan64.csv: frames=307, down=117, up=187, eq=3, fill=5168, drop=2868
#   Jalan65.csv: frames=269, down=134, up=130, eq=5, fill=2781, drop=3616
#   Jalan66.csv: frames=233, down=160, up=68, eq=5, fill=1257, drop=4285
#   Jalan67.csv: frames=251, down=73, up=175, eq=3, fill=4662, drop=1348
#   Jalan68.csv: frames=201, down=132, up=68, eq=1, fill=1402, drop=4173
#   Jalan69.csv: frames=228, down=98, up=128, eq=2, fill=3118, drop=2428
#   Jalan7.csv: frames=86, down=45, up=41, eq=0, fill=986, drop=1023
#   Jalan70.csv: frames=163, down=117, up=46, eq=0, fill=937, drop=4065
#   Jalan71.csv: frames=467, down=170, up=289, eq=8, fill=7215, drop=3628
#   Jalan72.csv: frames=436, down=246, up=185, eq=5, fill=3903, drop=8120
#   Jalan8.csv: frames=85, down=37, up=47, eq=1, fill=1327, drop=936
#   Jalan9.csv: frames=82, down=41, up=38, eq=3, fill=961, drop=1411
#
# === N=48 | Subject F | files=72 ===
#   Jalan1.csv: frames=75, down=46, up=29, eq=0, fill=396, drop=737
#   Jalan10.csv: frames=97, down=31, up=66, eq=0, fill=1646, drop=748
#   Jalan11.csv: frames=97, down=53, up=43, eq=1, fill=1057, drop=1122
#   Jalan12.csv: frames=95, down=37, up=55, eq=3, fill=1561, drop=968
#   Jalan13.csv: frames=105, down=54, up=51, eq=0, fill=1172, drop=1161
#   Jalan14.csv: frames=105, down=25, up=79, eq=1, fill=1787, drop=443
#   Jalan15.csv: frames=245, down=67, up=173, eq=5, fill=4218, drop=960
#   Jalan16.csv: frames=269, down=102, up=162, eq=5, fill=4336, drop=1899
#   Jalan17.csv: frames=238, down=108, up=126, eq=4, fill=2947, drop=2826
#   Jalan18.csv: frames=195, down=120, up=74, eq=1, fill=1617, drop=4018
#   Jalan19.csv: frames=214, down=62, up=151, eq=1, fill=4013, drop=1455
#   Jalan2.csv: frames=89, down=64, up=25, eq=0, fill=421, drop=2554
#   Jalan20.csv: frames=208, down=78, up=125, eq=5, fill=2916, drop=1782
#   Jalan21.csv: frames=171, down=86, up=84, eq=1, fill=1645, drop=2504
#   Jalan22.csv: frames=159, down=96, up=60, eq=3, fill=1485, drop=3207
#   Jalan23.csv: frames=398, down=156, up=239, eq=3, fill=5657, drop=3231
#   Jalan24.csv: frames=383, down=193, up=183, eq=7, fill=4199, drop=6501
#   Jalan25.csv: frames=70, down=26, up=43, eq=1, fill=662, drop=414
#   Jalan26.csv: frames=76, down=48, up=27, eq=1, fill=558, drop=1946
#   Jalan27.csv: frames=74, down=49, up=25, eq=0, fill=598, drop=1259
#   Jalan28.csv: frames=36, down=0, up=36, eq=0, fill=1466, drop=0
#   Jalan29.csv: frames=49, down=1, up=48, eq=0, fill=1536, drop=4
#   Jalan3.csv: frames=86, down=52, up=33, eq=1, fill=825, drop=1731
#   Jalan30.csv: frames=68, down=17, up=49, eq=2, fill=1190, drop=227
#   Jalan31.csv: frames=69, down=25, up=41, eq=3, fill=1017, drop=402
#   Jalan32.csv: frames=69, down=29, up=40, eq=0, fill=1177, drop=811
#   Jalan33.csv: frames=72, down=29, up=42, eq=1, fill=983, drop=458
#   Jalan34.csv: frames=75, down=17, up=57, eq=1, fill=1597, drop=273
#   Jalan35.csv: frames=77, down=43, up=32, eq=2, fill=773, drop=1429
#   Jalan36.csv: frames=72, down=36, up=36, eq=0, fill=1016, drop=1012
#   Jalan37.csv: frames=86, down=50, up=34, eq=2, fill=703, drop=1509
#   Jalan38.csv: frames=83, down=20, up=61, eq=2, fill=1568, drop=466
#   Jalan39.csv: frames=181, down=60, up=121, eq=0, fill=3045, drop=1318
#   Jalan4.csv: frames=46, down=0, up=46, eq=0, fill=1729, drop=0
#   Jalan40.csv: frames=186, down=48, up=135, eq=3, fill=3333, drop=1218
#   Jalan41.csv: frames=160, down=86, up=72, eq=2, fill=1673, drop=2082
#   Jalan42.csv: frames=133, down=93, up=36, eq=4, fill=609, drop=2971
#   Jalan43.csv: frames=177, down=36, up=136, eq=5, fill=3480, drop=598
#   Jalan44.csv: frames=182, down=57, up=122, eq=3, fill=2695, drop=1442
#   Jalan45.csv: frames=154, down=74, up=77, eq=3, fill=1766, drop=2203
#   Jalan46.csv: frames=119, down=72, up=46, eq=1, fill=1017, drop=2459
#   Jalan47.csv: frames=330, down=128, up=196, eq=6, fill=5207, drop=3214
#   Jalan48.csv: frames=302, down=128, up=170, eq=4, fill=3943, drop=4131
#   Jalan49.csv: frames=98, down=52, up=46, eq=0, fill=810, drop=956
#   Jalan5.csv: frames=60, down=1, up=59, eq=0, fill=1786, drop=4
#   Jalan50.csv: frames=99, down=72, up=25, eq=2, fill=505, drop=2969
#   Jalan51.csv: frames=102, down=51, up=51, eq=0, fill=1134, drop=1496
#   Jalan52.csv: frames=48, down=0, up=48, eq=0, fill=1893, drop=0
#   Jalan53.csv: frames=72, down=2, up=70, eq=0, fill=2145, drop=7
#   Jalan54.csv: frames=94, down=23, up=67, eq=4, fill=1713, drop=259
#   Jalan55.csv: frames=89, down=36, up=52, eq=1, fill=1381, drop=751
#   Jalan56.csv: frames=81, down=41, up=40, eq=0, fill=1296, drop=879
#   Jalan57.csv: frames=96, down=52, up=43, eq=1, fill=1066, drop=2265
#   Jalan58.csv: frames=98, down=30, up=67, eq=1, fill=1868, drop=617
#   Jalan59.csv: frames=81, down=36, up=43, eq=2, fill=1010, drop=543
#   Jalan6.csv: frames=73, down=23, up=50, eq=0, fill=1141, drop=300
#   Jalan60.csv: frames=106, down=30, up=73, eq=3, fill=2169, drop=473
#   Jalan61.csv: frames=107, down=67, up=40, eq=0, fill=859, drop=1658
#   Jalan62.csv: frames=102, down=36, up=66, eq=0, fill=1551, drop=923
#   Jalan63.csv: frames=253, down=67, up=182, eq=4, fill=4815, drop=1250
#   Jalan64.csv: frames=268, down=94, up=171, eq=3, fill=4366, drop=1903
#   Jalan65.csv: frames=229, down=104, up=120, eq=5, fill=2940, drop=2685
#   Jalan66.csv: frames=180, down=128, up=49, eq=3, fill=879, drop=3867
#   Jalan67.csv: frames=208, down=43, up=161, eq=4, fill=4229, drop=849
#   Jalan68.csv: frames=254, down=81, up=172, eq=1, fill=4511, drop=1712
#   Jalan69.csv: frames=203, down=91, up=106, eq=6, fill=2304, drop=2474
#   Jalan7.csv: frames=75, down=30, up=42, eq=3, fill=1132, drop=600
#   Jalan70.csv: frames=164, down=102, up=62, eq=0, fill=1349, drop=3124
#   Jalan71.csv: frames=428, down=188, up=236, eq=4, fill=6011, drop=4368
#   Jalan72.csv: frames=400, down=224, up=174, eq=2, fill=4003, drop=7777
#   Jalan8.csv: frames=78, down=33, up=45, eq=0, fill=1407, drop=929
#   Jalan9.csv: frames=103, down=57, up=46, eq=0, fill=1249, drop=2540
#
# === N=48 | Subject G | files=72 ===
#   Jalan1.csv: frames=93, down=48, up=42, eq=3, fill=699, drop=749
#   Jalan10.csv: frames=98, down=32, up=64, eq=2, fill=1653, drop=779
#   Jalan11.csv: frames=74, down=48, up=25, eq=1, fill=460, drop=707
#   Jalan12.csv: frames=97, down=38, up=59, eq=0, fill=1295, drop=1170
#   Jalan13.csv: frames=109, down=64, up=44, eq=1, fill=1083, drop=1978
#   Jalan14.csv: frames=106, down=37, up=67, eq=2, fill=1607, drop=638
#   Jalan15.csv: frames=235, down=60, up=175, eq=0, fill=4728, drop=1157
#   Jalan16.csv: frames=236, down=89, up=142, eq=5, fill=3341, drop=1999
#   Jalan17.csv: frames=214, down=107, up=107, eq=0, fill=2335, drop=2333
#   Jalan18.csv: frames=191, down=127, up=60, eq=4, fill=1335, drop=4507
#   Jalan19.csv: frames=231, down=51, up=180, eq=0, fill=4768, drop=1086
#   Jalan2.csv: frames=101, down=66, up=33, eq=2, fill=628, drop=2737
#   Jalan20.csv: frames=196, down=61, up=132, eq=3, fill=3373, drop=1049
#   Jalan21.csv: frames=174, down=81, up=90, eq=3, fill=1930, drop=2156
#   Jalan22.csv: frames=155, down=100, up=53, eq=2, fill=1018, drop=3724
#   Jalan23.csv: frames=387, down=104, up=279, eq=4, fill=6663, drop=2032
#   Jalan24.csv: frames=376, down=164, up=205, eq=7, fill=4526, drop=5182
#   Jalan25.csv: frames=64, down=22, up=38, eq=4, fill=756, drop=414
#   Jalan26.csv: frames=77, down=56, up=20, eq=1, fill=377, drop=2070
#   Jalan27.csv: frames=67, down=41, up=25, eq=1, fill=630, drop=1243
#   Jalan28.csv: frames=43, down=0, up=43, eq=0, fill=1658, drop=0
#   Jalan29.csv: frames=57, down=1, up=56, eq=0, fill=1758, drop=12
#   Jalan3.csv: frames=97, down=49, up=46, eq=2, fill=1057, drop=1356
#   Jalan30.csv: frames=70, down=22, up=48, eq=0, fill=1254, drop=281
#   Jalan31.csv: frames=59, down=32, up=24, eq=3, fill=451, drop=842
#   Jalan32.csv: frames=63, down=32, up=30, eq=1, fill=998, drop=806
#   Jalan33.csv: frames=64, down=28, up=36, eq=0, fill=958, drop=958
#   Jalan34.csv: frames=59, down=25, up=34, eq=0, fill=869, drop=611
#   Jalan35.csv: frames=65, down=34, up=31, eq=0, fill=678, drop=616
#   Jalan36.csv: frames=90, down=31, up=59, eq=0, fill=1432, drop=825
#   Jalan37.csv: frames=85, down=48, up=37, eq=0, fill=802, drop=1091
#   Jalan38.csv: frames=72, down=32, up=40, eq=0, fill=957, drop=604
#   Jalan39.csv: frames=185, down=65, up=118, eq=2, fill=3310, drop=1474
#   Jalan4.csv: frames=49, down=0, up=49, eq=0, fill=1984, drop=0
#   Jalan40.csv: frames=179, down=69, up=108, eq=2, fill=2955, drop=1903
#   Jalan41.csv: frames=169, down=88, up=79, eq=2, fill=1684, drop=2894
#   Jalan42.csv: frames=147, down=89, up=57, eq=1, fill=1077, drop=3976
#   Jalan43.csv: frames=171, down=58, up=112, eq=1, fill=3125, drop=1430
#   Jalan44.csv: frames=176, down=67, up=108, eq=1, fill=2936, drop=1497
#   Jalan45.csv: frames=149, down=100, up=47, eq=2, fill=1005, drop=2440
#   Jalan46.csv: frames=102, down=74, up=28, eq=0, fill=560, drop=2409
#   Jalan47.csv: frames=296, down=112, up=179, eq=5, fill=4169, drop=2157
#   Jalan48.csv: frames=311, down=147, up=159, eq=5, fill=3672, drop=4410
#   Jalan49.csv: frames=92, down=38, up=52, eq=2, fill=1068, drop=832
#   Jalan5.csv: frames=77, down=4, up=73, eq=0, fill=2268, drop=25
#   Jalan50.csv: frames=109, down=74, up=34, eq=1, fill=669, drop=2946
#   Jalan51.csv: frames=109, down=70, up=39, eq=0, fill=870, drop=2181
#   Jalan52.csv: frames=76, down=1, up=75, eq=0, fill=2501, drop=7
#   Jalan53.csv: frames=84, down=1, up=82, eq=1, fill=2432, drop=7
#   Jalan54.csv: frames=110, down=9, up=101, eq=0, fill=2970, drop=41
#   Jalan55.csv: frames=85, down=42, up=41, eq=2, fill=820, drop=910
#   Jalan56.csv: frames=84, down=42, up=41, eq=1, fill=1124, drop=1118
#   Jalan57.csv: frames=84, down=48, up=36, eq=0, fill=938, drop=2080
#   Jalan58.csv: frames=100, down=55, up=45, eq=0, fill=1032, drop=1248
#   Jalan59.csv: frames=100, down=55, up=45, eq=0, fill=1032, drop=1248
#   Jalan6.csv: frames=88, down=8, up=80, eq=0, fill=2154, drop=131
#   Jalan60.csv: frames=131, down=47, up=83, eq=1, fill=1984, drop=1365
#   Jalan61.csv: frames=111, down=45, up=61, eq=5, fill=1204, drop=1127
#   Jalan62.csv: frames=120, down=57, up=61, eq=2, fill=1430, drop=1323
#   Jalan63.csv: frames=288, down=92, up=196, eq=0, fill=5467, drop=1860
#   Jalan64.csv: frames=264, down=92, up=167, eq=5, fill=4203, drop=2119
#   Jalan65.csv: frames=204, down=131, up=70, eq=3, fill=1291, drop=3421
#   Jalan66.csv: frames=202, down=147, up=51, eq=4, fill=1046, drop=4693
#   Jalan67.csv: frames=248, down=82, up=165, eq=1, fill=4137, drop=1651
#   Jalan68.csv: frames=225, down=84, up=139, eq=2, fill=3468, drop=2416
#   Jalan69.csv: frames=192, down=128, up=62, eq=2, fill=1064, drop=3685
#   Jalan7.csv: frames=109, down=41, up=67, eq=1, fill=1319, drop=959
#   Jalan70.csv: frames=179, down=125, up=54, eq=0, fill=1031, drop=4433
#   Jalan71.csv: frames=426, down=142, up=278, eq=6, fill=6454, drop=2815
#   Jalan72.csv: frames=414, down=181, up=229, eq=4, fill=5740, drop=4896
#   Jalan8.csv: frames=85, down=45, up=39, eq=1, fill=1116, drop=1004
#   Jalan9.csv: frames=97, down=50, up=45, eq=2, fill=1190, drop=1966
#
# === N=48 | Subject H | files=72 ===
#   Jalan1.csv: frames=104, down=51, up=50, eq=3, fill=953, drop=992
#   Jalan10.csv: frames=79, down=21, up=57, eq=1, fill=1489, drop=351
#   Jalan11.csv: frames=84, down=38, up=45, eq=1, fill=1061, drop=713
#   Jalan12.csv: frames=101, down=43, up=57, eq=1, fill=1508, drop=1091
#   Jalan13.csv: frames=99, down=60, up=37, eq=2, fill=814, drop=1865
#   Jalan14.csv: frames=87, down=18, up=69, eq=0, fill=1985, drop=404
#   Jalan15.csv: frames=262, down=81, up=178, eq=3, fill=4443, drop=1397
#   Jalan16.csv: frames=253, down=87, up=164, eq=2, fill=4461, drop=2055
#   Jalan17.csv: frames=215, down=109, up=104, eq=2, fill=2420, drop=3426
#   Jalan18.csv: frames=189, down=104, up=83, eq=2, fill=1826, drop=2551
#   Jalan19.csv: frames=223, down=64, up=158, eq=1, fill=3985, drop=1323
#   Jalan2.csv: frames=117, down=77, up=40, eq=0, fill=722, drop=2591
#   Jalan20.csv: frames=227, down=80, up=146, eq=1, fill=3660, drop=2036
#   Jalan21.csv: frames=208, down=84, up=123, eq=1, fill=2960, drop=2547
#   Jalan22.csv: frames=184, down=97, up=85, eq=2, fill=1909, drop=2747
#   Jalan23.csv: frames=421, down=158, up=258, eq=5, fill=6080, drop=3228
#   Jalan24.csv: frames=378, down=181, up=196, eq=1, fill=4717, drop=6990
#   Jalan25.csv: frames=51, down=8, up=42, eq=1, fill=946, drop=188
#   Jalan26.csv: frames=52, down=18, up=34, eq=0, fill=900, drop=241
#   Jalan27.csv: frames=57, down=34, up=21, eq=2, fill=521, drop=1293
#   Jalan28.csv: frames=32, down=0, up=32, eq=0, fill=1207, drop=0
#   Jalan29.csv: frames=46, down=2, up=43, eq=1, fill=1509, drop=18
#   Jalan3.csv: frames=98, down=71, up=27, eq=0, fill=625, drop=2521
#   Jalan30.csv: frames=54, down=9, up=45, eq=0, fill=1149, drop=62
#   Jalan31.csv: frames=51, down=19, up=32, eq=0, fill=745, drop=378
#   Jalan32.csv: frames=47, down=19, up=27, eq=1, fill=893, drop=618
#   Jalan33.csv: frames=49, down=27, up=22, eq=0, fill=645, drop=722
#   Jalan34.csv: frames=47, down=12, up=35, eq=0, fill=998, drop=223
#   Jalan35.csv: frames=59, down=23, up=36, eq=0, fill=906, drop=555
#   Jalan36.csv: frames=64, down=11, up=50, eq=3, fill=1228, drop=226
#   Jalan37.csv: frames=72, down=38, up=32, eq=2, fill=834, drop=974
#   Jalan38.csv: frames=59, down=18, up=39, eq=2, fill=909, drop=376
#   Jalan39.csv: frames=170, down=44, up=125, eq=1, fill=3423, drop=1002
#   Jalan4.csv: frames=63, down=0, up=63, eq=0, fill=2340, drop=0
#   Jalan40.csv: frames=164, down=57, up=103, eq=4, fill=3070, drop=1396
#   Jalan41.csv: frames=179, down=77, up=99, eq=3, fill=2119, drop=1837
#   Jalan42.csv: frames=127, down=80, up=45, eq=2, fill=821, drop=2316
#   Jalan43.csv: frames=159, down=45, up=113, eq=1, fill=3325, drop=1050
#   Jalan44.csv: frames=161, down=56, up=103, eq=2, fill=2855, drop=1385
#   Jalan45.csv: frames=163, down=58, up=102, eq=3, fill=2535, drop=1884
#   Jalan46.csv: frames=139, down=66, up=70, eq=3, fill=1390, drop=1662
#   Jalan47.csv: frames=282, down=86, up=188, eq=8, fill=4832, drop=1732
#   Jalan48.csv: frames=276, down=129, up=146, eq=1, fill=3613, drop=4449
#   Jalan49.csv: frames=120, down=57, up=57, eq=6, fill=1222, drop=1013
#   Jalan5.csv: frames=76, down=0, up=76, eq=0, fill=2377, drop=0
#   Jalan50.csv: frames=156, down=99, up=54, eq=3, fill=1197, drop=3909
#   Jalan51.csv: frames=142, down=91, up=49, eq=2, fill=1130, drop=2418
#   Jalan52.csv: frames=75, down=0, up=75, eq=0, fill=2935, drop=0
#   Jalan53.csv: frames=89, down=0, up=89, eq=0, fill=3061, drop=0
#   Jalan54.csv: frames=111, down=9, up=99, eq=3, fill=2732, drop=63
#   Jalan55.csv: frames=132, down=43, up=86, eq=3, fill=1949, drop=1022
#   Jalan56.csv: frames=142, down=65, up=74, eq=3, fill=2292, drop=1869
#   Jalan57.csv: frames=130, down=75, up=52, eq=3, fill=1323, drop=2371
#   Jalan58.csv: frames=136, down=32, up=102, eq=2, fill=2635, drop=829
#   Jalan59.csv: frames=122, down=47, up=73, eq=2, fill=1532, drop=978
#   Jalan6.csv: frames=87, down=15, up=70, eq=2, fill=1776, drop=161
#   Jalan60.csv: frames=118, down=33, up=83, eq=2, fill=2330, drop=607
#   Jalan61.csv: frames=184, down=94, up=88, eq=2, fill=1870, drop=2852
#   Jalan62.csv: frames=160, down=72, up=88, eq=0, fill=2175, drop=1561
#   Jalan63.csv: frames=332, down=68, up=261, eq=3, fill=7103, drop=911
#   Jalan64.csv: frames=318, down=99, up=214, eq=5, fill=6039, drop=1933
#   Jalan65.csv: frames=281, down=93, up=184, eq=4, fill=4889, drop=2029
#   Jalan66.csv: frames=204, down=124, up=79, eq=1, fill=1569, drop=2957
#   Jalan67.csv: frames=256, down=72, up=184, eq=0, fill=5253, drop=1886
#   Jalan68.csv: frames=256, down=73, up=180, eq=3, fill=4859, drop=1958
#   Jalan69.csv: frames=246, down=81, up=163, eq=2, fill=4090, drop=2086
#   Jalan7.csv: frames=78, down=29, up=48, eq=1, fill=1207, drop=498
#   Jalan70.csv: frames=253, down=124, up=126, eq=3, fill=2859, drop=3093
#   Jalan71.csv: frames=510, down=154, up=350, eq=6, fill=9143, drop=3025
#   Jalan72.csv: frames=528, down=255, up=266, eq=7, fill=6165, drop=8141
#   Jalan8.csv: frames=78, down=34, up=44, eq=0, fill=1269, drop=918
#   Jalan9.csv: frames=80, down=46, up=34, eq=0, fill=792, drop=1821
#
# === N=48 | Subject I | files=72 ===
#   Jalan1.csv: frames=89, down=34, up=53, eq=2, fill=1228, drop=716
#   Jalan10.csv: frames=96, down=47, up=48, eq=1, fill=1183, drop=1263
#   Jalan11.csv: frames=89, down=48, up=41, eq=0, fill=1142, drop=1924
#   Jalan12.csv: frames=100, down=41, up=58, eq=1, fill=1445, drop=892
#   Jalan13.csv: frames=121, down=73, up=46, eq=2, fill=1045, drop=2019
#   Jalan14.csv: frames=107, down=45, up=62, eq=0, fill=1434, drop=1189
#   Jalan15.csv: frames=275, down=97, up=178, eq=0, fill=4546, drop=2509
#   Jalan16.csv: frames=269, down=128, up=135, eq=6, fill=3046, drop=3170
#   Jalan17.csv: frames=227, down=122, up=100, eq=5, fill=1990, drop=3323
#   Jalan18.csv: frames=174, down=132, up=40, eq=2, fill=705, drop=3881
#   Jalan19.csv: frames=232, down=84, up=144, eq=4, fill=3245, drop=2583
#   Jalan2.csv: frames=98, down=73, up=24, eq=1, fill=439, drop=2780
#   Jalan20.csv: frames=213, down=93, up=118, eq=2, fill=2726, drop=2727
#   Jalan21.csv: frames=209, down=125, up=80, eq=4, fill=1543, drop=3538
#   Jalan22.csv: frames=133, down=118, up=15, eq=0, fill=299, drop=4732
#   Jalan23.csv: frames=381, down=175, up=203, eq=3, fill=4613, drop=3841
#   Jalan24.csv: frames=393, down=212, up=176, eq=5, fill=4121, drop=6730
#   Jalan25.csv: frames=71, down=34, up=37, eq=0, fill=711, drop=738
#   Jalan26.csv: frames=79, down=52, up=27, eq=0, fill=425, drop=1953
#   Jalan27.csv: frames=78, down=46, up=31, eq=1, fill=687, drop=1987
#   Jalan28.csv: frames=57, down=1, up=56, eq=0, fill=1957, drop=1
#   Jalan29.csv: frames=66, down=11, up=54, eq=1, fill=1436, drop=144
#   Jalan3.csv: frames=91, down=66, up=25, eq=0, fill=531, drop=2211
#   Jalan30.csv: frames=73, down=23, up=49, eq=1, fill=1098, drop=331
#   Jalan31.csv: frames=66, down=42, up=24, eq=0, fill=591, drop=1227
#   Jalan32.csv: frames=65, down=29, up=36, eq=0, fill=781, drop=885
#   Jalan33.csv: frames=76, down=40, up=36, eq=0, fill=849, drop=1472
#   Jalan34.csv: frames=73, down=34, up=39, eq=0, fill=1166, drop=1208
#   Jalan35.csv: frames=72, down=34, up=38, eq=0, fill=919, drop=825
#   Jalan36.csv: frames=74, down=41, up=33, eq=0, fill=799, drop=883
#   Jalan37.csv: frames=82, down=46, up=35, eq=1, fill=924, drop=1258
#   Jalan38.csv: frames=84, down=36, up=47, eq=1, fill=1226, drop=1214
#   Jalan39.csv: frames=207, down=80, up=123, eq=4, fill=3142, drop=2063
#   Jalan4.csv: frames=79, down=1, up=78, eq=0, fill=2545, drop=12
#   Jalan40.csv: frames=194, down=97, up=94, eq=3, fill=2214, drop=2630
#   Jalan41.csv: frames=158, down=85, up=71, eq=2, fill=1609, drop=2403
#   Jalan42.csv: frames=124, down=96, up=26, eq=2, fill=392, drop=3428
#   Jalan43.csv: frames=170, down=76, up=92, eq=2, fill=1997, drop=2260
#   Jalan44.csv: frames=166, down=97, up=68, eq=1, fill=1183, drop=2842
#   Jalan45.csv: frames=144, down=86, up=57, eq=1, fill=968, drop=2649
#   Jalan46.csv: frames=128, down=99, up=25, eq=4, fill=449, drop=3972
#   Jalan47.csv: frames=308, down=151, up=153, eq=4, fill=3471, drop=4127
#   Jalan48.csv: frames=305, down=154, up=150, eq=1, fill=3553, drop=5122
#   Jalan49.csv: frames=102, down=41, up=58, eq=3, fill=1167, drop=914
#   Jalan5.csv: frames=78, down=4, up=73, eq=1, fill=2138, drop=26
#   Jalan50.csv: frames=117, down=81, up=33, eq=3, fill=666, drop=2698
#   Jalan51.csv: frames=110, down=71, up=39, eq=0, fill=968, drop=2780
#   Jalan52.csv: frames=84, down=1, up=82, eq=1, fill=2644, drop=18
#   Jalan53.csv: frames=94, down=10, up=84, eq=0, fill=2372, drop=97
#   Jalan54.csv: frames=114, down=29, up=83, eq=2, fill=2076, drop=413
#   Jalan55.csv: frames=107, down=55, up=51, eq=1, fill=1109, drop=1346
#   Jalan56.csv: frames=88, down=45, up=41, eq=2, fill=1136, drop=1197
#   Jalan57.csv: frames=108, down=71, up=37, eq=0, fill=1043, drop=2818
#   Jalan58.csv: frames=118, down=57, up=60, eq=1, fill=1673, drop=1570
#   Jalan59.csv: frames=114, down=62, up=51, eq=1, fill=1329, drop=1440
#   Jalan6.csv: frames=96, down=33, up=62, eq=1, fill=1433, drop=492
#   Jalan60.csv: frames=115, down=48, up=67, eq=0, fill=1848, drop=1672
#   Jalan61.csv: frames=143, down=75, up=66, eq=2, fill=1489, drop=1960
#   Jalan62.csv: frames=110, down=44, up=65, eq=1, fill=1516, drop=731
#   Jalan63.csv: frames=308, down=119, up=185, eq=4, fill=4466, drop=3135
#   Jalan64.csv: frames=264, down=130, up=127, eq=7, fill=2708, drop=3775
#   Jalan65.csv: frames=213, down=131, up=80, eq=2, fill=1690, drop=3897
#   Jalan66.csv: frames=178, down=130, up=46, eq=2, fill=638, drop=4483
#   Jalan67.csv: frames=271, down=91, up=178, eq=2, fill=4188, drop=2394
#   Jalan68.csv: frames=242, down=102, up=136, eq=4, fill=3266, drop=2557
#   Jalan69.csv: frames=205, down=153, up=49, eq=3, fill=817, drop=4511
#   Jalan7.csv: frames=89, down=46, up=42, eq=1, fill=908, drop=1021
#   Jalan70.csv: frames=167, down=137, up=28, eq=2, fill=435, drop=5391
#   Jalan71.csv: frames=428, down=207, up=217, eq=4, fill=4892, drop=5046
#   Jalan72.csv: frames=454, down=258, up=189, eq=7, fill=4083, drop=8365
#   Jalan8.csv: frames=84, down=44, up=40, eq=0, fill=1016, drop=1156
#   Jalan9.csv: frames=96, down=51, up=43, eq=2, fill=1090, drop=1110
#
# === N=48 | Subject J | files=72 ===
#   Jalan1.csv: frames=91, down=45, up=45, eq=1, fill=953, drop=935
#   Jalan10.csv: frames=91, down=42, up=49, eq=0, fill=1322, drop=1131
#   Jalan11.csv: frames=111, down=59, up=51, eq=1, fill=1430, drop=1510
#   Jalan12.csv: frames=98, down=38, up=57, eq=3, fill=1396, drop=1308
#   Jalan13.csv: frames=108, down=45, up=62, eq=1, fill=1362, drop=1486
#   Jalan14.csv: frames=94, down=38, up=56, eq=0, fill=1189, drop=617
#   Jalan15.csv: frames=257, down=52, up=202, eq=3, fill=5195, drop=832
#   Jalan16.csv: frames=233, down=90, up=142, eq=1, fill=3659, drop=2048
#   Jalan17.csv: frames=214, down=96, up=117, eq=1, fill=2668, drop=1641
#   Jalan18.csv: frames=177, down=125, up=50, eq=2, fill=1091, drop=3790
#   Jalan19.csv: frames=223, down=84, up=137, eq=2, fill=3273, drop=2046
#   Jalan2.csv: frames=100, down=69, up=28, eq=3, fill=570, drop=2096
#   Jalan20.csv: frames=225, down=125, up=96, eq=4, fill=2113, drop=2774
#   Jalan21.csv: frames=204, down=128, up=71, eq=5, fill=1160, drop=3275
#   Jalan22.csv: frames=181, down=114, up=67, eq=0, fill=1415, drop=3349
#   Jalan23.csv: frames=475, down=126, up=344, eq=5, fill=8208, drop=2068
#   Jalan24.csv: frames=468, down=221, up=241, eq=6, fill=5288, drop=7260
#   Jalan25.csv: frames=71, down=30, up=41, eq=0, fill=709, drop=622
#   Jalan26.csv: frames=75, down=51, up=24, eq=0, fill=418, drop=1036
#   Jalan27.csv: frames=80, down=50, up=30, eq=0, fill=811, drop=1636
#   Jalan28.csv: frames=59, down=0, up=59, eq=0, fill=1969, drop=0
#   Jalan29.csv: frames=61, down=3, up=58, eq=0, fill=1580, drop=13
#   Jalan3.csv: frames=91, down=56, up=35, eq=0, fill=716, drop=2264
#   Jalan30.csv: frames=67, down=18, up=49, eq=0, fill=1167, drop=216
#   Jalan31.csv: frames=69, down=35, up=33, eq=1, fill=761, drop=938
#   Jalan32.csv: frames=64, down=29, up=34, eq=1, fill=965, drop=705
#   Jalan33.csv: frames=75, down=39, up=35, eq=1, fill=740, drop=758
#   Jalan34.csv: frames=71, down=30, up=39, eq=2, fill=1170, drop=904
#   Jalan35.csv: frames=76, down=38, up=37, eq=1, fill=1017, drop=1127
#   Jalan36.csv: frames=68, down=19, up=48, eq=1, fill=1068, drop=386
#   Jalan37.csv: frames=84, down=32, up=50, eq=2, fill=1122, drop=655
#   Jalan38.csv: frames=74, down=28, up=46, eq=0, fill=973, drop=777
#   Jalan39.csv: frames=195, down=74, up=120, eq=1, fill=2645, drop=1885
#   Jalan4.csv: frames=77, down=1, up=76, eq=0, fill=2526, drop=2
#   Jalan40.csv: frames=195, down=74, up=120, eq=1, fill=2645, drop=1885
#   Jalan41.csv: frames=157, down=91, up=63, eq=3, fill=1121, drop=2006
#   Jalan42.csv: frames=132, down=94, up=34, eq=4, fill=591, drop=2786
#   Jalan43.csv: frames=191, down=87, up=99, eq=5, fill=2156, drop=2449
#   Jalan44.csv: frames=189, down=109, up=78, eq=2, fill=1483, drop=3132
#   Jalan45.csv: frames=151, down=111, up=38, eq=2, fill=568, drop=3139
#   Jalan46.csv: frames=123, down=102, up=20, eq=1, fill=290, drop=3302
#   Jalan47.csv: frames=332, down=122, up=205, eq=5, fill=4697, drop=2487
#   Jalan48.csv: frames=373, down=139, up=228, eq=6, fill=5632, drop=4898
#   Jalan49.csv: frames=112, down=47, up=64, eq=1, fill=1188, drop=999
#   Jalan5.csv: frames=78, down=3, up=75, eq=0, fill=2112, drop=23
#   Jalan50.csv: frames=109, down=63, up=45, eq=1, fill=728, drop=1729
#   Jalan51.csv: frames=113, down=77, up=35, eq=1, fill=837, drop=1980
#   Jalan52.csv: frames=88, down=2, up=85, eq=1, fill=2633, drop=22
#   Jalan53.csv: frames=98, down=4, up=94, eq=0, fill=2830, drop=15
#   Jalan54.csv: frames=104, down=12, up=92, eq=0, fill=2316, drop=106
#   Jalan55.csv: frames=109, down=70, up=39, eq=0, fill=874, drop=1889
#   Jalan56.csv: frames=97, down=42, up=53, eq=2, fill=1236, drop=818
#   Jalan57.csv: frames=108, down=63, up=44, eq=1, fill=1247, drop=1319
#   Jalan58.csv: frames=104, down=42, up=62, eq=0, fill=1622, drop=1011
#   Jalan59.csv: frames=112, down=64, up=46, eq=2, fill=1165, drop=2273
#   Jalan6.csv: frames=90, down=24, up=66, eq=0, fill=1626, drop=300
#   Jalan60.csv: frames=107, down=38, up=68, eq=1, fill=1704, drop=717
#   Jalan61.csv: frames=132, down=61, up=66, eq=5, fill=1547, drop=1614
#   Jalan62.csv: frames=121, down=46, up=71, eq=4, fill=1691, drop=1160
#   Jalan63.csv: frames=285, down=47, up=237, eq=1, fill=6443, drop=557
#   Jalan64.csv: frames=268, down=103, up=162, eq=3, fill=4033, drop=2171
#   Jalan65.csv: frames=228, down=107, up=116, eq=5, fill=2416, drop=2435
#   Jalan66.csv: frames=191, down=108, up=83, eq=0, fill=1454, drop=3015
#   Jalan67.csv: frames=259, down=113, up=141, eq=5, fill=2891, drop=2819
#   Jalan68.csv: frames=232, down=130, up=100, eq=2, fill=1937, drop=3408
#   Jalan69.csv: frames=196, down=145, up=50, eq=1, fill=841, drop=4434
#   Jalan7.csv: frames=91, down=39, up=50, eq=2, fill=1223, drop=871
#   Jalan70.csv: frames=163, down=130, up=32, eq=1, fill=518, drop=4498
#   Jalan71.csv: frames=519, down=169, up=347, eq=3, fill=8666, drop=3224
#   Jalan72.csv: frames=488, down=266, up=214, eq=8, fill=4677, drop=7754
#   Jalan8.csv: frames=83, down=37, up=46, eq=0, fill=1151, drop=843
#   Jalan9.csv: frames=98, down=43, up=54, eq=1, fill=1428, drop=1495
#
# Saved summary: E:\0.TA_Teguh\Sampling\FPS\fps_sampling_summary.csv
#           file subject   N  frames  down  up  eq  empty  total_drop  \
# 0   Jalan1.csv       A  48      82    17  63   2      0         256
# 1  Jalan10.csv       A  48      87    35  51   1      0         799
# 2  Jalan11.csv       A  48      87    42  44   1      0        1653
# 3  Jalan12.csv       A  48      98    51  46   1      0        1303
# 4  Jalan13.csv       A  48     103    47  53   3      0        1163
#
#    total_fill
# 0        1506
# 1        1289
# 2        1219
# 3        1205
# 4        1084

# %% [markdown]
# Cell 11 — Quick sanity checks on outputs (optional)

# %%
if len(all_stats) > 0:
    df_sum = pd.DataFrame(all_stats)
    display(df_sum.groupby(["N"]).agg(
        files=("file","count"),
        frames=("frames","sum"),
        down=("down","sum"),
        up=("up","sum"),
        eq=("eq","sum"),
        total_fill=("total_fill","sum"),
        total_drop=("total_drop","sum"),
    ).reset_index())

    display(df_sum.groupby(["N","subject"]).agg(
        files=("file","count"),
        frames=("frames","sum"),
        down=("down","sum"),
        up=("up","sum"),
        eq=("eq","sum"),
    ).reset_index())
# Out:
#     N  files  frames   down     up    eq  total_fill  total_drop
# 0  48    720  114170  47564  65299  1307     1627984     1264840
#     N subject  files  frames  down    up   eq
# 0  48       A     72   10459  4501  5843  115
# 1  48       B     72   12224  4920  7176  128
# 2  48       C     72   13890  4972  8772  146
# 3  48       D     72   11861  4481  7230  150
# 4  48       E     72   11102  4831  6147  124
# 5  48       F     72   10424  4396  5892  136
# 6  48       G     72   10532  4535  5879  118
# 7  48       H     72   11352  4344  6872  136
# 8  48       I     72   10993  5530  5337  126
# 9  48       J     72   11333  5054  6151  128
